# %% [markdown]
# # TensoerFlow 준비하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.1 시작하며
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# - 텐서플로우 공식 API: https://www.tensorflow.org/api_docs/python/tf
# -케라스 공식 API: https://keras.io/guides/functional_api/

# %% [markdown]
# ## 1.2 케라스란?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 구글 코랩
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'
