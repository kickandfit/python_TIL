# %%
# 평가 지표 평균 90 이상
import pandas as pd
from numpy import mean, std
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import metrics
from imblearn.under_sampling import TomekLinks
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from imblearn.under_sampling import *

df = pd.read_csv('./TravelInsurancePrediction.csv')
df['FrequentFlyer'] = df['FrequentFlyer'].map({'Yes': 1, 'No': 0})
df['EverTravelledAbroad'] = df['EverTravelledAbroad'].map({'Yes': 1, 'No': 0})
df["Employment Type"] = df["Employment Type"].map({"Government Sector" : 1, "Private Sector/Self Employed" : 0})
df['GraduateOrNot'] = df['GraduateOrNot'].map({'Yes': 1, 'No': 0})

# df = df.drop(["GraduateOrNot"] , axis=1)
df_index = ['Age', 'AnnualIncome', 'ChronicDiseases',"GraduateOrNot", 
          'FrequentFlyer', 'FamilyMembers', 'Employment Type',
          'EverTravelledAbroad']
df_label_index = ['TravelInsurance']
ndf = df[['Age', 'AnnualIncome', 'ChronicDiseases', 'GraduateOrNot',
          'FrequentFlyer', 'FamilyMembers', 'Employment Type',
          'EverTravelledAbroad', 'TravelInsurance']]
X = ndf[list(ndf.columns)[:-1]]
y = ndf[list(ndf.columns)[-1]]
# y = y.astype({'TravelInsurance': int})
# X = preprocessing.StandardScaler().fit(X).transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    random_state=10)
print(X_train.shape)
df_new = pd.concat([X_train,y_train], axis = 1)

df_new.head()
# Out:
# C:\Users\moh12\Anaconda3\envs\multi\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\moh12\Anaconda3\envs\multi\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\moh12\Anaconda3\envs\multi\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %
# (1589, 8)
#       Age  AnnualIncome  ChronicDiseases  GraduateOrNot  FrequentFlyer  \
# 1857   27        900000                0              1              0
# 685    34       1500000                1              1              1
# 1970   29        500000                0              1              0
# 1885   35       1100000                0              1              0
# 895    28        600000                0              1              0
#
#       FamilyMembers  Employment Type  EverTravelledAbroad  TravelInsurance
# 1857              4                1                    0                0
# 685               4                0                    1                1
# 1970              4                0                    0                1
# 1885              3                1                    0                0
# 895               5                0                    1                1

# %%
# incom>132500 이상, 가족이 5.5 명 이상 이걸 오버샘플링해보자
ndf1 = df[['Age', 'AnnualIncome', 'Employment Type',
           'TravelInsurance']]
X1 = ndf[list(ndf.columns)[:-1]]
y1 = ndf[list(ndf.columns)[-1]]
# y = y.astype({'TravelInsurance': int})
# X = preprocessing.StandardScaler().fit(X).transform(X)

X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, 
                                                    random_state=10)
df_new = pd.concat([X_train,y_train], axis = 1)

df_new = df_new[(df_new['AnnualIncome'] >= 1275000) | (df_new['FamilyMembers'] >= 5.5) | (df_new['Age'] >= 32.5)| (df_new['GraduateOrNot'] >= 0.5) ]
X_train = df_new[list(ndf.columns)[:-1]]

y_train = df_new[list(ndf.columns)[-1]]
df_new.info()
X_train.info()

# %%
df_new.describe()

# %% [markdown]
# #### 언더샘플링

# %%
# 평균 73, 재현율 70( 1) 그러나 (0 )이 70 대로 떨어짐
enn = EditedNearestNeighbours()
X_resampled, y_resampled  = enn.fit_resample(X_train, y_train)
print(X_resampled.shape)
# Out:
# (1143, 8)

# %%
# 재현율 57 
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=0)
X_resampled, y_resampled = rus.fit_resample(X_train, y_train)
print(X_resampled.shape)
# Out:
# (1138, 8)

# %%
from imblearn.under_sampling import NearMiss
nm1 = NearMiss(version=1)
X_resampled, y_resampled = nm1.fit_resample(X_train, y_train)
print(X_resampled.shape)
# Out:
# (1138, 8)

# %%
renn = RepeatedEditedNearestNeighbours()
X_resampled, y_resampled = renn.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %%
allknn = AllKNN()
X_resampled, y_resampled = allknn.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %%
#언더 샘플링 중에는 제일 좋네 그나마
cnn = CondensedNearestNeighbour(random_state=0)
X_resampled, y_resampled = cnn.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %%
# 니가 일등이네
oss = OneSidedSelection(random_state=0)
X_resampled, y_resampled = oss.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %%
ncr = NeighbourhoodCleaningRule()
X_resampled, y_resampled = ncr.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %%
from sklearn.linear_model import LogisticRegression
iht = InstanceHardnessThreshold(random_state=0,                                 estimator=LogisticRegression(
                                    solver='lbfgs', multi_class='auto'))
X_resampled, y_resampled = iht.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %% [markdown]
# #### 오버샘플링 smotenc / smoten

# %%
# 가장 높은 점수 결정 나무, depth 5
from imblearn.over_sampling import SMOTENC
smote_nc = SMOTENC(categorical_features=[0, 2], random_state=0)
X_resampled, y_resampled = smote_nc.fit_resample(X_train, y_train)
print(X_resampled.shape)
# Out:
# (2040, 8)

# %%
from imblearn.over_sampling import SMOTEN
sampler = SMOTEN(random_state=0)
X_resampled, y_resampled = sampler.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %% [markdown]
# #### 오버와 언더 조합

# %%
from imblearn.combine import *
smote_enn = SMOTEENN(random_state=0)
X_resampled, y_resampled = smote_enn.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %%
smote_tomek = SMOTETomek(random_state=0)
X_resampled, y_resampled = smote_tomek.fit_resample(X_train, y_train)
print(X_resampled.shape)

# %% [markdown]
# #### 분류 모델

# %%
from sklearn import tree
# sklearn 라이브러리에서 Decision Tree 분류 모형 가져오기

# 모형 객체 생성 (criterion='entropy' 적용)
tree_model = tree.DecisionTreeClassifier(criterion='entropy', max_depth=5)

tree_model.fit(X_resampled, y_resampled)
pred_proba = tree_model.predict_proba(X_test)

y_hat = tree_model.predict(X_test)
tree_matrix = metrics.confusion_matrix(y_test, y_hat)
print('DecisionTree : 결과')
print(tree_matrix)
tree_report = metrics.classification_report(y_test, y_hat)
print(tree_report)


# 타이타닉  생존자 데이터에서 predict() 결과 값과 predict_proba() 결과 값을 비교


print('pred_proba의 shape: {0}'.format(pred_proba.shape))
print('pred_proba의 array에서 앞 3개만 샘플로 추출 :\n', pred_proba[:3])

#예측확률 array와 예측 결과값 array를 병합하여 예측확률과 결괏값을 한 번에 확인
# pred_proba = tree_model.predict_proba(X_test)
pred_proba_result = np.concatenate([pred_proba, y_hat.reshape(-1,1)], axis=1)
print('두 개의 class 중 더 큰 확률을 클래스 값으로 예측\n', pred_proba_result[:3])
# Out:
# [[251   6]
#  [ 57  84]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89       257
#            1       0.93      0.60      0.73       141
#
#     accuracy                           0.84       398
#    macro avg       0.87      0.79      0.81       398
# weighted avg       0.86      0.84      0.83       398
#
# pred_proba의 shape: (398, 2)
# pred_proba의 array에서 앞 3개만 샘플로 추출 :
#  [[0.16       0.84      ]
#  [0.75630252 0.24369748]
#  [0.75630252 0.24369748]]
# 두 개의 class 중 더 큰 확률을 클래스 값으로 예측
#  [[0.16       0.84       1.        ]
#  [0.75630252 0.24369748 0.        ]
#  [0.75630252 0.24369748 0.        ]]

# %%
#thesold 조정
from sklearn.preprocessing import Binarizer
binarizer = Binarizer(threshold=0.3)
# Binarizer의 threshold 값을 0.5로 설정
for i in range(19, 81):
    custom_threshold = i*0.01
    # predict_proba() 결과 값의 두 번째 컬럼, 즉 Positive 클래스의 컬럼 하나만 추출하여 Binarizer를 적용
    pred_proba_1 = pred_proba[:,1].reshape(-1,1)

    binarizer = Binarizer(threshold=custom_threshold).fit(pred_proba_1)
    custom_predict = binarizer.transform(pred_proba_1)
    print(i-19,'번째  theshold 값 : ', i*0.01)
    get_clf_eval(y_test, custom_predict)
    print()

from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# 호출한 지표들을 한꺼번에 계산하는 함수 정의
def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    print('오차행렬')
    print(confusion)
    print('정확도 : {:.4f}\n정밀도 : {:.4f}\n재현율 : {:.4f}'.format(accuracy, precision, recall))
# Out:
# 0 번째  theshold 값 :  0.19
# 오차행렬
# [[ 60 197]
#  [  9 132]]
# 정확도 : 0.4824
# 정밀도 : 0.4012
# 재현율 : 0.9362
#
# 1 번째  theshold 값 :  0.2
# 오차행렬
# [[ 60 197]
#  [  9 132]]
# 정확도 : 0.4824
# 정밀도 : 0.4012
# 재현율 : 0.9362
#
# 2 번째  theshold 값 :  0.21
# 오차행렬
# [[ 60 197]
#  [  9 132]]
# 정확도 : 0.4824
# 정밀도 : 0.4012
# 재현율 : 0.9362
#
# 3 번째  theshold 값 :  0.22
# 오차행렬
# [[ 60 197]
#  [  9 132]]
# 정확도 : 0.4824
# 정밀도 : 0.4012
# 재현율 : 0.9362
#
# 4 번째  theshold 값 :  0.23
# 오차행렬
# [[ 60 197]
#  [  9 132]]
# 정확도 : 0.4824
# 정밀도 : 0.4012
# 재현율 : 0.9362
#
# 5 번째  theshold 값 :  0.24
# 오차행렬
# [[ 60 197]
#  [  9 132]]
# 정확도 : 0.4824
# 정밀도 : 0.4012
# 재현율 : 0.9362
#
# 6 번째  theshold 값 :  0.25
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 7 번째  theshold 값 :  0.26
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 8 번째  theshold 값 :  0.27
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 9 번째  theshold 값 :  0.28
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 10 번째  theshold 값 :  0.29
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 11 번째  theshold 값 :  0.3
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 12 번째  theshold 값 :  0.31
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 13 번째  theshold 값 :  0.32
# 오차행렬
# [[ 94 163]
#  [ 24 117]]
# 정확도 : 0.5302
# 정밀도 : 0.4179
# 재현율 : 0.8298
#
# 14 번째  theshold 값 :  0.33
# 오차행렬
# [[136 121]
#  [ 37 104]]
# 정확도 : 0.6030
# 정밀도 : 0.4622
# 재현율 : 0.7376
#
# 15 번째  theshold 값 :  0.34
# 오차행렬
# [[136 121]
#  [ 37 104]]
# 정확도 : 0.6030
# 정밀도 : 0.4622
# 재현율 : 0.7376
#
# 16 번째  theshold 값 :  0.35000000000000003
# 오차행렬
# [[136 121]
#  [ 37 104]]
# 정확도 : 0.6030
# 정밀도 : 0.4622
# 재현율 : 0.7376
#
# 17 번째  theshold 값 :  0.36
# 오차행렬
# [[136 121]
#  [ 37 104]]
# 정확도 : 0.6030
# 정밀도 : 0.4622
# 재현율 : 0.7376
#
# 18 번째  theshold 값 :  0.37
# 오차행렬
# [[136 121]
#  [ 37 104]]
# 정확도 : 0.6030
# 정밀도 : 0.4622
# 재현율 : 0.7376
#
# 19 번째  theshold 값 :  0.38
# 오차행렬
# [[136 121]
#  [ 37 104]]
# 정확도 : 0.6030
# 정밀도 : 0.4622
# 재현율 : 0.7376
#
# 20 번째  theshold 값 :  0.39
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 21 번째  theshold 값 :  0.4
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 22 번째  theshold 값 :  0.41000000000000003
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 23 번째  theshold 값 :  0.42
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 24 번째  theshold 값 :  0.43
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 25 번째  theshold 값 :  0.44
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 26 번째  theshold 값 :  0.45
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 27 번째  theshold 값 :  0.46
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 28 번째  theshold 값 :  0.47000000000000003
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 29 번째  theshold 값 :  0.48
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 30 번째  theshold 값 :  0.49
# 오차행렬
# [[244  13]
#  [ 56  85]]
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
#
# 31 번째  theshold 값 :  0.5
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 32 번째  theshold 값 :  0.51
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 33 번째  theshold 값 :  0.52
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 34 번째  theshold 값 :  0.53
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 35 번째  theshold 값 :  0.54
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 36 번째  theshold 값 :  0.55
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 37 번째  theshold 값 :  0.56
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 38 번째  theshold 값 :  0.5700000000000001
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 39 번째  theshold 값 :  0.58
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 40 번째  theshold 값 :  0.59
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 41 번째  theshold 값 :  0.6
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 42 번째  theshold 값 :  0.61
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 43 번째  theshold 값 :  0.62
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 44 번째  theshold 값 :  0.63
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 45 번째  theshold 값 :  0.64
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 46 번째  theshold 값 :  0.65
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 47 번째  theshold 값 :  0.66
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 48 번째  theshold 값 :  0.67
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 49 번째  theshold 값 :  0.68
# 오차행렬
# [[251   6]
#  [ 57  84]]
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
#
# 50 번째  theshold 값 :  0.6900000000000001
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 51 번째  theshold 값 :  0.7000000000000001
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 52 번째  theshold 값 :  0.71
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 53 번째  theshold 값 :  0.72
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 54 번째  theshold 값 :  0.73
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 55 번째  theshold 값 :  0.74
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 56 번째  theshold 값 :  0.75
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 57 번째  theshold 값 :  0.76
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 58 번째  theshold 값 :  0.77
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 59 번째  theshold 값 :  0.78
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 60 번째  theshold 값 :  0.79
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816
#
# 61 번째  theshold 값 :  0.8
# 오차행렬
# [[251   6]
#  [ 59  82]]
# 정확도 : 0.8367
# 정밀도 : 0.9318
# 재현율 : 0.5816

# %%
from sklearn.tree import DecisionTreeClassifier
from imblearn.ensemble import BalancedBaggingClassifier
bbc = BalancedBaggingClassifier(base_estimator=DecisionTreeClassifier(),
                                sampling_strategy='auto',
                                replacement=False,
                                random_state=0)
bbc.fit(X_resampled, y_resampled) 
y_hat = bbc.predict(X_test)
bbc_matrix = metrics.confusion_matrix(y_test, y_hat)
print(bbc_matrix)
bbc_report = metrics.classification_report(y_test, y_hat)
print(bbc_report)

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=100, random_state=0)
brf.fit(X_resampled, y_resampled) 
y_hat = brf.predict(X_test)
brf_matrix = metrics.confusion_matrix(y_test, y_hat)
print(brf_matrix)
brf_report = metrics.classification_report(y_test, y_hat)
print(brf_report)

# %%
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(random_state=0)
eec.fit(X_resampled, y_resampled)
y_hat = eec.predict(X_test)
eec_matrix = metrics.confusion_matrix(y_test, y_hat)
print(eec_matrix)
eec_report = metrics.classification_report(y_test, y_hat)
print(eec_report)

# %% [markdown]
# #### 랜덤포레스트

# %%
#랜덤 포레스트는 오버샘플링이 좋음
# 오버 언더 조합도 낫베드( 데이터 개수가 늘어날 수록 좋음)
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_resampled , y_resampled)
# rf_clf.fit(X_train , y_train)
pred_proba = rf_clf.predict_proba(X_test)

y_hat = rf_clf.predict(X_test)

pred_proba_result = np.concatenate([pred_proba, y_hat.reshape(-1,1)], axis=1)

rf_clf_matrix = metrics.confusion_matrix(y_test, y_hat)
print(rf_clf_matrix)
rf_clf_report = metrics.classification_report(y_test, y_hat)
print(rf_clf_report)
#thesold 조정
from sklearn.preprocessing import Binarizer
binarizer = Binarizer(threshold=1.1)
# Binarizer의 threshold 값을 0.5로 설정
for i in range(19, 51):
    custom_threshold = i*0.01
    # predict_proba() 결과 값의 두 번째 컬럼, 즉 Positive 클래스의 컬럼 하나만 추출하여 Binarizer를 적용
    pred_proba_1 = pred_proba[:,1].reshape(-1,1)

    binarizer = Binarizer(threshold=custom_threshold).fit(pred_proba_1)
    custom_predict = binarizer.transform(pred_proba_1)
    print(i-19,'번째  theshold 값 : ', i*0.01)
    get_clf_eval(y_test, custom_predict)
    print()
# Out:
# [[215  42]
#  [ 51  90]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       257
#            1       0.68      0.64      0.66       141
#
#     accuracy                           0.77       398
#    macro avg       0.75      0.74      0.74       398
# weighted avg       0.76      0.77      0.76       398
#
# 0 번째  theshold 값 :  0.19
# 오차행렬
# [[133 124]
#  [ 29 112]]
# 정확도 : 0.6156
# 정밀도 : 0.4746
# 재현율 : 0.7943
#
# 1 번째  theshold 값 :  0.2
# 오차행렬
# [[134 123]
#  [ 30 111]]
# 정확도 : 0.6156
# 정밀도 : 0.4744
# 재현율 : 0.7872
#
# 2 번째  theshold 값 :  0.21
# 오차행렬
# [[135 122]
#  [ 31 110]]
# 정확도 : 0.6156
# 정밀도 : 0.4741
# 재현율 : 0.7801
#
# 3 번째  theshold 값 :  0.22
# 오차행렬
# [[138 119]
#  [ 32 109]]
# 정확도 : 0.6206
# 정밀도 : 0.4781
# 재현율 : 0.7730
#
# 4 번째  theshold 값 :  0.23
# 오차행렬
# [[144 113]
#  [ 32 109]]
# 정확도 : 0.6357
# 정밀도 : 0.4910
# 재현율 : 0.7730
#
# 5 번째  theshold 값 :  0.24
# 오차행렬
# [[147 110]
#  [ 35 106]]
# 정확도 : 0.6357
# 정밀도 : 0.4907
# 재현율 : 0.7518
#
# 6 번째  theshold 값 :  0.25
# 오차행렬
# [[148 109]
#  [ 35 106]]
# 정확도 : 0.6382
# 정밀도 : 0.4930
# 재현율 : 0.7518
#
# 7 번째  theshold 값 :  0.26
# 오차행렬
# [[153 104]
#  [ 36 105]]
# 정확도 : 0.6482
# 정밀도 : 0.5024
# 재현율 : 0.7447
#
# 8 번째  theshold 값 :  0.27
# 오차행렬
# [[155 102]
#  [ 37 104]]
# 정확도 : 0.6508
# 정밀도 : 0.5049
# 재현율 : 0.7376
#
# 9 번째  theshold 값 :  0.28
# 오차행렬
# [[156 101]
#  [ 38 103]]
# 정확도 : 0.6508
# 정밀도 : 0.5049
# 재현율 : 0.7305
#
# 10 번째  theshold 값 :  0.29
# 오차행렬
# [[157 100]
#  [ 38 103]]
# 정확도 : 0.6533
# 정밀도 : 0.5074
# 재현율 : 0.7305
#
# 11 번째  theshold 값 :  0.3
# 오차행렬
# [[159  98]
#  [ 38 103]]
# 정확도 : 0.6583
# 정밀도 : 0.5124
# 재현율 : 0.7305
#
# 12 번째  theshold 값 :  0.31
# 오차행렬
# [[164  93]
#  [ 38 103]]
# 정확도 : 0.6709
# 정밀도 : 0.5255
# 재현율 : 0.7305
#
# 13 번째  theshold 값 :  0.32
# 오차행렬
# [[166  91]
#  [ 38 103]]
# 정확도 : 0.6759
# 정밀도 : 0.5309
# 재현율 : 0.7305
#
# 14 번째  theshold 값 :  0.33
# 오차행렬
# [[171  86]
#  [ 39 102]]
# 정확도 : 0.6859
# 정밀도 : 0.5426
# 재현율 : 0.7234
#
# 15 번째  theshold 값 :  0.34
# 오차행렬
# [[173  84]
#  [ 39 102]]
# 정확도 : 0.6910
# 정밀도 : 0.5484
# 재현율 : 0.7234
#
# 16 번째  theshold 값 :  0.35000000000000003
# 오차행렬
# [[177  80]
#  [ 41 100]]
# 정확도 : 0.6960
# 정밀도 : 0.5556
# 재현율 : 0.7092
#
# 17 번째  theshold 값 :  0.36
# 오차행렬
# [[181  76]
#  [ 42  99]]
# 정확도 : 0.7035
# 정밀도 : 0.5657
# 재현율 : 0.7021
#
# 18 번째  theshold 값 :  0.37
# 오차행렬
# [[182  75]
#  [ 42  99]]
# 정확도 : 0.7060
# 정밀도 : 0.5690
# 재현율 : 0.7021
#
# 19 번째  theshold 값 :  0.38
# 오차행렬
# [[184  73]
#  [ 43  98]]
# 정확도 : 0.7085
# 정밀도 : 0.5731
# 재현율 : 0.6950
#
# 20 번째  theshold 값 :  0.39
# 오차행렬
# [[191  66]
#  [ 43  98]]
# 정확도 : 0.7261
# 정밀도 : 0.5976
# 재현율 : 0.6950
#
# 21 번째  theshold 값 :  0.4
# 오차행렬
# [[194  63]
#  [ 44  97]]
# 정확도 : 0.7312
# 정밀도 : 0.6062
# 재현율 : 0.6879
#
# 22 번째  theshold 값 :  0.41000000000000003
# 오차행렬
# [[194  63]
#  [ 44  97]]
# 정확도 : 0.7312
# 정밀도 : 0.6062
# 재현율 : 0.6879
#
# 23 번째  theshold 값 :  0.42
# 오차행렬
# [[196  61]
#  [ 46  95]]
# 정확도 : 0.7312
# 정밀도 : 0.6090
# 재현율 : 0.6738
#
# 24 번째  theshold 값 :  0.43
# 오차행렬
# [[201  56]
#  [ 47  94]]
# 정확도 : 0.7412
# 정밀도 : 0.6267
# 재현율 : 0.6667
#
# 25 번째  theshold 값 :  0.44
# 오차행렬
# [[202  55]
#  [ 49  92]]
# 정확도 : 0.7387
# 정밀도 : 0.6259
# 재현율 : 0.6525
#
# 26 번째  theshold 값 :  0.45
# 오차행렬
# [[204  53]
#  [ 49  92]]
# 정확도 : 0.7437
# 정밀도 : 0.6345
# 재현율 : 0.6525
#
# 27 번째  theshold 값 :  0.46
# 오차행렬
# [[207  50]
#  [ 49  92]]
# 정확도 : 0.7513
# 정밀도 : 0.6479
# 재현율 : 0.6525
#
# 28 번째  theshold 값 :  0.47000000000000003
# 오차행렬
# [[208  49]
#  [ 49  92]]
# 정확도 : 0.7538
# 정밀도 : 0.6525
# 재현율 : 0.6525
#
# 29 번째  theshold 값 :  0.48
# 오차행렬
# [[211  46]
#  [ 50  91]]
# 정확도 : 0.7588
# 정밀도 : 0.6642
# 재현율 : 0.6454
#
# 30 번째  theshold 값 :  0.49
# 오차행렬
# [[214  43]
#  [ 51  90]]
# 정확도 : 0.7638
# 정밀도 : 0.6767
# 재현율 : 0.6383
#
# 31 번째  theshold 값 :  0.5
# 오차행렬
# [[215  42]
#  [ 51  90]]
# 정확도 : 0.7663
# 정밀도 : 0.6818
# 재현율 : 0.6383

# %% [markdown]
# #### 결정트리 시각화

# %%
from sklearn.tree import export_graphviz

export_graphviz(tree_model, out_file="tree.dot", 
                class_names=df_index , 
                feature_names = df_index, 
                impurity=True, 
                filled=True)

# %%
import graphviz

# 위에서 생성된 tree.dot 파일을 Graphviz 읽어서 Jupyter Notebook상에서 시각화 
with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %% [markdown]
# #### GBM

# %%
from lightgbm import LGBMClassifier
lgbm_wrapper = LGBMClassifier(n_estimators=400)

# LightGBM도 XGBoost와 동일하게 조기 중단 수행 가능. 
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_resampled, y_resampled, early_stopping_rounds=100, eval_metric="logloss", 
                 eval_set=evals, verbose=True)
pred_proba = rf_clf.predict_proba(X_testt

y_hat = lgbm_wrapper.predict(X_test)

pred_proba_result = np.concatenate([pred_proba, y_hat.reshape(-1,1)], axis=1)
lgbm_wrapper_matrix = metrics.confusion_matrix(y_test, y_hat)
print(lgbm_wrapper_matrix)
lgbm_wrapper_report = metrics.classification_report(y_test, y_hat)
print(lgbm_wrapper_report)

from sklearn.preprocessing import Binarizer
binarizer = Binarizer(threshold=1.1)
# Binarizer의 threshold 값을 0.5로 설정
for i in range(19, 51):
    custom_threshold = i*0.01
    # predict_proba() 결과 값의 두 번째 컬럼, 즉 Positive 클래스의 컬럼 하나만 추출하여 Binarizer를 적용
    pred_proba_1 = pred_proba[:,1].reshape(-1,1)

    binarizer = Binarizer(threshold=custom_threshold).fit(pred_proba_1)
    custom_predict = binarizer.transform(pred_proba_1)
    print(i-19,'번째  theshold 값 : ', i*0.01)
    get_clf_eval(y_test, custom_predict)
    print()
# Out:
# [1]	valid_0's binary_logloss: 0.656935
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.628151
# [3]	valid_0's binary_logloss: 0.603668
# [4]	valid_0's binary_logloss: 0.584206
# [5]	valid_0's binary_logloss: 0.566878
# [6]	valid_0's binary_logloss: 0.553361
# [7]	valid_0's binary_logloss: 0.541262
# [8]	valid_0's binary_logloss: 0.532146
# [9]	valid_0's binary_logloss: 0.524072
# [10]	valid_0's binary_logloss: 0.517319
# [11]	valid_0's binary_logloss: 0.511703
# [12]	valid_0's binary_logloss: 0.507899
# [13]	valid_0's binary_logloss: 0.50506
# [14]	valid_0's binary_logloss: 0.502212
# [15]	valid_0's binary_logloss: 0.500177
# [16]	valid_0's binary_logloss: 0.49924
# [17]	valid_0's binary_logloss: 0.498221
# [18]	valid_0's binary_logloss: 0.49751
# [19]	valid_0's binary_logloss: 0.497227
# [20]	valid_0's binary_logloss: 0.496744
# [21]	valid_0's binary_logloss: 0.496311
# [22]	valid_0's binary_logloss: 0.496875
# [23]	valid_0's binary_logloss: 0.496896
# [24]	valid_0's binary_logloss: 0.497486
# [25]	valid_0's binary_logloss: 0.496906
# [26]	valid_0's binary_logloss: 0.499034
# [27]	valid_0's binary_logloss: 0.500876
# [28]	valid_0's binary_logloss: 0.501649
# [29]	valid_0's binary_logloss: 0.503386
# [30]	valid_0's binary_logloss: 0.503997
# [31]	valid_0's binary_logloss: 0.504168
# [32]	valid_0's binary_logloss: 0.504714
# [33]	valid_0's binary_logloss: 0.504877
# [34]	valid_0's binary_logloss: 0.505679
# [35]	valid_0's binary_logloss: 0.506527
# [36]	valid_0's binary_logloss: 0.507217
# [37]	valid_0's binary_logloss: 0.507641
# [38]	valid_0's binary_logloss: 0.508656
# [39]	valid_0's binary_logloss: 0.508489
# [40]	valid_0's binary_logloss: 0.50874
# [41]	valid_0's binary_logloss: 0.50848
# [42]	valid_0's binary_logloss: 0.510354
# [43]	valid_0's binary_logloss: 0.508404
# [44]	valid_0's binary_logloss: 0.507616
# [45]	valid_0's binary_logloss: 0.508877
# [46]	valid_0's binary_logloss: 0.509114
# [47]	valid_0's binary_logloss: 0.509764
# [48]	valid_0's binary_logloss: 0.511861
# [49]	valid_0's binary_logloss: 0.513319
# [50]	valid_0's binary_logloss: 0.514021
# [51]	valid_0's binary_logloss: 0.514436
# [52]	valid_0's binary_logloss: 0.515361
# [53]	valid_0's binary_logloss: 0.516399
# [54]	valid_0's binary_logloss: 0.516717
# [55]	valid_0's binary_logloss: 0.51751
# [56]	valid_0's binary_logloss: 0.517129
# [57]	valid_0's binary_logloss: 0.518471
# [58]	valid_0's binary_logloss: 0.518247
# [59]	valid_0's binary_logloss: 0.519362
# [60]	valid_0's binary_logloss: 0.519695
# [61]	valid_0's binary_logloss: 0.520341
# [62]	valid_0's binary_logloss: 0.520311
# [63]	valid_0's binary_logloss: 0.519553
# [64]	valid_0's binary_logloss: 0.519688
# [65]	valid_0's binary_logloss: 0.520611
# [66]	valid_0's binary_logloss: 0.521238
# [67]	valid_0's binary_logloss: 0.521179
# [68]	valid_0's binary_logloss: 0.522562
# [69]	valid_0's binary_logloss: 0.521975
# [70]	valid_0's binary_logloss: 0.52247
# [71]	valid_0's binary_logloss: 0.523009
# [72]	valid_0's binary_logloss: 0.523663
# [73]	valid_0's binary_logloss: 0.523301
# [74]	valid_0's binary_logloss: 0.523433
# [75]	valid_0's binary_logloss: 0.523479
# [76]	valid_0's binary_logloss: 0.524676
# [77]	valid_0's binary_logloss: 0.523915
# [78]	valid_0's binary_logloss: 0.524513
# [79]	valid_0's binary_logloss: 0.526309
# [80]	valid_0's binary_logloss: 0.527851
# [81]	valid_0's binary_logloss: 0.527534
# [82]	valid_0's binary_logloss: 0.527123
# [83]	valid_0's binary_logloss: 0.529154
# [84]	valid_0's binary_logloss: 0.529303
# [85]	valid_0's binary_logloss: 0.528927
# [86]	valid_0's binary_logloss: 0.529417
# [87]	valid_0's binary_logloss: 0.529986
# [88]	valid_0's binary_logloss: 0.529941
# [89]	valid_0's binary_logloss: 0.530599
# [90]	valid_0's binary_logloss: 0.531083
# [91]	valid_0's binary_logloss: 0.531183
# [92]	valid_0's binary_logloss: 0.531577
# [93]	valid_0's binary_logloss: 0.532187
# [94]	valid_0's binary_logloss: 0.532189
# [95]	valid_0's binary_logloss: 0.53256
# [96]	valid_0's binary_logloss: 0.533814
# [97]	valid_0's binary_logloss: 0.534757
# [98]	valid_0's binary_logloss: 0.534932
# [99]	valid_0's binary_logloss: 0.535639
# [100]	valid_0's binary_logloss: 0.536572
# [101]	valid_0's binary_logloss: 0.535211
# [102]	valid_0's binary_logloss: 0.536064
# [103]	valid_0's binary_logloss: 0.537239
# [104]	valid_0's binary_logloss: 0.537477
# [105]	valid_0's binary_logloss: 0.538104
# [106]	valid_0's binary_logloss: 0.538911
# [107]	valid_0's binary_logloss: 0.540889
# [108]	valid_0's binary_logloss: 0.541413
# [109]	valid_0's binary_logloss: 0.541807
# [110]	valid_0's binary_logloss: 0.542106
# [111]	valid_0's binary_logloss: 0.542242
# [112]	valid_0's binary_logloss: 0.542585
# [113]	valid_0's binary_logloss: 0.542423
# [114]	valid_0's binary_logloss: 0.542652
# [115]	valid_0's binary_logloss: 0.543249
# [116]	valid_0's binary_logloss: 0.542913
# [117]	valid_0's binary_logloss: 0.543571
# [118]	valid_0's binary_logloss: 0.544549
# [119]	valid_0's binary_logloss: 0.545077
# [120]	valid_0's binary_logloss: 0.545686
# [121]	valid_0's binary_logloss: 0.546287
# Early stopping, best iteration is:
# [21]	valid_0's binary_logloss: 0.496311
# [[227  30]
#  [ 51  90]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       257
#            1       0.75      0.64      0.69       141
#
#     accuracy                           0.80       398
#    macro avg       0.78      0.76      0.77       398
# weighted avg       0.79      0.80      0.79       398
#
# 0 번째  theshold 값 :  0.19
# 오차행렬
# [[133 124]
#  [ 29 112]]
# 정확도 : 0.6156
# 정밀도 : 0.4746
# 재현율 : 0.7943
#
# 1 번째  theshold 값 :  0.2
# 오차행렬
# [[134 123]
#  [ 30 111]]
# 정확도 : 0.6156
# 정밀도 : 0.4744
# 재현율 : 0.7872
#
# 2 번째  theshold 값 :  0.21
# 오차행렬
# [[135 122]
#  [ 31 110]]
# 정확도 : 0.6156
# 정밀도 : 0.4741
# 재현율 : 0.7801
#
# 3 번째  theshold 값 :  0.22
# 오차행렬
# [[138 119]
#  [ 32 109]]
# 정확도 : 0.6206
# 정밀도 : 0.4781
# 재현율 : 0.7730
#
# 4 번째  theshold 값 :  0.23
# 오차행렬
# [[144 113]
#  [ 32 109]]
# 정확도 : 0.6357
# 정밀도 : 0.4910
# 재현율 : 0.7730
#
# 5 번째  theshold 값 :  0.24
# 오차행렬
# [[147 110]
#  [ 35 106]]
# 정확도 : 0.6357
# 정밀도 : 0.4907
# 재현율 : 0.7518
#
# 6 번째  theshold 값 :  0.25
# 오차행렬
# [[148 109]
#  [ 35 106]]
# 정확도 : 0.6382
# 정밀도 : 0.4930
# 재현율 : 0.7518
#
# 7 번째  theshold 값 :  0.26
# 오차행렬
# [[153 104]
#  [ 36 105]]
# 정확도 : 0.6482
# 정밀도 : 0.5024
# 재현율 : 0.7447
#
# 8 번째  theshold 값 :  0.27
# 오차행렬
# [[155 102]
#  [ 37 104]]
# 정확도 : 0.6508
# 정밀도 : 0.5049
# 재현율 : 0.7376
#
# 9 번째  theshold 값 :  0.28
# 오차행렬
# [[156 101]
#  [ 38 103]]
# 정확도 : 0.6508
# 정밀도 : 0.5049
# 재현율 : 0.7305
#
# 10 번째  theshold 값 :  0.29
# 오차행렬
# [[157 100]
#  [ 38 103]]
# 정확도 : 0.6533
# 정밀도 : 0.5074
# 재현율 : 0.7305
#
# 11 번째  theshold 값 :  0.3
# 오차행렬
# [[159  98]
#  [ 38 103]]
# 정확도 : 0.6583
# 정밀도 : 0.5124
# 재현율 : 0.7305
#
# 12 번째  theshold 값 :  0.31
# 오차행렬
# [[164  93]
#  [ 38 103]]
# 정확도 : 0.6709
# 정밀도 : 0.5255
# 재현율 : 0.7305
#
# 13 번째  theshold 값 :  0.32
# 오차행렬
# [[166  91]
#  [ 38 103]]
# 정확도 : 0.6759
# 정밀도 : 0.5309
# 재현율 : 0.7305
#
# 14 번째  theshold 값 :  0.33
# 오차행렬
# [[171  86]
#  [ 39 102]]
# 정확도 : 0.6859
# 정밀도 : 0.5426
# 재현율 : 0.7234
#
# 15 번째  theshold 값 :  0.34
# 오차행렬
# [[173  84]
#  [ 39 102]]
# 정확도 : 0.6910
# 정밀도 : 0.5484
# 재현율 : 0.7234
#
# 16 번째  theshold 값 :  0.35000000000000003
# 오차행렬
# [[177  80]
#  [ 41 100]]
# 정확도 : 0.6960
# 정밀도 : 0.5556
# 재현율 : 0.7092
#
# 17 번째  theshold 값 :  0.36
# 오차행렬
# [[181  76]
#  [ 42  99]]
# 정확도 : 0.7035
# 정밀도 : 0.5657
# 재현율 : 0.7021
#
# 18 번째  theshold 값 :  0.37
# 오차행렬
# [[182  75]
#  [ 42  99]]
# 정확도 : 0.7060
# 정밀도 : 0.5690
# 재현율 : 0.7021
#
# 19 번째  theshold 값 :  0.38
# 오차행렬
# [[184  73]
#  [ 43  98]]
# 정확도 : 0.7085
# 정밀도 : 0.5731
# 재현율 : 0.6950
#
# 20 번째  theshold 값 :  0.39
# 오차행렬
# [[191  66]
#  [ 43  98]]
# 정확도 : 0.7261
# 정밀도 : 0.5976
# 재현율 : 0.6950
#
# 21 번째  theshold 값 :  0.4
# 오차행렬
# [[194  63]
#  [ 44  97]]
# 정확도 : 0.7312
# 정밀도 : 0.6062
# 재현율 : 0.6879
#
# 22 번째  theshold 값 :  0.41000000000000003
# 오차행렬
# [[194  63]
#  [ 44  97]]
# 정확도 : 0.7312
# 정밀도 : 0.6062
# 재현율 : 0.6879
#
# 23 번째  theshold 값 :  0.42
# 오차행렬
# [[196  61]
#  [ 46  95]]
# 정확도 : 0.7312
# 정밀도 : 0.6090
# 재현율 : 0.6738
#
# 24 번째  theshold 값 :  0.43
# 오차행렬
# [[201  56]
#  [ 47  94]]
# 정확도 : 0.7412
# 정밀도 : 0.6267
# 재현율 : 0.6667
#
# 25 번째  theshold 값 :  0.44
# 오차행렬
# [[202  55]
#  [ 49  92]]
# 정확도 : 0.7387
# 정밀도 : 0.6259
# 재현율 : 0.6525
#
# 26 번째  theshold 값 :  0.45
# 오차행렬
# [[204  53]
#  [ 49  92]]
# 정확도 : 0.7437
# 정밀도 : 0.6345
# 재현율 : 0.6525
#
# 27 번째  theshold 값 :  0.46
# 오차행렬
# [[207  50]
#  [ 49  92]]
# 정확도 : 0.7513
# 정밀도 : 0.6479
# 재현율 : 0.6525
#
# 28 번째  theshold 값 :  0.47000000000000003
# 오차행렬
# [[208  49]
#  [ 49  92]]
# 정확도 : 0.7538
# 정밀도 : 0.6525
# 재현율 : 0.6525
#
# 29 번째  theshold 값 :  0.48
# 오차행렬
# [[211  46]
#  [ 50  91]]
# 정확도 : 0.7588
# 정밀도 : 0.6642
# 재현율 : 0.6454
#
# 30 번째  theshold 값 :  0.49
# 오차행렬
# [[214  43]
#  [ 51  90]]
# 정확도 : 0.7638
# 정밀도 : 0.6767
# 재현율 : 0.6383
#
# 31 번째  theshold 값 :  0.5
# 오차행렬
# [[215  42]
#  [ 51  90]]
# 정확도 : 0.7663
# 정밀도 : 0.6818
# 재현율 : 0.6383

# %% [markdown]
# #### recall / precision
#
# - recall 은 대상물체를 빠뜨리지 않고 얼마나 잘 잡아내느냐
# - precision은 검출된 결과가 얼마나 정확한가

# %% [markdown]
# #### xgboost

# %%
import xgboost as xgb
from xgboost import plot_importance
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

dtrain = xgb.DMatrix(data=X_train , label=y_train)
dtest = xgb.DMatrix(data=X_test , label=y_test)
params = { 'max_depth':3,
           'eta': 0.1,
           'objective':'binary:logistic',
           'eval_metric':'logloss',
           'early_stoppings':100
        }
num_rounds = 400
# train 데이터 셋은 ‘train’ , evaluation(test) 데이터 셋은 ‘eval’ 로 명기합니다. 
wlist = [(dtrain,'train'),(dtest,'eval') ]
# 하이퍼 파라미터와 early stopping 파라미터를 train( ) 함수의 파라미터로 전달
xgb_model = xgb.train(params = params , dtrain=dtrain , num_boost_round=num_rounds , evals=wlist )
pred_probs = xgb_model.predict(dtest)

preds = [ 1 if x > 0.5 else 0 for x in pred_probs ]
def get_clf_eval(y_test , pred):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    roc_auc = roc_auc_score(y_test, pred)
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

get_clf_eval(y_test , preds)

# %% [markdown]
# #### Catboosting

# %%
from catboost import CatBoostClassifier
cat = CatBoostClassifier(iterations=15)

cat.fit(X_train, y_train)
y_hat = cat.predict(X_test)
cat_matrix = metrics.confusion_matrix(y_test, y_hat)
print(cat_matrix)
cat_report = metrics.classification_report(y_test, y_hat)
print(cat_report)

# %%
pip install catboost

# %%
from itertools import combinations
a = ['ChronicDiseases',"GraduateOrNot",  'FrequentFlyer','Employment Type', 'EverTravelledAbroad' ]
for i in range(len(a)):
    print(list(combinations(a,i)), end = ' ')

# %%
import pandas as pd
from numpy import mean, std
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import metrics
from imblearn.under_sampling import TomekLinks
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from imblearn.under_sampling import *
df = pd.read_csv('./TravelInsurancePrediction.csv')
df['ChronicDiseases'] = df['ChronicDiseases'].map({1: "Yes", 0: 'No'})
df['FrequentFlyer'] = df['FrequentFlyer'].map({'Yes': 1, 'No': 0})
df['EverTravelledAbroad'] = df['EverTravelledAbroad'].map({'Yes': 1, 'No': 0})
df["Employment Type"] = df["Employment Type"].map({"Government Sector" : 1, "Private Sector/Self Employed" : 0})
df['GraduateOrNot'] = df['GraduateOrNot'].map({'Yes': 1, 'No': 0})

ndf = pd.get_dummies(df[['Age', 'AnnualIncome', 'GraduateOrNot','ChronicDiseases',
          'FrequentFlyer', 'FamilyMembers', 'Employment Type',
          'EverTravelledAbroad']])

ndf['FrequentFlyer'] = df['FrequentFlyer']
ndf['TravelInsurance'] = df['TravelInsurance']
X = ndf[list(ndf.columns)[:-1]]
y = ndf[list(ndf.columns)[-1]]
# y = y.astype({'TravelInsurance': int})
# X = preprocessing.StandardScaler().fit(X).transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    random_state=10)

# %%
df = pd.read_csv('./TravelInsurancePrediction.csv')
df['ChronicDiseases'] = df['ChronicDiseases'].map({1: "Yes", 0: 'No'})
df['FrequentFlyer'] = df['FrequentFlyer'].map({'Yes': 1, 'No': 0})
# df['EverTravelledAbroad'] = df['EverTravelledAbroad'].map({'Yes': 1, 'No': 0})
# df["Employment Type"] = df["Employment Type"].map({"Government Sector" : 1, "Private Sector/Self Employed" : 0})
# df['GraduateOrNot'] = df['GraduateOrNot'].map({'Yes': 1, 'No': 0})
# 
ndf = pd.get_dummies(df[['ChronicDiseases', 'GraduateOrNot','Employment Type','EverTravelledAbroad']])

ndf1 = df[['Age', 'AnnualIncome', 'FrequentFlyer',
           'FamilyMembers',
           'TravelInsurance']]
ndf = pd.concat([ndf, ndf1], axis = 1)
# # ndf['TravelInsurance'] = df['TravelInsurance']
X = ndf[list(ndf.columns)[:-1]]
y = ndf[list(ndf.columns)[-1]]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    random_state=10)

# %%
ndf.head()
# Out:
#    ChronicDiseases_No  ChronicDiseases_Yes  GraduateOrNot_No  \
# 0                   0                    1                 0
# 1                   1                    0                 0
# 2                   0                    1                 0
# 3                   0                    1                 0
# 4                   0                    1                 0
#
#    GraduateOrNot_Yes  Employment Type_Government Sector  \
# 0                  1                                  1
# 1                  1                                  0
# 2                  1                                  0
# 3                  1                                  0
# 4                  1                                  0
#
#    Employment Type_Private Sector/Self Employed  EverTravelledAbroad_No  \
# 0                                             0                       1
# 1                                             1                       1
# 2                                             1                       1
# 3                                             1                       1
# 4                                             1                       1
#
#    EverTravelledAbroad_Yes  Age  AnnualIncome  FrequentFlyer  FamilyMembers  \
# 0                        0   31        400000              0              6
# 1                        0   31       1250000              0              7
# 2                        0   34        500000              0              4
# 3                        0   28        700000              0              3
# 4                        0   28        700000              1              8
#
#    TravelInsurance
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0

# %%
X_train.head()
# Out:
#       ChronicDiseases  GraduateOrNot  EverTravelledAbroad  \
# 1857                0              1                    0
# 685                 1              1                    1
# 1970                0              1                    0
# 1885                0              1                    0
# 895                 0              1                    1
#
#       Employment Type_Government Sector  \
# 1857                                  1
# 685                                   0
# 1970                                  0
# 1885                                  1
# 895                                   0
#
#       Employment Type_Private Sector/Self Employed  Age  AnnualIncome  \
# 1857                                             0   27        900000
# 685                                              1   34       1500000
# 1970                                             1   29        500000
# 1885                                             0   35       1100000
# 895                                              1   28        600000
#
#       FrequentFlyer  FamilyMembers
# 1857              0              4
# 685               1              4
# 1970              0              4
# 1885              0              3
# 895               0              5

# %%
# 가장 높은 점수 결정 나무, depth 5
from imblearn.over_sampling import SMOTENC
smote_nc = SMOTENC(categorical_features=[0, 2], random_state=0)
X_resampled, y_resampled = smote_nc.fit_resample(X_train, y_train)
print(X_resampled.shape)
# Out:
# (2040, 12)

# %%
# 가공전 , 6/57
from sklearn import tree
# sklearn 라이브러리에서 Decision Tree 분류 모형 가져오기

# 모형 객체 생성 (criterion='entropy' 적용)
tree_model = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3)

# tree_model.fit(X_resampled, y_resampled)
tree_model.fit(X_train, y_train)
y_hat = tree_model.predict(X_test)
tree_matrix = metrics.confusion_matrix(y_test, y_hat)
print(tree_matrix)
tree_report = metrics.classification_report(y_test, y_hat)
print(tree_report)
# Out:
# [[249   8]
#  [ 59  82]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88       257
#            1       0.91      0.58      0.71       141
#
#     accuracy                           0.83       398
#    macro avg       0.86      0.78      0.80       398
# weighted avg       0.84      0.83      0.82       398

# %%
from lightgbm import LGBMClassifier
lgbm_wrapper = LGBMClassifier(n_estimators=400)

# LightGBM도 XGBoost와 동일하게 조기 중단 수행 가능. 
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_resampled, y_resampled, early_stopping_rounds=100, eval_metric="logloss", 
                 eval_set=evals, verbose=True)
y_hat = lgbm_wrapper.predict(X_test)
lgbm_wrapper_matrix = metrics.confusion_matrix(y_test, y_hat)
print(lgbm_wrapper_matrix)
lgbm_wrapper_report = metrics.classification_report(y_test, y_hat)
print(lgbm_wrapper_report)
# Out:
# [1]	valid_0's binary_logloss: 0.655608
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.626449
# [3]	valid_0's binary_logloss: 0.602122
# [4]	valid_0's binary_logloss: 0.583049
# [5]	valid_0's binary_logloss: 0.566604
# [6]	valid_0's binary_logloss: 0.553558
# [7]	valid_0's binary_logloss: 0.542497
# [8]	valid_0's binary_logloss: 0.532616
# [9]	valid_0's binary_logloss: 0.524257
# [10]	valid_0's binary_logloss: 0.517932
# [11]	valid_0's binary_logloss: 0.51247
# [12]	valid_0's binary_logloss: 0.508256
# [13]	valid_0's binary_logloss: 0.502065
# [14]	valid_0's binary_logloss: 0.497786
# [15]	valid_0's binary_logloss: 0.495944
# [16]	valid_0's binary_logloss: 0.493143
# [17]	valid_0's binary_logloss: 0.492166
# [18]	valid_0's binary_logloss: 0.490142
# [19]	valid_0's binary_logloss: 0.490124
# [20]	valid_0's binary_logloss: 0.488984
# [21]	valid_0's binary_logloss: 0.48892
# [22]	valid_0's binary_logloss: 0.48871
# [23]	valid_0's binary_logloss: 0.488385
# [24]	valid_0's binary_logloss: 0.48652
# [25]	valid_0's binary_logloss: 0.4865
# [26]	valid_0's binary_logloss: 0.487178
# [27]	valid_0's binary_logloss: 0.487489
# [28]	valid_0's binary_logloss: 0.487279
# [29]	valid_0's binary_logloss: 0.487164
# [30]	valid_0's binary_logloss: 0.487226
# [31]	valid_0's binary_logloss: 0.488458
# [32]	valid_0's binary_logloss: 0.487964
# [33]	valid_0's binary_logloss: 0.487734
# [34]	valid_0's binary_logloss: 0.488118
# [35]	valid_0's binary_logloss: 0.488912
# [36]	valid_0's binary_logloss: 0.488873
# [37]	valid_0's binary_logloss: 0.48827
# [38]	valid_0's binary_logloss: 0.488934
# [39]	valid_0's binary_logloss: 0.487761
# [40]	valid_0's binary_logloss: 0.487161
# [41]	valid_0's binary_logloss: 0.489253
# [42]	valid_0's binary_logloss: 0.490052
# [43]	valid_0's binary_logloss: 0.491383
# [44]	valid_0's binary_logloss: 0.491203
# [45]	valid_0's binary_logloss: 0.491702
# [46]	valid_0's binary_logloss: 0.491305
# [47]	valid_0's binary_logloss: 0.490837
# [48]	valid_0's binary_logloss: 0.49142
# [49]	valid_0's binary_logloss: 0.491738
# [50]	valid_0's binary_logloss: 0.492648
# [51]	valid_0's binary_logloss: 0.494621
# [52]	valid_0's binary_logloss: 0.495675
# [53]	valid_0's binary_logloss: 0.495922
# [54]	valid_0's binary_logloss: 0.496794
# [55]	valid_0's binary_logloss: 0.496915
# [56]	valid_0's binary_logloss: 0.498876
# [57]	valid_0's binary_logloss: 0.500021
# [58]	valid_0's binary_logloss: 0.50004
# [59]	valid_0's binary_logloss: 0.501067
# [60]	valid_0's binary_logloss: 0.503521
# [61]	valid_0's binary_logloss: 0.503703
# [62]	valid_0's binary_logloss: 0.503625
# [63]	valid_0's binary_logloss: 0.503569
# [64]	valid_0's binary_logloss: 0.504118
# [65]	valid_0's binary_logloss: 0.503383
# [66]	valid_0's binary_logloss: 0.503695
# [67]	valid_0's binary_logloss: 0.50448
# [68]	valid_0's binary_logloss: 0.503624
# [69]	valid_0's binary_logloss: 0.50455
# [70]	valid_0's binary_logloss: 0.504848
# [71]	valid_0's binary_logloss: 0.505876
# [72]	valid_0's binary_logloss: 0.507634
# [73]	valid_0's binary_logloss: 0.507404
# [74]	valid_0's binary_logloss: 0.508883
# [75]	valid_0's binary_logloss: 0.508836
# [76]	valid_0's binary_logloss: 0.509837
# [77]	valid_0's binary_logloss: 0.510497
# [78]	valid_0's binary_logloss: 0.51273
# [79]	valid_0's binary_logloss: 0.512687
# [80]	valid_0's binary_logloss: 0.513935
# [81]	valid_0's binary_logloss: 0.515063
# [82]	valid_0's binary_logloss: 0.515932
# [83]	valid_0's binary_logloss: 0.516268
# [84]	valid_0's binary_logloss: 0.515826
# [85]	valid_0's binary_logloss: 0.516183
# [86]	valid_0's binary_logloss: 0.51641
# [87]	valid_0's binary_logloss: 0.517211
# [88]	valid_0's binary_logloss: 0.51814
# [89]	valid_0's binary_logloss: 0.518098
# [90]	valid_0's binary_logloss: 0.518463
# [91]	valid_0's binary_logloss: 0.518803
# [92]	valid_0's binary_logloss: 0.519783
# [93]	valid_0's binary_logloss: 0.520031
# [94]	valid_0's binary_logloss: 0.520673
# [95]	valid_0's binary_logloss: 0.521073
# [96]	valid_0's binary_logloss: 0.521903
# [97]	valid_0's binary_logloss: 0.522375
# [98]	valid_0's binary_logloss: 0.522032
# [99]	valid_0's binary_logloss: 0.522105
# [100]	valid_0's binary_logloss: 0.522424
# [101]	valid_0's binary_logloss: 0.523471
# [102]	valid_0's binary_logloss: 0.523454
# [103]	valid_0's binary_logloss: 0.523027
# [104]	valid_0's binary_logloss: 0.522891
# [105]	valid_0's binary_logloss: 0.523396
# [106]	valid_0's binary_logloss: 0.524279
# [107]	valid_0's binary_logloss: 0.524193
# [108]	valid_0's binary_logloss: 0.525212
# [109]	valid_0's binary_logloss: 0.524927
# [110]	valid_0's binary_logloss: 0.525627
# [111]	valid_0's binary_logloss: 0.525932
# [112]	valid_0's binary_logloss: 0.5268
# [113]	valid_0's binary_logloss: 0.527159
# [114]	valid_0's binary_logloss: 0.52769
# [115]	valid_0's binary_logloss: 0.527804
# [116]	valid_0's binary_logloss: 0.527982
# [117]	valid_0's binary_logloss: 0.528484
# [118]	valid_0's binary_logloss: 0.528669
# [119]	valid_0's binary_logloss: 0.52925
# [120]	valid_0's binary_logloss: 0.529744
# [121]	valid_0's binary_logloss: 0.529693
# [122]	valid_0's binary_logloss: 0.53035
# [123]	valid_0's binary_logloss: 0.531315
# [124]	valid_0's binary_logloss: 0.532013
# [125]	valid_0's binary_logloss: 0.532337
# Early stopping, best iteration is:
# [25]	valid_0's binary_logloss: 0.4865
# [[231  26]
#  [ 57  84]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       257
#            1       0.76      0.60      0.67       141
#
#     accuracy                           0.79       398
#    macro avg       0.78      0.75      0.76       398
# weighted avg       0.79      0.79      0.78       398

# %%
#랜덤 포레스트는 오버샘플링이 좋음
# 오버 언더 조합도 낫베드( 데이터 개수가 늘어날 수록 좋음)
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_resampled , y_resampled)
# rf_clf.fit(X_train , y_train)
y_hat = rf_clf.predict(X_test)
rf_clf_matrix = metrics.confusion_matrix(y_test, y_hat)
print(rf_clf_matrix)
rf_clf_report = metrics.classification_report(y_test, y_hat)
print(rf_clf_report)
# Out:
# [[217  40]
#  [ 50  91]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83       257
#            1       0.69      0.65      0.67       141
#
#     accuracy                           0.77       398
#    macro avg       0.75      0.74      0.75       398
# weighted avg       0.77      0.77      0.77       398
