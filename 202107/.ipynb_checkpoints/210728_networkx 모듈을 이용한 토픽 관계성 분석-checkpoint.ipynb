# %% [markdown]
# ### networkx 기본

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import re

# %%
graph = nx.Graph()
df=pd.DataFrame({'from' : ['a', 'b', 'c', 'a', 'd', 'e'], 
                 'to' : ['d', 'a', 'e', 'c', 'a', 'e'],
                'weight' : [1, 2, 3, 4, 5, 6]})
print(df)
gra = nx.from_pandas_edgelist(df, 'from', 'to', create_using = nx.DiGraph)
nx.draw(gra, with_labels = True)
plt.show()
# Out:
#   from to  weight
# 0    a  d       1
# 1    b  a       2
# 2    c  e       3
# 3    a  c       4
# 4    d  a       5
# 5    e  e       6

# %%
# 연습
#graph.add_nodes_from((1,2,3,4,5))
# graph.add_edges_from([(1,2),(1,3),(1,4),(3,5)])
# nx.draw(graph, with_labels=True)
# plt.show()

# %% [markdown]
# ### 전국 공원리뷰를 이용한 네트워크 분석

# %%
f = open('c:/pydata/korpark10.txt', 'r', encoding = 'utf-8')
txt_data = f.readlines() # read 는 전체 파일을 메모리 하나의 공간에 넣는것
# readlines는 전체 파일을 메모리에 줄단위로 공간에 넣는다
# readline은 한줄만 가져온다
f.close()
txt_data[:5]
# Out:
# ['.세상에서 가장 크고 오래된 나무들이 사는곳 자유의 여신상보다 크고 2500년된 나무도 있고욬ㅋㅋㅋ크기가 어마어마한데 사진으로는 다 담기지도 않는것 😱강아지들이랑 가기도 좋은 국립공원중 하나에요☺️ .(다만 펫이 안되는곳도 있으니 미리 참고)단점은 사람이 너무 많음 🤣 . .#sequoianationalpark #🌲 #🐾\n',
#  '\n',
#  '.#일출 #빛 에 물든 #국립공원 연안 경비정...#벤로코리아#benrokorea#소매물도#여행#여행에미치다#바다#하늘 #풍경#풍경사진#야경#등산#백패킹#소니#소니이미지갤러리#스냅#스냅사진#감성#감성사진#a7r3#sonyimages#ig_asia#ig_korea#longexposures#nightview#sonyalpha#ig_color\n',
#  '\n',
#  'Mt. Bukhansan National Park아름다운 우리강산 - MangyongdaeBeautiful Korea#북한산. #만경대. #일출. #하늘빛. #가을아침. #국립공원. #산스타그램. #Photography. #NationalPark.#Travel. #nature. #mountainView. #sunsetSky. #SunriseSky. #nightscape. #seoul. #KoreanLandscape. #OlympusEM1. #PhotoStargram.\n']

# %% [markdown]
# ### 정규식 표현

# %%
from konlpy.tag import Okt
from tqdm import tqdm
okt = Okt()

dataset = []
for txt in tqdm(txt_data):
    nons =(okt.nouns(re.sub('[^ㄱ-ㅣ가-힣a-zA-Z ]\s',"",txt)))
    if len(nons) >= 1:
        dataset.append(nons)
print(dataset[:5])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1966/1966 [00:09<00:00, 205.50it/s]
# [['세상', '가장', '나무', '곳', '자유', '여신', '나무', '있고욬', '크기', '사진', '강아지', '가기', '국립공원', '하나', '다만', '펫', '곳도', '미리', '참고', '단점', '사람'], ['물든', '연안', '경비정', '소매물도', '여행', '여행', '바다', '하늘', '풍경사진', '야경', '등산', '패킹', '소니', '소니', '이미지', '갤러리', '스냅', '스냅', '사진', '감성', '감성', '사진'], ['우리', '강산', '북한', '산', '만경대', '일출', '하늘빛', '가을', '아침', '국립공원', '산', '스타', '그램'], ['인증'], ['사진', '뭘', '찌', '길잡이', '사진', '운전', '승엽', '어린이', '용렬', '동상', '고생', '다음', '또', '출동', '쟈', '설악산', '국립공원', '토', '폭포', '별', '소년', '길', '릿', '지산', '행', '암릉산행', '지산', '행', '토', '왕골', '토폭', '상단', '봉', '등산', '스타', '그램', '산', '스타', '그램', '마운트', '립', '하이킹']]

# %%
from apyori import apriori

# %%
support_res = (list(apriori(dataset, min_support = 0.05)))

# %%
df1 = pd.DataFrame(support_res)
df1
# Out:
#              items   support  \
# 0              (것)  0.060241
# 1             (계곡)  0.069880
# 2              (곳)  0.085542
# 3           (국립공원)  0.342169
# 4             (그램)  0.066265
# 5              (길)  0.060241
# 6              (나)  0.057831
# 7              (날)  0.050602
# 8             (사진)  0.083133
# 9              (산)  0.100000
# 10           (설악산)  0.051807
# 11             (수)  0.103614
# 12            (스타)  0.060241
# 13            (시간)  0.055422
# 14            (여름)  0.073494
# 15            (여행)  0.114458
# 16            (오늘)  0.077108
# 17            (우리)  0.060241
# 18            (자연)  0.053012
# 19            (하루)  0.069880
# 20            (휴가)  0.080723
# 21      (그램, 국립공원)  0.053012
# 22       (국립공원, 산)  0.067470
# 23      (스타, 국립공원)  0.050602
# 24      (국립공원, 여행)  0.075904
# 25        (그램, 스타)  0.060241
# 26  (그램, 스타, 국립공원)  0.050602
#
#                                    ordered_statistics
# 0              [((), (것), 0.060240963855421686, 1.0)]
# 1              [((), (계곡), 0.06987951807228916, 1.0)]
# 2                [((), (곳), 0.0855421686746988, 1.0)]
# 3             [((), (국립공원), 0.3421686746987952, 1.0)]
# 4              [((), (그램), 0.06626506024096386, 1.0)]
# 5              [((), (길), 0.060240963855421686, 1.0)]
# 6               [((), (나), 0.05783132530120482, 1.0)]
# 7               [((), (날), 0.05060240963855422, 1.0)]
# 8              [((), (사진), 0.08313253012048193, 1.0)]
# 9                               [((), (산), 0.1, 1.0)]
# 10           [((), (설악산), 0.051807228915662654, 1.0)]
# 11              [((), (수), 0.10361445783132531, 1.0)]
# 12            [((), (스타), 0.060240963855421686, 1.0)]
# 13             [((), (시간), 0.05542168674698795, 1.0)]
# 14             [((), (여름), 0.07349397590361446, 1.0)]
# 15              [((), (여행), 0.1144578313253012, 1.0)]
# 16             [((), (오늘), 0.07710843373493977, 1.0)]
# 17            [((), (우리), 0.060240963855421686, 1.0)]
# 18             [((), (자연), 0.05301204819277108, 1.0)]
# 19             [((), (하루), 0.06987951807228916, 1.0)]
# 20             [((), (휴가), 0.08072289156626505, 1.0)]
# 21  [((), (그램, 국립공원), 0.05301204819277108, 1.0), (...
# 22  [((), (국립공원, 산), 0.06746987951807229, 1.0), ((...
# 23  [((), (스타, 국립공원), 0.05060240963855422, 1.0), (...
# 24  [((), (국립공원, 여행), 0.07590361445783132, 1.0), (...
# 25  [((), (그램, 스타), 0.060240963855421686, 1.0), ((...
# 26  [((), (그램, 스타, 국립공원), 0.05060240963855422, 1.0...

# %%
df1['length'] = df1['items'].apply(lambda x: len(x))
df1
# Out:
#              items   support  \
# 0              (것)  0.060241
# 1             (계곡)  0.069880
# 2              (곳)  0.085542
# 3           (국립공원)  0.342169
# 4             (그램)  0.066265
# 5              (길)  0.060241
# 6              (나)  0.057831
# 7              (날)  0.050602
# 8             (사진)  0.083133
# 9              (산)  0.100000
# 10           (설악산)  0.051807
# 11             (수)  0.103614
# 12            (스타)  0.060241
# 13            (시간)  0.055422
# 14            (여름)  0.073494
# 15            (여행)  0.114458
# 16            (오늘)  0.077108
# 17            (우리)  0.060241
# 18            (자연)  0.053012
# 19            (하루)  0.069880
# 20            (휴가)  0.080723
# 21      (그램, 국립공원)  0.053012
# 22       (국립공원, 산)  0.067470
# 23      (스타, 국립공원)  0.050602
# 24      (국립공원, 여행)  0.075904
# 25        (그램, 스타)  0.060241
# 26  (그램, 스타, 국립공원)  0.050602
#
#                                    ordered_statistics  length
# 0              [((), (것), 0.060240963855421686, 1.0)]       1
# 1              [((), (계곡), 0.06987951807228916, 1.0)]       1
# 2                [((), (곳), 0.0855421686746988, 1.0)]       1
# 3             [((), (국립공원), 0.3421686746987952, 1.0)]       1
# 4              [((), (그램), 0.06626506024096386, 1.0)]       1
# 5              [((), (길), 0.060240963855421686, 1.0)]       1
# 6               [((), (나), 0.05783132530120482, 1.0)]       1
# 7               [((), (날), 0.05060240963855422, 1.0)]       1
# 8              [((), (사진), 0.08313253012048193, 1.0)]       1
# 9                               [((), (산), 0.1, 1.0)]       1
# 10           [((), (설악산), 0.051807228915662654, 1.0)]       1
# 11              [((), (수), 0.10361445783132531, 1.0)]       1
# 12            [((), (스타), 0.060240963855421686, 1.0)]       1
# 13             [((), (시간), 0.05542168674698795, 1.0)]       1
# 14             [((), (여름), 0.07349397590361446, 1.0)]       1
# 15              [((), (여행), 0.1144578313253012, 1.0)]       1
# 16             [((), (오늘), 0.07710843373493977, 1.0)]       1
# 17            [((), (우리), 0.060240963855421686, 1.0)]       1
# 18             [((), (자연), 0.05301204819277108, 1.0)]       1
# 19             [((), (하루), 0.06987951807228916, 1.0)]       1
# 20             [((), (휴가), 0.08072289156626505, 1.0)]       1
# 21  [((), (그램, 국립공원), 0.05301204819277108, 1.0), (...       2
# 22  [((), (국립공원, 산), 0.06746987951807229, 1.0), ((...       2
# 23  [((), (스타, 국립공원), 0.05060240963855422, 1.0), (...       2
# 24  [((), (국립공원, 여행), 0.07590361445783132, 1.0), (...       2
# 25  [((), (그램, 스타), 0.060240963855421686, 1.0), ((...       2
# 26  [((), (그램, 스타, 국립공원), 0.05060240963855422, 1.0...       3

# %%
df = df1[(df1['lenth']==2)&(df1['support']>=)]
