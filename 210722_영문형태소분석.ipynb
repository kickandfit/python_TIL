# %%
#!pip install nltk

# %%
from nltk.tokenize import RegexpTokenizer  # 정규표현식 문장에 적용
from nltk import Text
import matplotlib.pyplot as plt

# %% [markdown]
# ### 텍스트 파일 읽고쓰기
# #### [파일 열고 닫기]
# - 파일 열기: f=open("파일경로와 이름", "파일 열기 모드")
# - 파일 닫기: f.close()
# #### [읽어오는 방법]
# - read(): 전체 데이터 읽어오기
# - readline(): 한줄단위 읽어오기
# - readlines(): 줄단위 요소를 리스트 형태로 읽어오기
# #### [열기 모드]
# - r : 읽기모드-파일을 읽기만 할때 사용(읽기전용)
# - w : 쓰기모드-파일을 새로 생성해 내용을 쓸 때 사용
# - a : 추가모드-기존 파일의 마지막에 내용을 추가할때 사용

# %%
f=open('c:/pydata/test.txt', "r")
txt=f.read()      
print(txt)
f.close()
# Out:
# n land And now I understand What you tried to say to me How you suffered for yo
# you suffered for your sanity How you tried to set them free They would not list
# g hand And now I understand What you tried to say to me How you suffered for yo
# you suffered for your sanity How you tried to set them free They would not list
# snow And now I think I know What you tried to say to me How you suffered for yo
# you suffered for your sanity How you tried to set them free They would not list

# %%
plt.rcParams["figure.figsize"]=(14, 5)
retok=RegexpTokenizer("[\w]+")   # [a-zA-Z0-9_] 영문자(대소문자)와 숫자를 제외한 나머지 글자 제거
txts=Text(retok.tokenize(txt))   # Text 클래스: 문석 분석용 클래스, 토큰열 입력 생성
print(type(txts))
# Out:
# <class 'nltk.text.Text'>

# %%
plt.title('NLTK Test')
txts.plot()        # 각 단어(토큰)의 사용 빈도를 그래프로 표현(Text 클래스가 제공)
plt.show()

# %%
txts.dispersion_plot(['you', 'for', 'set', 'free'])   # 단어가 사용된 위치를 시각화

# %%
import nltk
nltk.download('book', quiet=True)
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
print(nltk.corpus.gutenberg.fileids())
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
emma_raw = nltk.corpus.gutenberg.raw("austen-emma.txt")
print(emma_raw[:1302])
print(emma_raw[:10])
# Out:
# [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.
#
# She was the youngest of the two daughters of a most affectionate,
# indulgent father; and had, in consequence of her sister's marriage,
# been mistress of his house from a very early period.  Her mother
# had died too long ago for her to have more than an indistinct
# remembrance of her caresses; and her place had been supplied
# by an excellent woman as governess, who had fallen little short
# of a mother in affection.
#
# Sixteen years had Miss Taylor been in Mr. Woodhouse's family,
# less as a governess than a friend, very fond of both daughters,
# but particularly of Emma.  Between _them_ it was more the intimacy
# ...

# %%
# Text 클래스: 문석 분석용 클래스, 토큰열 입력 생성
retok=RegexpTokenizer("[\w]+")
print(Text(retok.tokenize((emma_raw[50:100]))))
# Out:
# <Text: Emma Woodhouse handsome clever and rich with a...>

# %%
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize

# %%
text=emma_raw[50:100]
tag_list=pos_tag(word_tokenize(text))
print(tag_list)
# Out:
# [('Emma', 'NNP'), ('Woodhouse', 'NNP'), (',', ','), ('handsome', 'NN'), (',', ','), ('clever', 'NN'), (',', ','), ('and', 'CC'), ('rich', 'JJ'), (',', ','), ('with', 'IN'), ('a', 'DT')]

# %%
nouns_list=[t[0] for t in tag_list if t[1]=='NNP' or t[1]=='NN']
print(nouns_list)
# Out:
# ['Emma', 'Woodhouse', 'handsome', 'clever']
