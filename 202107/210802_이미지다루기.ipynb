# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#cv2.imread(), 흑백 이미지 로드
image = cv2.imread('c:/pydata/plane.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image) #imshow 이미지 볼때

# %%
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape #결과 : 이미지 해상도 3600 X 2270
# Out:
# (2270, 3600)

# %%
# 가장 첫번째 픽셀의 값(펙셀 강도) : 강도 - 검정(0)~흰색(255)
image[0,0]
# Out:
# 140

# %%
#imread, 컬러 이미지 로드

image_bgr = cv2.imread('c:/pydata/plane.jpg', cv2.IMREAD_COLOR)
plt.imshow(image_bgr)
plt.show()
