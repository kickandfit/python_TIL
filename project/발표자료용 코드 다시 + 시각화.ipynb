# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\programdata\miniconda3\envs\multi\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\programdata\miniconda3\envs\multi\lib\site-packages (from imblearn) (0.8.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\miniconda3\envs\multi\lib\site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\miniconda3\envs\multi\lib\site-packages (from imbalanced-learn->imblearn) (1.7.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\miniconda3\envs\multi\lib\site-packages (from imbalanced-learn->imblearn) (1.21.1)
# Requirement already satisfied: scikit-learn>=0.24 in c:\programdata\miniconda3\envs\multi\lib\site-packages (from imbalanced-learn->imblearn) (0.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\miniconda3\envs\multi\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.2.0)

# %%
import pandas as pd
from sklearn import tree
from sklearn.preprocessing import Binarizer
from sklearn.metrics import accuracy_score, precision_score,classification_report, recall_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.ensemble import BalancedBaggingClassifier
from sklearn.model_selection import train_test_split, cross_val_score

df = pd.read_csv('./TravelInsurancePrediction.csv')
df['FrequentFlyer'] = df['FrequentFlyer'].map({'Yes': 1, 'No': 0})
df['EverTravelledAbroad'] = df['EverTravelledAbroad'].map({'Yes': 1, 'No': 0})
df["Employment Type"] = df["Employment Type"].map({"Government Sector" : 1, "Private Sector/Self Employed" : 0})
df['GraduateOrNot'] = df['GraduateOrNot'].map({'Yes': 1, 'No': 0})

# df = df.drop(["GraduateOrNot"] , axis=1)
df_index = ['Age', 'AnnualIncome', 'ChronicDiseases',"GraduateOrNot", 
          'FrequentFlyer', 'FamilyMembers', 'Employment Type',
          'EverTravelledAbroad']
df_label_index = ['TravelInsurance']
ndf = df[['Age', 'AnnualIncome', 'ChronicDiseases', 'GraduateOrNot',
          'FrequentFlyer', 'FamilyMembers', 'Employment Type',
          'EverTravelledAbroad', 'TravelInsurance']]
X = ndf[list(ndf.columns)[:-1]]
y = ndf[list(ndf.columns)[-1]]
# y = y.astype({'TravelInsurance': int})
# X = preprocessing.StandardScaler().fit(X).transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                    random_state=10)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from imblearn.over_sampling import SMOTENC ,SMOTEN
from imblearn.combine import *
from imblearn.under_sampling import *
from imblearn.over_sampling import *
from sklearn.tree import DecisionTreeClassifier
from imblearn.ensemble import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

                #언더샘플링
sample_list = {'enn' : EditedNearestNeighbours(), 
               'rus' : RandomUnderSampler(random_state=0),
              'nm1' : NearMiss(version=1),
               'renn' : RepeatedEditedNearestNeighbours(),
              'allknn' : AllKNN(), 
               'cnn' : CondensedNearestNeighbour(random_state=0),
              'oss' : OneSidedSelection(random_state=0),
               'ncr' : NeighbourhoodCleaningRule(),
              'iht' : InstanceHardnessThreshold(random_state=0,estimator=LogisticRegression(solver='lbfgs', multi_class='auto')),
                #오버샘플링
               'smote_nc' :  SMOTENC(categorical_features=[0, 2], random_state=0),
               'smote' : SMOTEN(random_state=0),
                #언더 오버 조합
               'smote_enn' : SMOTEENN(random_state=0),
               'smote_tomek' : SMOTETomek(random_state=0)
              }

model_list = {'Decisiontree' : tree.DecisionTreeClassifier(criterion='entropy', max_depth=5),
             'BalancedBagging' : BalancedBaggingClassifier(base_estimator=DecisionTreeClassifier(),
                                sampling_strategy='auto',
                                replacement=False,
                                random_state=0),
             'BalancedRandomForest': BalancedRandomForestClassifier(n_estimators=100, random_state=0),
             'EasyEnsemble' : EasyEnsembleClassifier(random_state=0),
             'RandomForest': RandomForestClassifier(random_state=0),
             }

def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    report = classification_report(y_test, pred)
    print('오차행렬')
    print()
    print(confusion)
    print()
    print('report')
    print()
    print(report)
    print()
    print('정리')
    print()
    print('정확도 : {:.4f}\n정밀도 : {:.4f}\n재현율 : {:.4f}'.format(accuracy, precision, recall))

# %%
f1_list={}
    
for under in sample_list:
    X_resampled, y_resampled  = sample_list[under].fit_resample(X_train, y_train)
    for model in model_list:
        model_ = model_list[model]
        model_.fit(X_resampled, y_resampled)
        y_hat = model_.predict(X_test)
        
        print('샘플링 방법 : ',under)
        print()
        print(model,'모델')
        get_clf_eval(y_test, y_hat)
        
        f1=f1_score(y_test, y_hat,  average='macro')
        name=str(under)+" "+str(model_).split("(")[0]
        f1_list[name]=f1
        
print(f1_list)
# Out:
# 샘플링 방법 :  enn
#
# Decisiontree 모델
# 오차행렬
#
# [[191  66]
#  [ 46  95]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       257
#            1       0.59      0.67      0.63       141
#
#     accuracy                           0.72       398
#    macro avg       0.70      0.71      0.70       398
# weighted avg       0.73      0.72      0.72       398
#
#
# 정리
#
# 정확도 : 0.7186
# 정밀도 : 0.5901
# 재현율 : 0.6738
# 샘플링 방법 :  enn
#
# BalancedBagging 모델
# 오차행렬
#
# [[159  98]
#  [ 40 101]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.62      0.70       257
#            1       0.51      0.72      0.59       141
#
#     accuracy                           0.65       398
#    macro avg       0.65      0.67      0.65       398
# weighted avg       0.70      0.65      0.66       398
#
#
# 정리
#
# 정확도 : 0.6533
# 정밀도 : 0.5075
# 재현율 : 0.7163
# 샘플링 방법 :  enn
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[162  95]
#  [ 37 104]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.63      0.71       257
#            1       0.52      0.74      0.61       141
#
#     accuracy                           0.67       398
#    macro avg       0.67      0.68      0.66       398
# weighted avg       0.71      0.67      0.68       398
#
#
# 정리
#
# 정확도 : 0.6683
# 정밀도 : 0.5226
# 재현율 : 0.7376
# 샘플링 방법 :  enn
#
# EasyEnsemble 모델
# 오차행렬
#
# [[208  49]
#  [ 49  92]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       257
#            1       0.65      0.65      0.65       141
#
#     accuracy                           0.75       398
#    macro avg       0.73      0.73      0.73       398
# weighted avg       0.75      0.75      0.75       398
#
#
# 정리
#
# 정확도 : 0.7538
# 정밀도 : 0.6525
# 재현율 : 0.6525
# 샘플링 방법 :  enn
#
# RandomForest 모델
# 오차행렬
#
# [[157 100]
#  [ 36 105]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.61      0.70       257
#            1       0.51      0.74      0.61       141
#
#     accuracy                           0.66       398
#    macro avg       0.66      0.68      0.65       398
# weighted avg       0.71      0.66      0.67       398
#
#
# 정리
#
# 정확도 : 0.6583
# 정밀도 : 0.5122
# 재현율 : 0.7447
# 샘플링 방법 :  rus
#
# Decisiontree 모델
# 오차행렬
#
# [[248   9]
#  [ 59  82]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88       257
#            1       0.90      0.58      0.71       141
#
#     accuracy                           0.83       398
#    macro avg       0.85      0.77      0.79       398
# weighted avg       0.84      0.83      0.82       398
#
#
# 정리
#
# 정확도 : 0.8291
# 정밀도 : 0.9011
# 재현율 : 0.5816
# 샘플링 방법 :  rus
#
# BalancedBagging 모델
# 오차행렬
#
# [[187  70]
#  [ 49  92]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76       257
#            1       0.57      0.65      0.61       141
#
#     accuracy                           0.70       398
#    macro avg       0.68      0.69      0.68       398
# weighted avg       0.71      0.70      0.70       398
#
#
# 정리
#
# 정확도 : 0.7010
# 정밀도 : 0.5679
# 재현율 : 0.6525
# 샘플링 방법 :  rus
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[194  63]
#  [ 45  96]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       257
#            1       0.60      0.68      0.64       141
#
#     accuracy                           0.73       398
#    macro avg       0.71      0.72      0.71       398
# weighted avg       0.74      0.73      0.73       398
#
#
# 정리
#
# 정확도 : 0.7286
# 정밀도 : 0.6038
# 재현율 : 0.6809
# 샘플링 방법 :  rus
#
# EasyEnsemble 모델
# 오차행렬
#
# [[220  37]
#  [ 52  89]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       257
#            1       0.71      0.63      0.67       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.74      0.75       398
# weighted avg       0.77      0.78      0.77       398
#
#
# 정리
#
# 정확도 : 0.7764
# 정밀도 : 0.7063
# 재현율 : 0.6312
# 샘플링 방법 :  rus
#
# RandomForest 모델
# 오차행렬
#
# [[188  69]
#  [ 48  93]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76       257
#            1       0.57      0.66      0.61       141
#
#     accuracy                           0.71       398
#    macro avg       0.69      0.70      0.69       398
# weighted avg       0.72      0.71      0.71       398
#
#
# 정리
#
# 정확도 : 0.7060
# 정밀도 : 0.5741
# 재현율 : 0.6596
# 샘플링 방법 :  nm1
#
# Decisiontree 모델
# 오차행렬
#
# [[235  22]
#  [ 52  89]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       257
#            1       0.80      0.63      0.71       141
#
#     accuracy                           0.81       398
#    macro avg       0.81      0.77      0.79       398
# weighted avg       0.81      0.81      0.81       398
#
#
# 정리
#
# 정확도 : 0.8141
# 정밀도 : 0.8018
# 재현율 : 0.6312
# 샘플링 방법 :  nm1
#
# BalancedBagging 모델
# 오차행렬
#
# [[181  76]
#  [ 43  98]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75       257
#            1       0.56      0.70      0.62       141
#
#     accuracy                           0.70       398
#    macro avg       0.69      0.70      0.69       398
# weighted avg       0.72      0.70      0.71       398
#
#
# 정리
#
# 정확도 : 0.7010
# 정밀도 : 0.5632
# 재현율 : 0.6950
# 샘플링 방법 :  nm1
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[193  64]
#  [ 41 100]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.79       257
#            1       0.61      0.71      0.66       141
#
#     accuracy                           0.74       398
#    macro avg       0.72      0.73      0.72       398
# weighted avg       0.75      0.74      0.74       398
#
#
# 정리
#
# 정확도 : 0.7362
# 정밀도 : 0.6098
# 재현율 : 0.7092
# 샘플링 방법 :  nm1
#
# EasyEnsemble 모델
# 오차행렬
#
# [[183  74]
#  [ 43  98]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.71      0.76       257
#            1       0.57      0.70      0.63       141
#
#     accuracy                           0.71       398
#    macro avg       0.69      0.70      0.69       398
# weighted avg       0.72      0.71      0.71       398
#
#
# 정리
#
# 정확도 : 0.7060
# 정밀도 : 0.5698
# 재현율 : 0.6950
# 샘플링 방법 :  nm1
#
# RandomForest 모델
# 오차행렬
#
# [[194  63]
#  [ 41 100]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       257
#            1       0.61      0.71      0.66       141
#
#     accuracy                           0.74       398
#    macro avg       0.72      0.73      0.72       398
# weighted avg       0.75      0.74      0.74       398
#
#
# 정리
#
# 정확도 : 0.7387
# 정밀도 : 0.6135
# 재현율 : 0.7092
# 샘플링 방법 :  renn
#
# Decisiontree 모델
# 오차행렬
#
# [[209  48]
#  [ 50  91]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       257
#            1       0.65      0.65      0.65       141
#
#     accuracy                           0.75       398
#    macro avg       0.73      0.73      0.73       398
# weighted avg       0.75      0.75      0.75       398
#
#
# 정리
#
# 정확도 : 0.7538
# 정밀도 : 0.6547
# 재현율 : 0.6454
# 샘플링 방법 :  renn
#
# BalancedBagging 모델
# 오차행렬
#
# [[124 133]
#  [ 28 113]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.48      0.61       257
#            1       0.46      0.80      0.58       141
#
#     accuracy                           0.60       398
#    macro avg       0.64      0.64      0.60       398
# weighted avg       0.69      0.60      0.60       398
#
#
# 정리
#
# 정확도 : 0.5955
# 정밀도 : 0.4593
# 재현율 : 0.8014
# 샘플링 방법 :  renn
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[125 132]
#  [ 31 110]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.49      0.61       257
#            1       0.45      0.78      0.57       141
#
#     accuracy                           0.59       398
#    macro avg       0.63      0.63      0.59       398
# weighted avg       0.68      0.59      0.59       398
#
#
# 정리
#
# 정확도 : 0.5905
# 정밀도 : 0.4545
# 재현율 : 0.7801
# 샘플링 방법 :  renn
#
# EasyEnsemble 모델
# 오차행렬
#
# [[188  69]
#  [ 44  97]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77       257
#            1       0.58      0.69      0.63       141
#
#     accuracy                           0.72       398
#    macro avg       0.70      0.71      0.70       398
# weighted avg       0.73      0.72      0.72       398
#
#
# 정리
#
# 정확도 : 0.7161
# 정밀도 : 0.5843
# 재현율 : 0.6879
# 샘플링 방법 :  renn
#
# RandomForest 모델
# 오차행렬
#
# [[113 144]
#  [ 28 113]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.44      0.57       257
#            1       0.44      0.80      0.57       141
#
#     accuracy                           0.57       398
#    macro avg       0.62      0.62      0.57       398
# weighted avg       0.67      0.57      0.57       398
#
#
# 정리
#
# 정확도 : 0.5678
# 정밀도 : 0.4397
# 재현율 : 0.8014
# 샘플링 방법 :  allknn
#
# Decisiontree 모델
# 오차행렬
#
# [[233  24]
#  [ 58  83]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       257
#            1       0.78      0.59      0.67       141
#
#     accuracy                           0.79       398
#    macro avg       0.79      0.75      0.76       398
# weighted avg       0.79      0.79      0.79       398
#
#
# 정리
#
# 정확도 : 0.7940
# 정밀도 : 0.7757
# 재현율 : 0.5887
# 샘플링 방법 :  allknn
#
# BalancedBagging 모델
# 오차행렬
#
# [[144 113]
#  [ 31 110]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.56      0.67       257
#            1       0.49      0.78      0.60       141
#
#     accuracy                           0.64       398
#    macro avg       0.66      0.67      0.64       398
# weighted avg       0.71      0.64      0.64       398
#
#
# 정리
#
# 정확도 : 0.6382
# 정밀도 : 0.4933
# 재현율 : 0.7801
# 샘플링 방법 :  allknn
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[149 108]
#  [ 33 108]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.58      0.68       257
#            1       0.50      0.77      0.61       141
#
#     accuracy                           0.65       398
#    macro avg       0.66      0.67      0.64       398
# weighted avg       0.71      0.65      0.65       398
#
#
# 정리
#
# 정확도 : 0.6457
# 정밀도 : 0.5000
# 재현율 : 0.7660
# 샘플링 방법 :  allknn
#
# EasyEnsemble 모델
# 오차행렬
#
# [[201  56]
#  [ 45  96]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       257
#            1       0.63      0.68      0.66       141
#
#     accuracy                           0.75       398
#    macro avg       0.72      0.73      0.73       398
# weighted avg       0.75      0.75      0.75       398
#
#
# 정리
#
# 정확도 : 0.7462
# 정밀도 : 0.6316
# 재현율 : 0.6809
# 샘플링 방법 :  allknn
#
# RandomForest 모델
# 오차행렬
#
# [[145 112]
#  [ 32 109]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.56      0.67       257
#            1       0.49      0.77      0.60       141
#
#     accuracy                           0.64       398
#    macro avg       0.66      0.67      0.64       398
# weighted avg       0.70      0.64      0.64       398
#
#
# 정리
#
# 정확도 : 0.6382
# 정밀도 : 0.4932
# 재현율 : 0.7730
# 샘플링 방법 :  cnn
#
# Decisiontree 모델
# 오차행렬
#
# [[244  13]
#  [ 56  85]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.88       257
#            1       0.87      0.60      0.71       141
#
#     accuracy                           0.83       398
#    macro avg       0.84      0.78      0.79       398
# weighted avg       0.83      0.83      0.82       398
#
#
# 정리
#
# 정확도 : 0.8266
# 정밀도 : 0.8673
# 재현율 : 0.6028
# 샘플링 방법 :  cnn
#
# BalancedBagging 모델
# 오차행렬
#
# [[206  51]
#  [ 51  90]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       257
#            1       0.64      0.64      0.64       141
#
#     accuracy                           0.74       398
#    macro avg       0.72      0.72      0.72       398
# weighted avg       0.74      0.74      0.74       398
#
#
# 정리
#
# 정확도 : 0.7437
# 정밀도 : 0.6383
# 재현율 : 0.6383
# 샘플링 방법 :  cnn
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[224  33]
#  [ 58  83]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       257
#            1       0.72      0.59      0.65       141
#
#     accuracy                           0.77       398
#    macro avg       0.75      0.73      0.74       398
# weighted avg       0.77      0.77      0.77       398
#
#
# 정리
#
# 정확도 : 0.7714
# 정밀도 : 0.7155
# 재현율 : 0.5887
# 샘플링 방법 :  cnn
#
# EasyEnsemble 모델
# 오차행렬
#
# [[235  22]
#  [ 59  82]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       257
#            1       0.79      0.58      0.67       141
#
#     accuracy                           0.80       398
#    macro avg       0.79      0.75      0.76       398
# weighted avg       0.80      0.80      0.79       398
#
#
# 정리
#
# 정확도 : 0.7965
# 정밀도 : 0.7885
# 재현율 : 0.5816
# 샘플링 방법 :  cnn
#
# RandomForest 모델
# 오차행렬
#
# [[185  72]
#  [ 47  94]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76       257
#            1       0.57      0.67      0.61       141
#
#     accuracy                           0.70       398
#    macro avg       0.68      0.69      0.68       398
# weighted avg       0.72      0.70      0.71       398
#
#
# 정리
#
# 정확도 : 0.7010
# 정밀도 : 0.5663
# 재현율 : 0.6667
# 샘플링 방법 :  oss
#
# Decisiontree 모델
# 오차행렬
#
# [[250   7]
#  [ 58  83]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88       257
#            1       0.92      0.59      0.72       141
#
#     accuracy                           0.84       398
#    macro avg       0.87      0.78      0.80       398
# weighted avg       0.85      0.84      0.83       398
#
#
# 정리
#
# 정확도 : 0.8367
# 정밀도 : 0.9222
# 재현율 : 0.5887
# 샘플링 방법 :  oss
#
# BalancedBagging 모델
# 오차행렬
#
# [[210  47]
#  [ 50  91]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81       257
#            1       0.66      0.65      0.65       141
#
#     accuracy                           0.76       398
#    macro avg       0.73      0.73      0.73       398
# weighted avg       0.76      0.76      0.76       398
#
#
# 정리
#
# 정확도 : 0.7563
# 정밀도 : 0.6594
# 재현율 : 0.6454
# 샘플링 방법 :  oss
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[198  59]
#  [ 45  96]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       257
#            1       0.62      0.68      0.65       141
#
#     accuracy                           0.74       398
#    macro avg       0.72      0.73      0.72       398
# weighted avg       0.75      0.74      0.74       398
#
#
# 정리
#
# 정확도 : 0.7387
# 정밀도 : 0.6194
# 재현율 : 0.6809
# 샘플링 방법 :  oss
#
# EasyEnsemble 모델
# 오차행렬
#
# [[229  28]
#  [ 55  86]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       257
#            1       0.75      0.61      0.67       141
#
#     accuracy                           0.79       398
#    macro avg       0.78      0.75      0.76       398
# weighted avg       0.79      0.79      0.79       398
#
#
# 정리
#
# 정확도 : 0.7915
# 정밀도 : 0.7544
# 재현율 : 0.6099
# 샘플링 방법 :  oss
#
# RandomForest 모델
# 오차행렬
#
# [[225  32]
#  [ 55  86]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       257
#            1       0.73      0.61      0.66       141
#
#     accuracy                           0.78       398
#    macro avg       0.77      0.74      0.75       398
# weighted avg       0.78      0.78      0.78       398
#
#
# 정리
#
# 정확도 : 0.7814
# 정밀도 : 0.7288
# 재현율 : 0.6099
# 샘플링 방법 :  ncr
#
# Decisiontree 모델
# 오차행렬
#
# [[239  18]
#  [ 57  84]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86       257
#            1       0.82      0.60      0.69       141
#
#     accuracy                           0.81       398
#    macro avg       0.82      0.76      0.78       398
# weighted avg       0.81      0.81      0.80       398
#
#
# 정리
#
# 정확도 : 0.8116
# 정밀도 : 0.8235
# 재현율 : 0.5957
# 샘플링 방법 :  ncr
#
# BalancedBagging 모델
# 오차행렬
#
# [[168  89]
#  [ 39 102]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.65      0.72       257
#            1       0.53      0.72      0.61       141
#
#     accuracy                           0.68       398
#    macro avg       0.67      0.69      0.67       398
# weighted avg       0.71      0.68      0.69       398
#
#
# 정리
#
# 정확도 : 0.6784
# 정밀도 : 0.5340
# 재현율 : 0.7234
# 샘플링 방법 :  ncr
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[173  84]
#  [ 41 100]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73       257
#            1       0.54      0.71      0.62       141
#
#     accuracy                           0.69       398
#    macro avg       0.68      0.69      0.67       398
# weighted avg       0.71      0.69      0.69       398
#
#
# 정리
#
# 정확도 : 0.6859
# 정밀도 : 0.5435
# 재현율 : 0.7092
# 샘플링 방법 :  ncr
#
# EasyEnsemble 모델
# 오차행렬
#
# [[211  46]
#  [ 47  94]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       257
#            1       0.67      0.67      0.67       141
#
#     accuracy                           0.77       398
#    macro avg       0.74      0.74      0.74       398
# weighted avg       0.77      0.77      0.77       398
#
#
# 정리
#
# 정확도 : 0.7663
# 정밀도 : 0.6714
# 재현율 : 0.6667
# 샘플링 방법 :  ncr
#
# RandomForest 모델
# 오차행렬
#
# [[182  75]
#  [ 44  97]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.71      0.75       257
#            1       0.56      0.69      0.62       141
#
#     accuracy                           0.70       398
#    macro avg       0.68      0.70      0.69       398
# weighted avg       0.72      0.70      0.71       398
#
#
# 정리
#
# 정확도 : 0.7010
# 정밀도 : 0.5640
# 재현율 : 0.6879
# 샘플링 방법 :  iht
#
# Decisiontree 모델
# 오차행렬
#
# [[144 113]
#  [ 34 107]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.56      0.66       257
#            1       0.49      0.76      0.59       141
#
#     accuracy                           0.63       398
#    macro avg       0.65      0.66      0.63       398
# weighted avg       0.69      0.63      0.64       398
#
#
# 정리
#
# 정확도 : 0.6307
# 정밀도 : 0.4864
# 재현율 : 0.7589
# 샘플링 방법 :  iht
#
# BalancedBagging 모델
# 오차행렬
#
# [[128 129]
#  [ 28 113]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.50      0.62       257
#            1       0.47      0.80      0.59       141
#
#     accuracy                           0.61       398
#    macro avg       0.64      0.65      0.60       398
# weighted avg       0.70      0.61      0.61       398
#
#
# 정리
#
# 정확도 : 0.6055
# 정밀도 : 0.4669
# 재현율 : 0.8014
# 샘플링 방법 :  iht
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[128 129]
#  [ 28 113]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.50      0.62       257
#            1       0.47      0.80      0.59       141
#
#     accuracy                           0.61       398
#    macro avg       0.64      0.65      0.60       398
# weighted avg       0.70      0.61      0.61       398
#
#
# 정리
#
# 정확도 : 0.6055
# 정밀도 : 0.4669
# 재현율 : 0.8014
# 샘플링 방법 :  iht
#
# EasyEnsemble 모델
# 오차행렬
#
# [[139 118]
#  [ 42  99]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.54      0.63       257
#            1       0.46      0.70      0.55       141
#
#     accuracy                           0.60       398
#    macro avg       0.61      0.62      0.59       398
# weighted avg       0.66      0.60      0.61       398
#
#
# 정리
#
# 정확도 : 0.5980
# 정밀도 : 0.4562
# 재현율 : 0.7021
# 샘플링 방법 :  iht
#
# RandomForest 모델
# 오차행렬
#
# [[131 126]
#  [ 28 113]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.51      0.63       257
#            1       0.47      0.80      0.59       141
#
#     accuracy                           0.61       398
#    macro avg       0.65      0.66      0.61       398
# weighted avg       0.70      0.61      0.62       398
#
#
# 정리
#
# 정확도 : 0.6131
# 정밀도 : 0.4728
# 재현율 : 0.8014
# 샘플링 방법 :  smote_nc
#
# Decisiontree 모델
# 오차행렬
#
# [[251   6]
#  [ 57  84]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89       257
#            1       0.93      0.60      0.73       141
#
#     accuracy                           0.84       398
#    macro avg       0.87      0.79      0.81       398
# weighted avg       0.86      0.84      0.83       398
#
#
# 정리
#
# 정확도 : 0.8417
# 정밀도 : 0.9333
# 재현율 : 0.5957
# 샘플링 방법 :  smote_nc
#
# BalancedBagging 모델
# 오차행렬
#
# [[210  47]
#  [ 50  91]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81       257
#            1       0.66      0.65      0.65       141
#
#     accuracy                           0.76       398
#    macro avg       0.73      0.73      0.73       398
# weighted avg       0.76      0.76      0.76       398
#
#
# 정리
#
# 정확도 : 0.7563
# 정밀도 : 0.6594
# 재현율 : 0.6454
# 샘플링 방법 :  smote_nc
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[215  42]
#  [ 51  90]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       257
#            1       0.68      0.64      0.66       141
#
#     accuracy                           0.77       398
#    macro avg       0.75      0.74      0.74       398
# weighted avg       0.76      0.77      0.76       398
#
#
# 정리
#
# 정확도 : 0.7663
# 정밀도 : 0.6818
# 재현율 : 0.6383
# 샘플링 방법 :  smote_nc
#
# EasyEnsemble 모델
# 오차행렬
#
# [[220  37]
#  [ 52  89]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       257
#            1       0.71      0.63      0.67       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.74      0.75       398
# weighted avg       0.77      0.78      0.77       398
#
#
# 정리
#
# 정확도 : 0.7764
# 정밀도 : 0.7063
# 재현율 : 0.6312
# 샘플링 방법 :  smote_nc
#
# RandomForest 모델
# 오차행렬
#
# [[215  42]
#  [ 51  90]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       257
#            1       0.68      0.64      0.66       141
#
#     accuracy                           0.77       398
#    macro avg       0.75      0.74      0.74       398
# weighted avg       0.76      0.77      0.76       398
#
#
# 정리
#
# 정확도 : 0.7663
# 정밀도 : 0.6818
# 재현율 : 0.6383
# 샘플링 방법 :  smote
#
# Decisiontree 모델
# 오차행렬
#
# [[232  25]
#  [ 56  85]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       257
#            1       0.77      0.60      0.68       141
#
#     accuracy                           0.80       398
#    macro avg       0.79      0.75      0.76       398
# weighted avg       0.79      0.80      0.79       398
#
#
# 정리
#
# 정확도 : 0.7965
# 정밀도 : 0.7727
# 재현율 : 0.6028
# 샘플링 방법 :  smote
#
# BalancedBagging 모델
# 오차행렬
#
# [[218  39]
#  [ 48  93]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       257
#            1       0.70      0.66      0.68       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.75      0.76       398
# weighted avg       0.78      0.78      0.78       398
#
#
# 정리
#
# 정확도 : 0.7814
# 정밀도 : 0.7045
# 재현율 : 0.6596
# 샘플링 방법 :  smote
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[222  35]
#  [ 52  89]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84       257
#            1       0.72      0.63      0.67       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.75      0.75       398
# weighted avg       0.78      0.78      0.78       398
#
#
# 정리
#
# 정확도 : 0.7814
# 정밀도 : 0.7177
# 재현율 : 0.6312
# 샘플링 방법 :  smote
#
# EasyEnsemble 모델
# 오차행렬
#
# [[224  33]
#  [ 55  86]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       257
#            1       0.72      0.61      0.66       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.74      0.75       398
# weighted avg       0.77      0.78      0.77       398
#
#
# 정리
#
# 정확도 : 0.7789
# 정밀도 : 0.7227
# 재현율 : 0.6099
# 샘플링 방법 :  smote
#
# RandomForest 모델
# 오차행렬
#
# [[224  33]
#  [ 51  90]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       257
#            1       0.73      0.64      0.68       141
#
#     accuracy                           0.79       398
#    macro avg       0.77      0.75      0.76       398
# weighted avg       0.79      0.79      0.79       398
#
#
# 정리
#
# 정확도 : 0.7889
# 정밀도 : 0.7317
# 재현율 : 0.6383
# 샘플링 방법 :  smote_enn
#
# Decisiontree 모델
# 오차행렬
#
# [[224  33]
#  [ 54  87]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       257
#            1       0.72      0.62      0.67       141
#
#     accuracy                           0.78       398
#    macro avg       0.77      0.74      0.75       398
# weighted avg       0.78      0.78      0.78       398
#
#
# 정리
#
# 정확도 : 0.7814
# 정밀도 : 0.7250
# 재현율 : 0.6170
# 샘플링 방법 :  smote_enn
#
# BalancedBagging 모델
# 오차행렬
#
# [[213  44]
#  [ 54  87]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       257
#            1       0.66      0.62      0.64       141
#
#     accuracy                           0.75       398
#    macro avg       0.73      0.72      0.73       398
# weighted avg       0.75      0.75      0.75       398
#
#
# 정리
#
# 정확도 : 0.7538
# 정밀도 : 0.6641
# 재현율 : 0.6170
# 샘플링 방법 :  smote_enn
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[232  25]
#  [ 58  83]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       257
#            1       0.77      0.59      0.67       141
#
#     accuracy                           0.79       398
#    macro avg       0.78      0.75      0.76       398
# weighted avg       0.79      0.79      0.78       398
#
#
# 정리
#
# 정확도 : 0.7915
# 정밀도 : 0.7685
# 재현율 : 0.5887
# 샘플링 방법 :  smote_enn
#
# EasyEnsemble 모델
# 오차행렬
#
# [[241  16]
#  [ 58  83]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87       257
#            1       0.84      0.59      0.69       141
#
#     accuracy                           0.81       398
#    macro avg       0.82      0.76      0.78       398
# weighted avg       0.82      0.81      0.80       398
#
#
# 정리
#
# 정확도 : 0.8141
# 정밀도 : 0.8384
# 재현율 : 0.5887
# 샘플링 방법 :  smote_enn
#
# RandomForest 모델
# 오차행렬
#
# [[226  31]
#  [ 58  83]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       257
#            1       0.73      0.59      0.65       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.73      0.74       398
# weighted avg       0.77      0.78      0.77       398
#
#
# 정리
#
# 정확도 : 0.7764
# 정밀도 : 0.7281
# 재현율 : 0.5887
# 샘플링 방법 :  smote_tomek
#
# Decisiontree 모델
# 오차행렬
#
# [[246  11]
#  [ 60  81]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87       257
#            1       0.88      0.57      0.70       141
#
#     accuracy                           0.82       398
#    macro avg       0.84      0.77      0.78       398
# weighted avg       0.83      0.82      0.81       398
#
#
# 정리
#
# 정확도 : 0.8216
# 정밀도 : 0.8804
# 재현율 : 0.5745
# 샘플링 방법 :  smote_tomek
#
# BalancedBagging 모델
# 오차행렬
#
# [[210  47]
#  [ 50  91]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81       257
#            1       0.66      0.65      0.65       141
#
#     accuracy                           0.76       398
#    macro avg       0.73      0.73      0.73       398
# weighted avg       0.76      0.76      0.76       398
#
#
# 정리
#
# 정확도 : 0.7563
# 정밀도 : 0.6594
# 재현율 : 0.6454
# 샘플링 방법 :  smote_tomek
#
# BalancedRandomForest 모델
# 오차행렬
#
# [[216  41]
#  [ 47  94]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       257
#            1       0.70      0.67      0.68       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.75      0.76       398
# weighted avg       0.78      0.78      0.78       398
#
#
# 정리
#
# 정확도 : 0.7789
# 정밀도 : 0.6963
# 재현율 : 0.6667
# 샘플링 방법 :  smote_tomek
#
# EasyEnsemble 모델
# 오차행렬
#
# [[223  34]
#  [ 52  89]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       257
#            1       0.72      0.63      0.67       141
#
#     accuracy                           0.78       398
#    macro avg       0.77      0.75      0.76       398
# weighted avg       0.78      0.78      0.78       398
#
#
# 정리
#
# 정확도 : 0.7839
# 정밀도 : 0.7236
# 재현율 : 0.6312
# 샘플링 방법 :  smote_tomek
#
# RandomForest 모델
# 오차행렬
#
# [[220  37]
#  [ 52  89]]
#
# report
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       257
#            1       0.71      0.63      0.67       141
#
#     accuracy                           0.78       398
#    macro avg       0.76      0.74      0.75       398
# weighted avg       0.77      0.78      0.77       398
#
#
# 정리
#
# 정확도 : 0.7764
# 정밀도 : 0.7063
# 재현율 : 0.6312
# {'enn DecisionTreeClassifier': 0.7012092125372014, 'enn BalancedBaggingClassifier': 0.6457430340557275, 'enn BalancedRandomForestClassifier': 0.6611455108359133, 'enn EasyEnsembleClassifier': 0.7309103954521622, 'enn RandomForestClassifier': 0.6523570969813745, 'rus DecisionTreeClassifier': 0.7931645879188065, 'rus BalancedBaggingClassifier': 0.6829407078638898, 'rus BalancedRandomForestClassifier': 0.7111290322580646, 'rus EasyEnsembleClassifier': 0.749212350346566, 'rus RandomForestClassifier': 0.688269435462816, 'nm1 DecisionTreeClassifier': 0.7851598972922502, 'nm1 BalancedBaggingClassifier': 0.6874104874104874, 'nm1 BalancedRandomForestClassifier': 0.7209442088744951, 'nm1 EasyEnsembleClassifier': 0.6919810291111861, 'nm1 RandomForestClassifier': 0.7232563115104834, 'renn DecisionTreeClassifier': 0.7300387596899225, 'renn BalancedBaggingClassifier': 0.5951681481902669, 'renn BalancedRandomForestClassifier': 0.5898697045751964, 'renn EasyEnsembleClassifier': 0.7004189897617287, 'renn RandomForestClassifier': 0.5678391959798995, 'allknn DecisionTreeClassifier': 0.7598599011066636, 'allknn BalancedBaggingClassifier': 0.6355311355311355, 'allknn BalancedRandomForestClassifier': 0.6419287532780766, 'allknn EasyEnsembleClassifier': 0.727247436880424, 'allknn RandomForestClassifier': 0.6352063548641698, 'cnn DecisionTreeClassifier': 0.7937095768574928, 'cnn BalancedBaggingClassifier': 0.7199271462869443, 'cnn BalancedRandomForestClassifier': 0.7385416140279953, 'cnn EasyEnsembleClassifier': 0.7611911552279713, 'cnn RandomForestClassifier': 0.6845120334658914, 'oss DecisionTreeClassifier': 0.801785235413554, 'oss BalancedBaggingClassifier': 0.7323544296776967, 'oss BalancedRandomForestClassifier': 0.7203243243243244, 'oss EasyEnsembleClassifier': 0.7605451052879563, 'oss RandomForestClassifier': 0.7510407454541532, 'ncr DecisionTreeClassifier': 0.7778670774451365, 'ncr BalancedBaggingClassifier': 0.669297881179892, 'ncr BalancedRandomForestClassifier': 0.6749959170341336, 'ncr EasyEnsembleClassifier': 0.7442283108178143, 'ncr RandomForestClassifier': 0.6867157475575312, 'iht DecisionTreeClassifier': 0.6274333747253797, 'iht BalancedBaggingClassifier': 0.60496652526568, 'iht BalancedRandomForestClassifier': 0.60496652526568, 'iht EasyEnsembleClassifier': 0.593887911022678, 'iht RandomForestClassifier': 0.6122722672064778, 'smote_nc DecisionTreeClassifier': 0.8078841512469831, 'smote_nc BalancedBaggingClassifier': 0.7323544296776967, 'smote_nc BalancedRandomForestClassifier': 0.7407601958271175, 'smote_nc EasyEnsembleClassifier': 0.749212350346566, 'smote_nc RandomForestClassifier': 0.7407601958271175, 'smote DecisionTreeClassifier': 0.7643334917211886, 'smote BalancedBaggingClassifier': 0.7574853444834324, 'smote BalancedRandomForestClassifier': 0.7539281526489714, 'smote EasyEnsembleClassifier': 0.7486796785304248, 'smote RandomForestClassifier': 0.7619617224880384, 'smote_enn DecisionTreeClassifier': 0.7520249221183801, 'smote_enn BalancedBaggingClassifier': 0.7263414907947912, 'smote_enn BalancedRandomForestClassifier': 0.7574649603900061, 'smote_enn EasyEnsembleClassifier': 0.7792865707434053, 'smote_enn RandomForestClassifier': 0.7432351128991338, 'smote_tomek DecisionTreeClassifier': 0.7845844228115781, 'smote_tomek BalancedBaggingClassifier': 0.7323544296776967, 'smote_tomek BalancedRandomForestClassifier': 0.755964325529543, 'smote_tomek EasyEnsembleClassifier': 0.7562941444520392, 'smote_tomek RandomForestClassifier': 0.749212350346566}

# %%
df_plot=pd.DataFrame(f1_list, index=[0])
df_plot=df_plot.transpose()

# %%
condition = df_plot[0].sort_values(ascending = False)
condition=condition.head(5)

# %%
condition=pd.DataFrame(condition)
condition
# Out:
#                                         0
# smote_nc DecisionTreeClassifier  0.807884
# oss DecisionTreeClassifier       0.801785
# cnn DecisionTreeClassifier       0.793710
# rus DecisionTreeClassifier       0.793165
# nm1 DecisionTreeClassifier       0.785160

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

x=condition.index
y=condition[0]

fig, ax = plt.subplots(figsize=(8,6))
sns.barplot(x=x, y=y);
plt.xlabel("Models")
plt.ylabel("F1 Score")
plt.xticks(rotation=40)
plt.title("Model Comparison - F1 Score");
