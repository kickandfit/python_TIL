# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import os
from tqdm import tqdm
import time
import urllib.request

# %%
url = 'https://play.google.com/store/apps/details?id=com.coupang.mobile&hl=ko&gl=US&showAllReviews=true'
driver = webdriver.Chrome('c:/pydata/chromedriver.exe')
driver.get(url)
n = 5#스크롤 횟수
for i in range(n):
    try:
        driver.find_element_by_css_selector('#fcxH9b > div.WpDbMd > c-wiz:nth-child(4) > div > div.ZfcPIb > div > div > main > div > div.W4P4ne > div:nth-child(2) > div.PFAhAf > div > span > span').click()
        time.sleep(2)
    except:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)
html = driver.page_source
soup = bs(html , 'html.parser')
soup
# Out:
# <html dir="ltr" lang="ko"><head><script async="" crossorigin="anonymous" integrity="sha384-rGhFlpuQD75xJXsUuH5NiV7hX6gmbfW2F7WVQ2ff6OpdIpBYNeDFDjZNTjhhs4QO" nonce="" src="https://www.gstatic.com/recaptcha/releases/Iwg4ANhK7Iu8SHToSsE0E20K/recaptcha__ko.js" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js"></script><base href="https://play.google.com/"/><meta content="origin" name="referrer"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="/opensearch.xml" rel="search" title="Google Play" type="application/opensearchdescription+xml"/><link href="//www.gstatic.com/android/market_images/web/favicon_v2.ico" rel="shortcut icon"/><script async="" nonce="" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.2cdKFnNWjuc.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo-rZMnae0kdWLu9CWmKEzOTJj_h7w/cb=gapi.loaded_0"></script><script data-id="_gd" nonce="">window.WIZ_global_d
# ...

# %%
body_soup = soup.find_all('div', class_="UD7Dzf")

new_list = []
for i in body_soup:
    body = i.find('span', jsname="bN97Pc").text
    full = i.find('span', jsname="fbQN7e").text
    new_list.append(body)
txt = ""
for i in new_list:
    txt = txt+str(i)
txt
# Out:
# '별 하나도 아까울정도로 서비스 개판임. 다들 로켓배송 칭찬하는데 로켓배송 상품이 다음날 도착하지 않는 경우가 여러번임. 문의해도 거들떠도 안봄. 그냥 서비스 개판임. 그냥 로켓배송 달아놓고 돈쓰게 만들고 담날 갖다줌. 그냥 추악한 상술임. 담날 받든 말든 신경도 안쓰고 그냥 지들은 띵가띵가 노는거임. 이딴 것도 대기업이라고 믿는 호구들이 더 없길 바람. 로켓배송 믿지 마셈. 쿠팡 쓸빠엔 그냥 배송일 2일이여도 정확히 지키는 다른 앱. 씀 24시간 상담은 그냥 매크로임. 제대로 상담해보려해도 대기시간만 몇시간임. 서비스가 제대로 되있...전체 리뷰공룡 덩치라 그렇지만서도 로켓배송, 아묻따 반품, 넓은 선택폭, 최저가 아무도 못이죠.. 그런데 덩치 커지기전부터 원래부터도 검색,분류등 쇼핑하기 완전 편했어요 그게 좋아서 초기부터 썼거든요 공룡된 지금도 여전히 상담사 응대 메뉴얼 친절한거도 참 좋고 쿠팡 쓰다가 다른데는 성질나서 못써요 덩치가 너무 커져도 안되니 한번씩은 다른데 쓰기도 하지만요 혜택과 친절이 언제까지 유지될진 모르지만 변하지 않는한 저는 쿠팡 러버입니다good! 이었지만 대표 경영진의 모습들이 쿠팡이라는 기업 이미지를 한참 밑바닥으로 이끌고있다. 쿠팡의 혁신적임 에 찬사를 보내지만 경영진은 한낱 개미새끼로 보겠지만 아니 신경조차 쓰지 않겠지만 나도 노동자로써 이 기업을 이용하지만 점점 쓰고싶지 않게된다..가격비교에만 이용하고있다(별5->별3)배송이나 상품 서비스를 볼 때마다 생각남. 오늘은 몇명이 갈려나가서 우리가 편리할까. 대가는 받고 일들하는 것인가.로켓배송 완전 편하고 배송비도 엄청나게 아낄 수 있음. 그리고 무엇보다 고객센터가 잘되어있음. 주말 새벽에도 실시간으로 상담사랑 1대1 채팅이 가능함ㄷㄷ;; 어쩌다가 상품이나 주문에 문제생겨도 언제든 바로 해결가능하다는게 진짜 엄청남...쿠팡은 쿠팡과 거래하는 업체들을 쥐어짜는 수준이 가히 천재적. 매출때문에 거래를 계속하게 만들면서 각종 비용은 점점 옥좨게하는 기술이 가히 예술. 양아치의 진수를
# ...

# %%
import pandas as pd
from tqdm import tqdm
from konlpy.tag import Okt
okt = Okt()

# %%
SentiWord = pd.read_csv('c:/pydata/sw/SentiWord_info.csv')
def pos_neg(word):
    tmp =SentiWord[(SentiWord['word']==word) | (SentiWord['word_root']==word)]
    try:
        word_res = (word,tmp['polarity'][tmp.index[0]])
    except:
        word_res = (word, 0)
    return word_res

morp = okt.morphs(txt)
morp
# Out:
# ['별',
#  '하나',
#  '도',
#  '아까울',
#  '정도',
#  '로',
#  '서비스',
#  '개판',
#  '임',
#  '.',
#  '다',
#  '들',
#  '로켓',
#  '배송',
#  '칭찬',
#  '하는데',
#  '로켓',
#  '배송',
#  '상품',
#  '이',
#  '다음',
#  '날',
#  '도착',
#  '하지',
#  '않는',
#  '경우',
#  '가',
#  '여러',
#  '번임',
#  '.',
#  '문의',
#  '해도',
#  '거들',
#  '떠도',
#  '안',
#  '봄',
#  '.',
#  '그냥',
#  '서비스',
#  '개판',
#  '임',
#  '.',
#  '그냥',
#  '로켓',
#  '배송',
#  '달아놓고',
#  '돈',
#  '쓰게',
#  '만들고',
#  '담날',
#  '갖다',
#  '줌',
#  '.',
#  '그냥',
#  '추악한',
#  '상술',
#  '임',
#  '.',
#  '담날',
#  '받든',
#  '말',
#  '든',
#  '신경',
#  '도',
#  '안',
#  '쓰고',
#  '그냥',
#  '지',
#  '들은',
#  '띵가띵',
#  '가',
#  '노는거',
#  '임',
#  '.',
#  '이딴',
#  '것',
#  '도',
#  '대기업',
#  '이라고',
#  '믿는',
#  '호구',
#  '들',
#  '이',
#  '더',
#  '없길',
#  '바람',
#  '.',
#  '로켓',
#  '배송',
#  '믿지',
#  '마셈',
#  '.',
#  '쿠팡',
#  '쓸빠',
#  '엔',
#  '그냥',
#  '배송',
#  '일',
#  '2일',
#  '이여도',
#  '정확히',
#  '지키는',
#  '다른',
#  '앱',
#  '.',
#  '씀',
#  '24시간',
#  '상담',
#  '은',
#  '그냥',
#  '매크로',
#  '임',
#  '.',
# ...

# %%
from tqdm import tqdm
pos_list = []
neg_list = []
unkown_list = []
for noun in tqdm(morp, '긍/부정 나누기'):
    word_res = pos_neg(noun)
    if word_res[1] > 0:
        pos_list.append(word_res[0])
    elif word_res[1] < 0 :
        neg_list.append(word_res[0])
    else:
        unkown_list.append(word_res)
# Out:
# 긍/부정 나누기: 100%|█████████████████████████████████████████████████████████████| 8344/8344 [00:38<00:00, 218.69it/s]

# %%
print('긍정키워드 수:', len(pos_list),'개')
print('부정키워드 수:', len(neg_list),'개')
print('중립 또는 모름 키워드 수:', len(unkown_list),'개')
# Out:
# 긍정키워드 수: 327 개
# 부정키워드 수: 841 개
# 중립 또는 모름 키워드 수: 7176 개

# %%
from collections import Counter #jdk 제공 모듈

pos_count = dict(Counter(pos_list).most_common()) # 단어별 갯수 계산 및 내림차순 정렬, 딕셔너리 구조
neg_count = dict(Counter(neg_list).most_common())
unkown_count = dict(Counter(unkown_list).most_common())
print(pos_count)
print('========================================')
# Out:
# {'로': 39, '것': 23, '잘': 19, '개': 17, '사람': 16, '품절': 14, '좋은': 13, '해결': 7, 'ㅎㅎ': 7, '제대로': 6, '편하고': 6, '점': 6, '무료': 6, ':': 6, '(': 5, '와': 5, '하기': 4, '좋고': 4, '혜택': 4, '장점': 4, '좋을': 4, '타': 4, '용': 4, '편리하고': 4, '보': 4, '예': 3, '좋': 3, '개선': 3, 'ㅋ': 3, '함께': 3, '많음': 3, '추천': 3, '넘': 3, '열': 3, '쉽게': 3, '완전': 2, '^': 2, '신뢰': 2, '믿고': 2, '최고': 2, '사랑': 2, '분명': 2, '세': 2, '원': 2, '편안하게': 2, '이벤트': 2, '칭찬': 1, '최저': 1, '좋아서': 1, '친절': 1, '유지': 1, '혁신': 1, '찬사': 1, '명': 1, '대가': 1, '정상': 1, '크': 1, '발전': 1, '정확': 1, '이해': 1, '애': 1, '도움': 1, '써': 1, '용한': 1, '생기': 1, '자세히': 1, '신기': 1, '유명한': 1, '고르': 1, '이롭게': 1, '좋아': 1, '만족': 1, '좋음': 1, '충분히': 1, '대단한': 1, '재주': 1, '동의': 1, '교묘하게': 1, '정': 1, '편리하다': 1, '가능': 1, '순': 1, '돋는다': 1, '신선': 1, '쉽': 1, '저렴': 1, '기미': 1, '좋다고': 1, '정확한': 1, '심': 1}
# ...

# %%
stop_words = '로 것 ㅋ 타 애 와 용'
stop_words = stop_words.split(" ")
stop_words
# Out:
# ['로', '것', 'ㅋ', '타', '애', '와', '용']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
tmp_dic={}
for key, values in pos_count.items():#items()는 딕셔너리 구조를 튜플구조로
    if key not in stop_words:
        tmp_dic[key]=values
pos_count = tmp_dic
def color_func(**kawargs):
    color="#0b1177"
    return color
img_path = 'c:/pydata/sw/good.jpg'
cloud_mask = np.array(Image.open(img_path))
img = Image.open(img_path)
wordcloud = WordCloud(font_path="c:/Windows/Fonts/malgun.ttf",
                      background_color="white", mask=cloud_mask)
wc = wordcloud.generate_from_frequencies(pos_count)
plt.figure(figsize=(10,15))
plt.imshow(wc.recolor(color_func=color_func), interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
def color_func2(**kawargs):
    color="#f20101"
    return color
tmp_dic={}
for key, values in neg_count.items():#items()는 딕셔너리 구조를 튜플구조로
    if key not in stop_words:
        tmp_dic[key]=values
neg_count = tmp_dic
img_path = 'c:/pydata/sw/bad.jpg'
cloud_mask = np.array(Image.open(img_path))
cloud_mask.shape
img = Image.open(img_path)
wordcloud = WordCloud(font_path="c:/Windows/Fonts/malgun.ttf",
                      background_color="white", mask=cloud_mask)
wc = wordcloud.generate_from_frequencies(neg_count)
plt.figure(figsize=(10,15))
plt.imshow(wc.recolor(color_func=color_func2), interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import matplotlib.font_manager as fm
font_name=fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc('font', family=font_name)

pos_count = list(Counter(pos_list).most_common()) # 단어별 갯수 계산 및 내림차순 정렬, 딕셔너리 구조
neg_count = list(Counter(neg_list).most_common())
unkown_count = list(Counter(unkown_list).most_common())


most_df_pos=pd.DataFrame(pos_count, columns=["토픽(단어)", "빈도수"])
most_df_neg=pd.DataFrame(neg_count, columns=["토픽(단어)", "빈도수"])
most_df_unkown=pd.DataFrame(unkown_count, columns=["토픽(단어)", "빈도수"])


plt_df=most_df_pos[most_df_pos['빈도수']>=1]

plt.style.use('ggplot')

plt_df.set_index("토픽(단어)", inplace=True)
plt_df.plot.bar(figsize=(14, 5))
plt.title("긍정단어 빈도수")
plt.show()

plt_df=most_df_neg[most_df_neg['빈도수']>=2]



plt_df.set_index("토픽(단어)", inplace=True)
plt_df.plot.bar(figsize=(14, 5))
plt.title("부정단어 빈도수")
plt.show()

plt_df=most_df_unkown[most_df_unkown['빈도수']>=10]




plt_df.set_index("토픽(단어)", inplace=True)
plt_df.plot.bar(figsize=(14, 5))
plt.title("중립단어 빈도수")
plt.show()
