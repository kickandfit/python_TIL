# %% [markdown]
# #### 미션
#
# - 특정 데이터를 집어넣었을 때, 데이터를 기준으로함
# - ai api_data 사이트 언어분석 api를 이용해 문자에 들어있는 객체명을 가져와 df로 변경
# - 옵션 : 형태소가 뭐가 있고 단어단위로 몇건이 나왔는지

# %%
import urllib3
import json

# %%
openApiURL = "http://aiopen.etri.re.kr:8000/WiseNLU" 

accessKey = "fdf16766-d73d-48be-a4b3-c03276a6cfb2"
analysisCode = "ner"
text = ""

# %%
text += "윤동주(尹東柱, 1917년 12월 30일 ~ 1945년 2월 16일)는 한국의 독립운동가, 시인, 작가이다.중국 만저우 지방 지린 성 연변 용정에서 출생하여 명동학교에서 수학하였고, 숭실중학교와 연희전문학교를 졸업하였다. 숭실중학교 때 처음 시를 발표하였고, 1939년 연희전문 2학년 재학 중 소년(少年) 지에 시를 발표하며 정식으로 문단에 데뷔했다.일본 유학 후 도시샤 대학 재학 중 , 1943년 항일운동을 했다는 혐의로 일본 경찰에 체포되어 후쿠오카 형무소(福岡刑務所)에 투옥, 100여 편의 시를 남기고 27세의 나이에 옥중에서 요절하였다. 사인이 일본의 생체실험이라는 견해가 있고 그의 사후 일본군에 의한 마루타, 생체실험설이 제기되었으나 불확실하다. 사후에 그의 시집 《하늘과 바람과 별과 시》가 출간되었다."        "일제 강점기 후반의 양심적 지식인으로 인정받았으며, 그의 시는 일제와 조선총독부에 대한 비판과 자아성찰 등을 소재로 하였다. 그의 친구이자 사촌인 송몽규 역시 독립운동에 가담하려다가 체포되어 일제의 생체 실험으로 의문의 죽음을 맞는다. 1990년대 후반 이후 그의 창씨개명 '히라누마'가 알려져 논란이 일기도 했다. 본명 외에 윤동주(尹童柱), 윤주(尹柱)라는 필명도 사용하였다."

# %%
requestJson = {
    "access_key": accessKey,
    "argument": {
        "text": text,
        "analysis_code": analysisCode
    }
}

# %%
http = urllib3.PoolManager()
response = http.request(
    "POST",
    openApiURL,
    headers={"Content-Type": "application/json; charset=UTF-8"},
    body=json.dumps(requestJson)
)

# %%
print("[responseCode] " + str(response.status))
print("[responBody]")
print(str(response.data,"utf-8"))
# Out:
# [responseCode] 200
# [responBody]
# {"result":0,"return_object":{"doc_id":"","DCT":"","category":"","category_weight":0.0,"title":{"text":"","NE":""},"metaInfo":{},"paragraphInfo":[],"sentence":[{"id":0.0,"reserve_str":"","text":"윤동주(尹東柱, 1917년 12월 30일 ~ 1945년 2월 16일)는 한국의 독립운동가, 시인, 작가이다.","morp":[{"id":0.0,"lemma":"윤동주","type":"NNP","position":0.0,"weight":0.0566805},{"id":1.0,"lemma":"(","type":"SS","position":9.0,"weight":1.0},{"id":2.0,"lemma":"尹東柱","type":"SH","position":10.0,"weight":1.0},{"id":3.0,"lemma":",","type":"SP","position":19.0,"weight":1.0},{"id":4.0,"lemma":"1917","type":"SN","position":21.0,"weight":1.0},{"id":5.0,"lemma":"년","type":"NNB","position":25.0,"weight":0.0597013},{"id":6.0,"lemma":"12","type":"SN","position":29.0,"weight":1.0},{"id":7.0,"lemma":"월","type":"NNB","position":31.0,"weight":0.0583588},{"id":8.0,"lemma":"30","type":"SN","position":35.0,"weight":1.0},{"id":9.0,"lemma":"일","type":"NNB","position":37.0,"weight":0.0487802},{"id":10.0,"lemma":"~","type":"SO","position":41.0,"weight":1.0},{"id":11.0,"lemma":"1945","type":"SN","position":43.0,"weight":1.0},{"id":12.0,"lemma":"년","type":"NNB","position":47.0,"weight":0.0518608},{"id":13.0,"lemma":"2","type":"SN","position":51.0,"weight":1.0},{"id":14.0,"lemma":"월","type":"NNB","position":52.0,"weight":0.0649133},{"id":15.0,"lemma":"16","type":"SN","position":56.0,"weight":1.0},{"id":16.0,"lemma":"일","type":"NNB","position":58.0,"weight":0.0426752},{"id":17.0,"lemma":")","type":"SS","position":61.0,"weight":1.0},{"id":18.0,"lemma":"는","type":"JX","position":62.0,"weight":0.0897092},{"id":19.0,"lemma":"한국","type":"NNP","position":66.0,"weight":0.156358},{"id":20.0,"lemma":"의","type":"JKG","position":72.0,"weight":0.100211},{"id":21.0,"lemma":"독립","type":"NNG","position":76.0,"weight":0.160432},{"id":22.0,"lemma":"운동","type":"NNG","position":82.0,"weight":0.160432},{"id":23.0,"lemma":"가","type":"XSN","position":88.0,"weight":0.160432},{"id":24.0,"lemma":",","type":"SP","position":91.0,"weight":1.0},{"id":25.0,"lemma":"시인","type":"NNG","position":93.0,"weight":0.0583063},{"id":26.0,"lemma":",","type":"SP","position":99.0,"weight":1.0},{"id":27.0,"lemma":"작가","type":"NNG","position":101.0,"weight":0.0498619},{"id":28.0,"lemma":"이","type":"VCP","position":107.0,"weight":0.0484025},{"id":29.0,"lemma":"다","type":"EF","position":110.0,"weight":0.0749575},{"id":30.0,"lemma":".","type":"SF","position":113.0,"weight":1.0}],"WSD":[{"id":0.0,"text":"윤동주","type":"NNP","scode":"00","weight":20.0,"position":0.0,"begin":0.0,"end":0.0},{"id":1.0,"text":"(","type":"SS","scode":"00","weight":1.0,"position":9.0,"begin":1.0,"end":1.0},{"id":2.0,"text":"尹東柱","type":"SH","scode":"00","weight":1.0,"position":10.0,"begin":2.0,"end":2.0},{"id":3.0,"text":",","type":"SP","scode":"00","weight":1.0,"position":19.0,"begin":3.0,"end":3.0},{"id":4.0,"text":"1917","type":"SN","scode":"00","weight":1.0,"position":21.0,"begin":4.0,"end":4.0},{"id":5.0,"text":"년","type":"NNB","scode":"02","weight":3.3,"position":25.0,"begin":5.0,"end":5.0},{"id":6.0,"text":"12","type":"SN","scode":"00","weight":1.0,"position":29.0,"begin":6.0,"end":6.0},{"id":7.0,"text":"월","type":"NNB","scode":"02","weight":1.0,"position":31.0,"begin":7.0,"end":7.0},{"id":8.0,"text":"30","type":"SN","scode":"00","weight":1.0,"position":35.0,"begin":8.0,"end":8.0},{"id":9.0,"text":"일","type":"NNB","scode":"07","weight":1.0,"position":37.0,"begin":9.0,"end":9.0},{"id":10.0,"text":"~","type":"SO","scode":"00","weight":1.0,"position":41.0,"begin":10.0,"end":10.0},{"id":11.0,"text":"1945","type":"SN","scode":"00","weight":1.0,"position":43.0,"begin":11.0,"end":11.0},{"id":12.0,"text":"년","type":"NNB","scode":"02","weight":1.0,"position":47.0,"begin":12.0,"end":12.0},{"id":13.0,"text":"2","type":"SN","scode":"00","weight":1.0,"position":51.0,"begin":13.0,"end":13.0},{"id":14.0,"text":"월","type":"NNB","scode":"02","weight":3.3,"position":52.0,"begin":14.0,"end":14.0},{"id":15.0,"text":"16","type":"SN","scode":"00","weight":1.0,"position":56.0,"begin":15.0 ...

# %%
import pandas as pd

json_data=json.loads(response.data)
prn_data=json_data["return_object"]['sentence']
prn_data
# Out:
# [{'id': 0.0,
#   'reserve_str': '',
#   'text': '윤동주(尹東柱, 1917년 12월 30일 ~ 1945년 2월 16일)는 한국의 독립운동가, 시인, 작가이다.',
#   'morp': [{'id': 0.0,
#     'lemma': '윤동주',
#     'type': 'NNP',
#     'position': 0.0,
#     'weight': 0.0566805},
#    {'id': 1.0, 'lemma': '(', 'type': 'SS', 'position': 9.0, 'weight': 1.0},
#    {'id': 2.0, 'lemma': '尹東柱', 'type': 'SH', 'position': 10.0, 'weight': 1.0},
#    {'id': 3.0, 'lemma': ',', 'type': 'SP', 'position': 19.0, 'weight': 1.0},
#    {'id': 4.0, 'lemma': '1917', 'type': 'SN', 'position': 21.0, 'weight': 1.0},
#    {'id': 5.0,
#     'lemma': '년',
#     'type': 'NNB',
#     'position': 25.0,
#     'weight': 0.0597013},
#    {'id': 6.0, 'lemma': '12', 'type': 'SN', 'position': 29.0, 'weight': 1.0},
#    {'id': 7.0,
#     'lemma': '월',
#     'type': 'NNB',
#     'position': 31.0,
#     'weight': 0.0583588},
#    {'id': 8.0, 'lemma': '30', 'type': 'SN', 'position': 35.0, 'weight': 1.0},
#    {'id': 9.0,
#     'lemma': '일',
#     'type': 'NNB',
#     'position': 37.0,
#     'weight': 0.0487802},
#    {'id': 10.0, 'lemma': '~', 'type': 'SO', 'position': 41.0, 'weight': 1.0},
#    {'id': 11.0,
#     'lemma': '1945',
#     'type': 'SN',
#     'position': 43.0,
#     'weight': 1.0},
#    {'id': 12.0,
#     'lemma': '년',
#     'type': 'NNB',
#     'position': 47.0,
#     'weight': 0.0518608},
#    {'id': 13.0, 'lemma': '2', 'type': 'SN', 'position': 51.0, 'weight': 1.0},
#    {'id': 14.0,
#     'lemma': '월',
#     'type': 'NNB',
#     'position': 52.0,
#     'weight': 0.0649133},
#    {'id': 15.0, 'lemma': '16', 'type': 'SN', 'position': 56.0, 'weight': 1.0},
#    {'id': 16.0,
#     'lemma': '일',
#     'type': 'NNB',
#     'position': 58.0,
#     'weight': 0.0426752},
#    {'id': 17.0, 'lemma': ')', 'type': 'SS', 'position': 61.0, 'weight': 1.0},
#    {'id': 18.0,
#     'lemma': '는',
#     'type': 'JX',
#     'position': 62.0,
#     'weight': 0.0897092},
#    {'id': 19.0,
#     'lemma': '한국',
#     'type': 'NNP',
#     'position': 66.0,
#     'weight': 0.156358},
#    {'id': 20.0,
#     'lemma': '의',
#     'type': 'JKG',
#     'position': 72.0,
#     'weight': 0.100211},
#    {'id': 21.0,
#     'lemma': '독립',
#     'type': 'NNG',
#     'position': 76.0,
#     'weight': 0.160432},
#    {'id': 22.0,
#     'lemma': '운동',
#     'type': 'NNG',
#     'position': 82.0,
#     'weight': 0.160432},
#    {'id': 23.0,
#     'lemma': '가',
#     'type': 'XSN',
#     'position': 88.0,
#     'weight': 0.160432},
#    {'id': 24.0, 'lemma': ',', 'type': 'SP', 'position': 91.0, 'weight': 1.0},
#    {'id': 25.0,
#     'lemma': '시인',
#     'type': 'NNG',
#     'position': 93.0,
#     'weight': 0.0583063},
#    {'id': 26.0, 'lemma': ',', 'type': 'SP', 'position': 99.0, 'weight': 1.0},
#    {'id': 27.0,
#     'lemma': '작가',
#     'type': 'NNG',
#     'position': 101.0,
#     'weight': 0.0498619},
#    {'id': 28.0,
#     'lemma': '이',
#     'type': 'VCP',
#     'position': 107.0,
#     'weight': 0.0484025},
#    {'id': 29.0,
#     'lemma': '다',
#     'type': 'EF',
#     'position': 110.0,
#     'weight': 0.0749575},
#    {'id': 30.0, 'lemma': '.', 'type': 'SF', 'position': 113.0, 'weight': 1.0}],
#   'WSD': [{'id': 0.0,
#     'text': '윤동주',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 20.0,
#     'position': 0.0,
#     'begin': 0.0,
#     'end': 0.0},
#    {'id': 1.0,
#     'text': '(',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 9.0,
#     'begin': 1.0,
#     'end': 1.0},
#    {'id': 2.0,
#     'text': '尹東柱',
#     'type': 'SH',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 10.0,
#     'begin': 2.0,
#     'end': 2.0},
#    {'id': 3.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 19.0,
#     'begin': 3.0,
#     'end': 3.0},
#    {'id': 4.0,
#     'text': '1917',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 21.0,
#     'begin': 4.0,
#     'end': 4.0},
#    {'id': 5.0,
#     'text': '년',
#     'type': 'NNB',
#     'scode': '02',
#     'weight': 3.3,
#     'position': 25.0,
#     'begin': 5.0,
#     'end': 5.0},
#    {'id': 6.0,
#     'text': '12',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 29.0,
#     'begin': 6.0,
#     'end': 6.0},
#    {'id': 7.0,
#     'text': '월',
#     'type': 'NNB',
#     'scode': '02',
#     'weight': 1.0,
#     'position': 31.0,
#     'begin': 7.0,
#     'end': 7.0},
#    {'id': 8.0,
#     'text': '30',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 35.0,
#     'begin': 8.0,
#     'end': 8.0},
#    {'id': 9.0,
#     'text': '일',
#     'type': 'NNB',
#     'scode': '07',
#     'weight': 1.0,
#     'position': 37.0,
#     'begin': 9.0,
#     'end': 9.0},
#    {'id': 10.0,
#     'text': '~',
#     'type': 'SO',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 41.0,
#     'begin': 10.0,
#     'end': 10.0},
#    {'id': 11.0,
#     'text': '1945',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 43.0,
#     'begin': 11.0,
#     'end': 11.0},
#    {'id': 12.0,
#     'text': '년',
#     'type': 'NNB',
#     'scode': '02',
#     'weight': 1.0,
#     'position': 47.0,
#     'begin': 12.0,
#     'end': 12.0},
#    {'id': 13.0,
#     'text': '2',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 51.0,
#     'begin': 13.0,
#     'end': 13.0},
#    {'id': 14.0,
#     'text': '월',
#     'type': 'NNB',
#     'scode': '02',
#     'weight': 3.3,
#     'position': 52.0,
#     'begin': 14.0,
#     'end': 14.0},
#    {'id': 15.0,
#     'text': '16',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 56.0,
#     'begin': 15.0,
#     'end': 15.0},
#    {'id': 16.0,
#     'text': '일',
#     'type': 'NNB',
#     'scode': '07',
#     'weight': 6.5,
#     'position': 58.0,
#     'begin': 16.0,
#     'end': 16.0},
#    {'id': 17.0,
#     'text': ')',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 61.0,
#     'begin': 17.0,
#     'end': 17.0},
#    {'id': 18.0,
#     'text': '는',
#     'type': 'JX',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 62.0,
#     'begin': 18.0,
#     'end': 18.0},
#    {'id': 19.0,
#     'text': '한국',
#     'type': 'NNP',
#     'scode': '05',
#     'weight': 6.6,
#     'position': 66.0,
#     'begin': 19.0,
#     'end': 19.0},
#    {'id': 20.0,
#     'text': '의',
#     'type': 'JKG',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 72.0,
#     'begin': 20.0,
#     'end': 20.0},
#    {'id': 21.0,
#     'text': '독립',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 76.0,
#     'begin': 21.0,
#     'end': 21.0},
#    {'id': 22.0,
#     'text': '운동가',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 6.7,
#     'position': 82.0,
#     'begin': 22.0,
#     'end': 23.0},
#    {'id': 23.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 91.0,
#     'begin': 24.0,
#     'end': 24.0},
#    {'id': 24.0,
#     'text': '시인',
#     'type': 'NNG',
#     'scode': '10',
#     'weight': 7.53333,
#     'position': 93.0,
#     'begin': 25.0,
#     'end': 25.0},
#    {'id': 25.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 99.0,
#     'begin': 26.0,
#     'end': 26.0},
#    {'id': 26.0,
#     'text': '작가',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 3.2,
#     'position': 101.0,
#     'begin': 27.0,
#     'end': 27.0},
#    {'id': 27.0,
#     'text': '이',
#     'type': 'VCP',
#     'scode': '01',
#     'weight': 1.0,
#     'position': 107.0,
#     'begin': 28.0,
#     'end': 28.0},
#    {'id': 28.0,
#     'text': '다',
#     'type': 'EF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 110.0,
#     'begin': 29.0,
#     'end': 29.0},
#    {'id': 29.0,
#     'text': '.',
#     'type': 'SF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 113.0,
#     'begin': 30.0,
#     'end': 30.0}],
#   'word': [{'id': 0.0,
#     'text': '윤동주(尹東柱,',
#     'type': '',
#     'begin': 0.0,
#     'end': 3.0},
#    {'id': 1.0, 'text': '1917년', 'type': '', 'begin': 4.0, 'end': 5.0},
#    {'id': 2.0, 'text': '12월', 'type': '', 'begin': 6.0, 'end': 7.0},
#    {'id': 3.0, 'text': '30일', 'type': '', 'begin': 8.0, 'end': 9.0},
#    {'id': 4.0, 'text': '~', 'type': '', 'begin': 10.0, 'end': 10.0},
#    {'id': 5.0, 'text': '1945년', 'type': '', 'begin': 11.0, 'end': 12.0},
#    {'id': 6.0, 'text': '2월', 'type': '', 'begin': 13.0, 'end': 14.0},
#    {'id': 7.0, 'text': '16일)는', 'type': '', 'begin': 15.0, 'end': 18.0},
#    {'id': 8.0, 'text': '한국의', 'type': '', 'begin': 19.0, 'end': 20.0},
#    {'id': 9.0, 'text': '독립운동가,', 'type': '', 'begin': 21.0, 'end': 24.0},
#    {'id': 10.0, 'text': '시인,', 'type': '', 'begin': 25.0, 'end': 26.0},
#    {'id': 11.0, 'text': '작가이다.', 'type': '', 'begin': 27.0, 'end': 30.0}],
#   'NE': [{'id': 0.0,
#     'text': '윤동주',
#     'type': 'PS_NAME',
#     'begin': 0.0,
#     'end': 0.0,
#     'weight': 0.389352,
#     'common_noun': 0.0},
#    {'id': 1.0,
#     'text': '尹東柱',
#     'type': 'PS_NAME',
#     'begin': 2.0,
#     'end': 2.0,
#     'weight': 1.0,
#     'common_noun': 0.0},
#    {'id': 2.0,
#     'text': '1917년 12월 30일 ~ 1945년 2월 16일',
#     'type': 'DT_DURATION',
#     'begin': 4.0,
#     'end': 16.0,
#     'weight': 1.0,
#     'common_noun': 0.0},
#    {'id': 3.0,
#     'text': '한국',
#     'type': 'LCP_COUNTRY',
#     'begin': 19.0,
#     'end': 19.0,
#     'weight': 0.583397,
#     'common_noun': 0.0},
#    {'id': 4.0,
#     'text': '독립운동가',
#     'type': 'CV_OCCUPATION',
#     'begin': 21.0,
#     'end': 23.0,
#     'weight': 0.556841,
#     'common_noun': 0.0},
#    {'id': 5.0,
#     'text': '시인',
#     'type': 'CV_OCCUPATION',
#     'begin': 25.0,
#     'end': 25.0,
#     'weight': 0.668102,
#     'common_noun': 0.0},
#    {'id': 6.0,
#     'text': '작가',
#     'type': 'CV_OCCUPATION',
#     'begin': 27.0,
#     'end': 27.0,
#     'weight': 0.466321,
#     'common_noun': 0.0}],
#   'NE_Link': [],
#   'dependency': [],
#   'SRL': []},
#  {'id': 1.0,
#   'reserve_str': '',
#   'text': '중국 만저우 지방 지린 성 연변 용정에서 출생하여 명동학교에서 수학하였고, 숭실중학교와 연희전문학교를 졸업하였다.',
#   'morp': [{'id': 0.0,
#     'lemma': '중국',
#     'type': 'NNP',
#     'position': 114.0,
#     'weight': 0.122298},
#    {'id': 1.0,
#     'lemma': '만저우',
#     'type': 'NNP',
#     'position': 121.0,
#     'weight': 0.0287512},
#    {'id': 2.0,
#     'lemma': '지방',
#     'type': 'NNG',
#     'position': 131.0,
#     'weight': 0.0823577},
#    {'id': 3.0,
#     'lemma': '지리',
#     'type': 'VV',
#     'position': 138.0,
#     'weight': 0.0350485},
#    {'id': 4.0,
#     'lemma': 'ㄴ',
#     'type': 'ETM',
#     'position': 141.0,
#     'weight': 0.0257694},
#    {'id': 5.0,
#     'lemma': '성',
#     'type': 'NNG',
#     'position': 145.0,
#     'weight': 0.0658209},
#    {'id': 6.0,
#     'lemma': '연변',
#     'type': 'NNP',
#     'position': 149.0,
#     'weight': 0.0565261},
#    {'id': 7.0,
#     'lemma': '용정',
#     'type': 'NNP',
#     'position': 156.0,
#     'weight': 0.0567193},
#    {'id': 8.0,
#     'lemma': '에서',
#     'type': 'JKB',
#     'position': 162.0,
#     'weight': 0.0768727},
#    {'id': 9.0,
#     'lemma': '출생',
#     'type': 'NNG',
#     'position': 169.0,
#     'weight': 0.0621906},
#    {'id': 10.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 175.0,
#     'weight': 0.0621906},
#    {'id': 11.0,
#     'lemma': '여',
#     'type': 'EC',
#     'position': 178.0,
#     'weight': 0.0554633},
#    {'id': 12.0,
#     'lemma': '명동',
#     'type': 'NNP',
#     'position': 182.0,
#     'weight': 1.0},
#    {'id': 13.0,
#     'lemma': '학교',
#     'type': 'NNG',
#     'position': 188.0,
#     'weight': 0.0743571},
#    {'id': 14.0,
#     'lemma': '에서',
#     'type': 'JKB',
#     'position': 194.0,
#     'weight': 0.0871505},
#    {'id': 15.0,
#     'lemma': '수학',
#     'type': 'NNG',
#     'position': 201.0,
#     'weight': 0.0428931},
#    {'id': 16.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 207.0,
#     'weight': 0.0428931},
#    {'id': 17.0,
#     'lemma': '였',
#     'type': 'EP',
#     'position': 210.0,
#     'weight': 0.0422369},
#    {'id': 18.0,
#     'lemma': '고',
#     'type': 'EC',
#     'position': 213.0,
#     'weight': 0.0995226},
#    {'id': 19.0, 'lemma': ',', 'type': 'SP', 'position': 216.0, 'weight': 1.0},
#    {'id': 20.0,
#     'lemma': '숭실',
#     'type': 'NNP',
#     'position': 218.0,
#     'weight': 0.0306303},
#    {'id': 21.0,
#     'lemma': '중',
#     'type': 'NNG',
#     'position': 224.0,
#     'weight': 0.0502578},
#    {'id': 22.0,
#     'lemma': '학교',
#     'type': 'NNG',
#     'position': 227.0,
#     'weight': 0.0502578},
#    {'id': 23.0,
#     'lemma': '와',
#     'type': 'JC',
#     'position': 233.0,
#     'weight': 0.0490814},
#    {'id': 24.0,
#     'lemma': '연희',
#     'type': 'NNP',
#     'position': 237.0,
#     'weight': 0.0398019},
#    {'id': 25.0,
#     'lemma': '전문',
#     'type': 'NNG',
#     'position': 243.0,
#     'weight': 0.0691777},
#    {'id': 26.0,
#     'lemma': '학교',
#     'type': 'NNG',
#     'position': 249.0,
#     'weight': 0.0691777},
#    {'id': 27.0,
#     'lemma': '를',
#     'type': 'JKO',
#     'position': 255.0,
#     'weight': 0.108245},
#    {'id': 28.0,
#     'lemma': '졸업',
#     'type': 'NNG',
#     'position': 259.0,
#     'weight': 0.0553247},
#    {'id': 29.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 265.0,
#     'weight': 0.0553247},
#    {'id': 30.0,
#     'lemma': '였',
#     'type': 'EP',
#     'position': 268.0,
#     'weight': 0.0511886},
#    {'id': 31.0,
#     'lemma': '다',
#     'type': 'EF',
#     'position': 271.0,
#     'weight': 0.0896857},
#    {'id': 32.0, 'lemma': '.', 'type': 'SF', 'position': 274.0, 'weight': 1.0}],
#   'WSD': [{'id': 0.0,
#     'text': '중국',
#     'type': 'NNP',
#     'scode': '01',
#     'weight': 2.2,
#     'position': 114.0,
#     'begin': 0.0,
#     'end': 0.0},
#    {'id': 1.0,
#     'text': '만저우',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 121.0,
#     'begin': 1.0,
#     'end': 1.0},
#    {'id': 2.0,
#     'text': '지방',
#     'type': 'NNG',
#     'scode': '05',
#     'weight': 5.5,
#     'position': 131.0,
#     'begin': 2.0,
#     'end': 2.0},
#    {'id': 3.0,
#     'text': '지리',
#     'type': 'VV',
#     'scode': '01',
#     'weight': 1.0,
#     'position': 138.0,
#     'begin': 3.0,
#     'end': 3.0},
#    {'id': 4.0,
#     'text': 'ㄴ',
#     'type': 'ETM',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 141.0,
#     'begin': 4.0,
#     'end': 4.0},
#    {'id': 5.0,
#     'text': '성',
#     'type': 'NNG',
#     'scode': '12',
#     'weight': 2.51429,
#     'position': 145.0,
#     'begin': 5.0,
#     'end': 5.0},
#    {'id': 6.0,
#     'text': '연변',
#     'type': 'NNP',
#     'scode': '02',
#     'weight': 1.0,
#     'position': 149.0,
#     'begin': 6.0,
#     'end': 6.0},
#    {'id': 7.0,
#     'text': '용정',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 156.0,
#     'begin': 7.0,
#     'end': 7.0},
#    {'id': 8.0,
#     'text': '에서',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 162.0,
#     'begin': 8.0,
#     'end': 8.0},
#    {'id': 9.0,
#     'text': '출생하',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 169.0,
#     'begin': 9.0,
#     'end': 10.0},
#    {'id': 10.0,
#     'text': '여',
#     'type': 'EC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 178.0,
#     'begin': 11.0,
#     'end': 11.0},
#    {'id': 11.0,
#     'text': '명동',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 182.0,
#     'begin': 12.0,
#     'end': 12.0},
#    {'id': 12.0,
#     'text': '학교',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 188.0,
#     'begin': 13.0,
#     'end': 13.0},
#    {'id': 13.0,
#     'text': '에서',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 194.0,
#     'begin': 14.0,
#     'end': 14.0},
#    {'id': 14.0,
#     'text': '수학하',
#     'type': 'VV',
#     'scode': '01',
#     'weight': 2.2,
#     'position': 201.0,
#     'begin': 15.0,
#     'end': 16.0},
#    {'id': 15.0,
#     'text': '였',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 210.0,
#     'begin': 17.0,
#     'end': 17.0},
#    {'id': 16.0,
#     'text': '고',
#     'type': 'EC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 213.0,
#     'begin': 18.0,
#     'end': 18.0},
#    {'id': 17.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 216.0,
#     'begin': 19.0,
#     'end': 19.0},
#    {'id': 18.0,
#     'text': '숭실',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 218.0,
#     'begin': 20.0,
#     'end': 20.0},
#    {'id': 19.0,
#     'text': '중학교',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 224.0,
#     'begin': 21.0,
#     'end': 22.0},
#    {'id': 20.0,
#     'text': '와',
#     'type': 'JC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 233.0,
#     'begin': 23.0,
#     'end': 23.0},
#    {'id': 21.0,
#     'text': '연희',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 237.0,
#     'begin': 24.0,
#     'end': 24.0},
#    {'id': 22.0,
#     'text': '전문학교',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 243.0,
#     'begin': 25.0,
#     'end': 26.0},
#    {'id': 23.0,
#     'text': '를',
#     'type': 'JKO',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 255.0,
#     'begin': 27.0,
#     'end': 27.0},
#    {'id': 24.0,
#     'text': '졸업하',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 259.0,
#     'begin': 28.0,
#     'end': 29.0},
#    {'id': 25.0,
#     'text': '였',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 268.0,
#     'begin': 30.0,
#     'end': 30.0},
#    {'id': 26.0,
#     'text': '다',
#     'type': 'EF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 271.0,
#     'begin': 31.0,
#     'end': 31.0},
#    {'id': 27.0,
#     'text': '.',
#     'type': 'SF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 274.0,
#     'begin': 32.0,
#     'end': 32.0}],
#   'word': [{'id': 0.0, 'text': '중국', 'type': '', 'begin': 0.0, 'end': 0.0},
#    {'id': 1.0, 'text': '만저우', 'type': '', 'begin': 1.0, 'end': 1.0},
#    {'id': 2.0, 'text': '지방', 'type': '', 'begin': 2.0, 'end': 2.0},
#    {'id': 3.0, 'text': '지린', 'type': '', 'begin': 3.0, 'end': 4.0},
#    {'id': 4.0, 'text': '성', 'type': '', 'begin': 5.0, 'end': 5.0},
#    {'id': 5.0, 'text': '연변', 'type': '', 'begin': 6.0, 'end': 6.0},
#    {'id': 6.0, 'text': '용정에서', 'type': '', 'begin': 7.0, 'end': 8.0},
#    {'id': 7.0, 'text': '출생하여', 'type': '', 'begin': 9.0, 'end': 11.0},
#    {'id': 8.0, 'text': '명동학교에서', 'type': '', 'begin': 12.0, 'end': 14.0},
#    {'id': 9.0, 'text': '수학하였고,', 'type': '', 'begin': 15.0, 'end': 19.0},
#    {'id': 10.0, 'text': '숭실중학교와', 'type': '', 'begin': 20.0, 'end': 23.0},
#    {'id': 11.0, 'text': '연희전문학교를', 'type': '', 'begin': 24.0, 'end': 27.0},
#    {'id': 12.0, 'text': '졸업하였다.', 'type': '', 'begin': 28.0, 'end': 32.0}],
#   'NE': [{'id': 0.0,
#     'text': '중국',
#     'type': 'LCP_COUNTRY',
#     'begin': 0.0,
#     'end': 0.0,
#     'weight': 0.689047,
#     'common_noun': 0.0},
#    {'id': 1.0,
#     'text': '만저우',
#     'type': 'LCP_PROVINCE',
#     'begin': 1.0,
#     'end': 1.0,
#     'weight': 0.688773,
#     'common_noun': 0.0},
#    {'id': 2.0,
#     'text': '지린 성',
#     'type': 'LCP_PROVINCE',
#     'begin': 3.0,
#     'end': 5.0,
#     'weight': 0.591262,
#     'common_noun': 0.0},
#    {'id': 3.0,
#     'text': '연변',
#     'type': 'LCP_CITY',
#     'begin': 6.0,
#     'end': 6.0,
#     'weight': 0.551269,
#     'common_noun': 0.0},
#    {'id': 4.0,
#     'text': '용정',
#     'type': 'LCP_COUNTY',
#     'begin': 7.0,
#     'end': 7.0,
#     'weight': 0.747056,
#     'common_noun': 0.0},
#    {'id': 5.0,
#     'text': '명동학교',
#     'type': 'OGG_EDUCATION',
#     'begin': 12.0,
#     'end': 13.0,
#     'weight': 0.234722,
#     'common_noun': 0.0},
#    {'id': 6.0,
#     'text': '숭실중학교',
#     'type': 'OGG_EDUCATION',
#     'begin': 20.0,
#     'end': 22.0,
#     'weight': 0.649397,
#     'common_noun': 0.0},
#    {'id': 7.0,
#     'text': '연희전문학교',
#     'type': 'OGG_EDUCATION',
#     'begin': 24.0,
#     'end': 26.0,
#     'weight': 0.807503,
#     'common_noun': 0.0}],
#   'NE_Link': [],
#   'dependency': [],
#   'SRL': []},
#  {'id': 2.0,
#   'reserve_str': '',
#   'text': ' 숭실중학교 때 처음 시를 발표하였고, 1939년 연희전문 2학년 재학 중 소년(少年) 지에 시를 발표하며 정식으로 문단에 데뷔했다.',
#   'morp': [{'id': 0.0,
#     'lemma': '숭실',
#     'type': 'NNP',
#     'position': 276.0,
#     'weight': 0.038762},
#    {'id': 1.0,
#     'lemma': '중',
#     'type': 'NNG',
#     'position': 282.0,
#     'weight': 0.0391093},
#    {'id': 2.0,
#     'lemma': '학교',
#     'type': 'NNG',
#     'position': 285.0,
#     'weight': 0.0391093},
#    {'id': 3.0,
#     'lemma': '때',
#     'type': 'NNG',
#     'position': 292.0,
#     'weight': 0.129692},
#    {'id': 4.0,
#     'lemma': '처음',
#     'type': 'NNG',
#     'position': 296.0,
#     'weight': 0.0639952},
#    {'id': 5.0,
#     'lemma': '시',
#     'type': 'NNG',
#     'position': 303.0,
#     'weight': 0.0451564},
#    {'id': 6.0,
#     'lemma': '를',
#     'type': 'JKO',
#     'position': 306.0,
#     'weight': 0.107295},
#    {'id': 7.0,
#     'lemma': '발표',
#     'type': 'NNG',
#     'position': 310.0,
#     'weight': 0.0499287},
#    {'id': 8.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 316.0,
#     'weight': 0.0499287},
#    {'id': 9.0,
#     'lemma': '였',
#     'type': 'EP',
#     'position': 319.0,
#     'weight': 0.0443303},
#    {'id': 10.0,
#     'lemma': '고',
#     'type': 'EC',
#     'position': 322.0,
#     'weight': 0.101443},
#    {'id': 11.0, 'lemma': ',', 'type': 'SP', 'position': 325.0, 'weight': 1.0},
#    {'id': 12.0,
#     'lemma': '1939',
#     'type': 'SN',
#     'position': 327.0,
#     'weight': 1.0},
#    {'id': 13.0,
#     'lemma': '년',
#     'type': 'NNB',
#     'position': 331.0,
#     'weight': 0.0593733},
#    {'id': 14.0,
#     'lemma': '연희',
#     'type': 'NNP',
#     'position': 335.0,
#     'weight': 0.0513281},
#    {'id': 15.0,
#     'lemma': '전문',
#     'type': 'NNG',
#     'position': 341.0,
#     'weight': 0.0469005},
#    {'id': 16.0, 'lemma': '2', 'type': 'SN', 'position': 348.0, 'weight': 1.0},
#    {'id': 17.0,
#     'lemma': '학년',
#     'type': 'NNG',
#     'position': 349.0,
#     'weight': 0.0681781},
#    {'id': 18.0,
#     'lemma': '재학',
#     'type': 'NNG',
#     'position': 356.0,
#     'weight': 0.0868406},
#    {'id': 19.0,
#     'lemma': '중',
#     'type': 'NNB',
#     'position': 363.0,
#     'weight': 0.117578},
#    {'id': 20.0,
#     'lemma': '소년',
#     'type': 'NNG',
#     'position': 367.0,
#     'weight': 1.0},
#    {'id': 21.0, 'lemma': '(', 'type': 'SS', 'position': 373.0, 'weight': 1.0},
#    {'id': 22.0, 'lemma': '少年', 'type': 'SH', 'position': 374.0, 'weight': 1.0},
#    {'id': 23.0, 'lemma': ')', 'type': 'SS', 'position': 380.0, 'weight': 1.0},
#    {'id': 24.0,
#     'lemma': '지',
#     'type': 'NNG',
#     'position': 382.0,
#     'weight': 0.0205648},
#    {'id': 25.0,
#     'lemma': '에',
#     'type': 'JKB',
#     'position': 385.0,
#     'weight': 0.0814017},
#    {'id': 26.0,
#     'lemma': '시',
#     'type': 'NNG',
#     'position': 389.0,
#     'weight': 0.070908},
#    {'id': 27.0,
#     'lemma': '를',
#     'type': 'JKO',
#     'position': 392.0,
#     'weight': 0.114907},
#    {'id': 28.0,
#     'lemma': '발표',
#     'type': 'NNG',
#     'position': 396.0,
#     'weight': 0.031119},
#    {'id': 29.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 402.0,
#     'weight': 0.031119},
#    {'id': 30.0,
#     'lemma': '며',
#     'type': 'EC',
#     'position': 405.0,
#     'weight': 0.13048},
#    {'id': 31.0,
#     'lemma': '정식',
#     'type': 'NNG',
#     'position': 409.0,
#     'weight': 0.0779634},
#    {'id': 32.0,
#     'lemma': '으로',
#     'type': 'JKB',
#     'position': 415.0,
#     'weight': 0.069591},
#    {'id': 33.0,
#     'lemma': '문단',
#     'type': 'NNG',
#     'position': 422.0,
#     'weight': 0.0698656},
#    {'id': 34.0,
#     'lemma': '에',
#     'type': 'JKB',
#     'position': 428.0,
#     'weight': 0.0906228},
#    {'id': 35.0,
#     'lemma': '데뷔',
#     'type': 'NNG',
#     'position': 432.0,
#     'weight': 0.0366732},
#    {'id': 36.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 438.0,
#     'weight': 0.0366732},
#    {'id': 37.0,
#     'lemma': '었',
#     'type': 'EP',
#     'position': 438.0,
#     'weight': 0.0278956},
#    {'id': 38.0,
#     'lemma': '다',
#     'type': 'EF',
#     'position': 441.0,
#     'weight': 0.0919921},
#    {'id': 39.0, 'lemma': '.', 'type': 'SF', 'position': 444.0, 'weight': 1.0}],
#   'WSD': [{'id': 0.0,
#     'text': '숭실',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 276.0,
#     'begin': 0.0,
#     'end': 0.0},
#    {'id': 1.0,
#     'text': '중학교',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 282.0,
#     'begin': 1.0,
#     'end': 2.0},
#    {'id': 2.0,
#     'text': '때',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 8.8,
#     'position': 292.0,
#     'begin': 3.0,
#     'end': 3.0},
#    {'id': 3.0,
#     'text': '처음',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 296.0,
#     'begin': 4.0,
#     'end': 4.0},
#    {'id': 4.0,
#     'text': '시',
#     'type': 'NNG',
#     'scode': '13',
#     'weight': 5.36563,
#     'position': 303.0,
#     'begin': 5.0,
#     'end': 5.0},
#    {'id': 5.0,
#     'text': '를',
#     'type': 'JKO',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 306.0,
#     'begin': 6.0,
#     'end': 6.0},
#    {'id': 6.0,
#     'text': '발표하',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 310.0,
#     'begin': 7.0,
#     'end': 8.0},
#    {'id': 7.0,
#     'text': '였',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 319.0,
#     'begin': 9.0,
#     'end': 9.0},
#    {'id': 8.0,
#     'text': '고',
#     'type': 'EC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 322.0,
#     'begin': 10.0,
#     'end': 10.0},
#    {'id': 9.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 325.0,
#     'begin': 11.0,
#     'end': 11.0},
#    {'id': 10.0,
#     'text': '1939',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 327.0,
#     'begin': 12.0,
#     'end': 12.0},
#    {'id': 11.0,
#     'text': '년',
#     'type': 'NNB',
#     'scode': '02',
#     'weight': 10.9,
#     'position': 331.0,
#     'begin': 13.0,
#     'end': 13.0},
#    {'id': 12.0,
#     'text': '연희',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 335.0,
#     'begin': 14.0,
#     'end': 14.0},
#    {'id': 13.0,
#     'text': '전문',
#     'type': 'NNG',
#     'scode': '08',
#     'weight': 2.2,
#     'position': 341.0,
#     'begin': 15.0,
#     'end': 15.0},
#    {'id': 14.0,
#     'text': '2',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 348.0,
#     'begin': 16.0,
#     'end': 16.0},
#    {'id': 15.0,
#     'text': '학년',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 349.0,
#     'begin': 17.0,
#     'end': 17.0},
#    {'id': 16.0,
#     'text': '재학',
#     'type': 'NNG',
#     'scode': '02',
#     'weight': 3.2,
#     'position': 356.0,
#     'begin': 18.0,
#     'end': 18.0},
#    {'id': 17.0,
#     'text': '중',
#     'type': 'NNB',
#     'scode': '04',
#     'weight': 4.2,
#     'position': 363.0,
#     'begin': 19.0,
#     'end': 19.0},
#    {'id': 18.0,
#     'text': '소년',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 22.0,
#     'position': 367.0,
#     'begin': 20.0,
#     'end': 20.0},
#    {'id': 19.0,
#     'text': '(',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 373.0,
#     'begin': 21.0,
#     'end': 21.0},
#    {'id': 20.0,
#     'text': '少年',
#     'type': 'SH',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 374.0,
#     'begin': 22.0,
#     'end': 22.0},
#    {'id': 21.0,
#     'text': ')',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 380.0,
#     'begin': 23.0,
#     'end': 23.0},
#    {'id': 22.0,
#     'text': '지',
#     'type': 'NNG',
#     'scode': '13',
#     'weight': 1.0,
#     'position': 382.0,
#     'begin': 24.0,
#     'end': 24.0},
#    {'id': 23.0,
#     'text': '에',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 385.0,
#     'begin': 25.0,
#     'end': 25.0},
#    {'id': 24.0,
#     'text': '시',
#     'type': 'NNG',
#     'scode': '13',
#     'weight': 4.9,
#     'position': 389.0,
#     'begin': 26.0,
#     'end': 26.0},
#    {'id': 25.0,
#     'text': '를',
#     'type': 'JKO',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 392.0,
#     'begin': 27.0,
#     'end': 27.0},
#    {'id': 26.0,
#     'text': '발표하',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 396.0,
#     'begin': 28.0,
#     'end': 29.0},
#    {'id': 27.0,
#     'text': '며',
#     'type': 'EC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 405.0,
#     'begin': 30.0,
#     'end': 30.0},
#    {'id': 28.0,
#     'text': '정식',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 2.0,
#     'position': 409.0,
#     'begin': 31.0,
#     'end': 31.0},
#    {'id': 29.0,
#     'text': '으로',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 415.0,
#     'begin': 32.0,
#     'end': 32.0},
#    {'id': 30.0,
#     'text': '문단',
#     'type': 'NNG',
#     'scode': '02',
#     'weight': 5.4,
#     'position': 422.0,
#     'begin': 33.0,
#     'end': 33.0},
#    {'id': 31.0,
#     'text': '에',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 428.0,
#     'begin': 34.0,
#     'end': 34.0},
#    {'id': 32.0,
#     'text': '데뷔하',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 432.0,
#     'begin': 35.0,
#     'end': 36.0},
#    {'id': 33.0,
#     'text': '었',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 438.0,
#     'begin': 37.0,
#     'end': 37.0},
#    {'id': 34.0,
#     'text': '다',
#     'type': 'EF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 441.0,
#     'begin': 38.0,
#     'end': 38.0},
#    {'id': 35.0,
#     'text': '.',
#     'type': 'SF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 444.0,
#     'begin': 39.0,
#     'end': 39.0}],
#   'word': [{'id': 0.0, 'text': '숭실중학교', 'type': '', 'begin': 0.0, 'end': 2.0},
#    {'id': 1.0, 'text': '때', 'type': '', 'begin': 3.0, 'end': 3.0},
#    {'id': 2.0, 'text': '처음', 'type': '', 'begin': 4.0, 'end': 4.0},
#    {'id': 3.0, 'text': '시를', 'type': '', 'begin': 5.0, 'end': 6.0},
#    {'id': 4.0, 'text': '발표하였고,', 'type': '', 'begin': 7.0, 'end': 11.0},
#    {'id': 5.0, 'text': '1939년', 'type': '', 'begin': 12.0, 'end': 13.0},
#    {'id': 6.0, 'text': '연희전문', 'type': '', 'begin': 14.0, 'end': 15.0},
#    {'id': 7.0, 'text': '2학년', 'type': '', 'begin': 16.0, 'end': 17.0},
#    {'id': 8.0, 'text': '재학', 'type': '', 'begin': 18.0, 'end': 18.0},
#    {'id': 9.0, 'text': '중', 'type': '', 'begin': 19.0, 'end': 19.0},
#    {'id': 10.0, 'text': '소년(少年)', 'type': '', 'begin': 20.0, 'end': 23.0},
#    {'id': 11.0, 'text': '지에', 'type': '', 'begin': 24.0, 'end': 25.0},
#    {'id': 12.0, 'text': '시를', 'type': '', 'begin': 26.0, 'end': 27.0},
#    {'id': 13.0, 'text': '발표하며', 'type': '', 'begin': 28.0, 'end': 30.0},
#    {'id': 14.0, 'text': '정식으로', 'type': '', 'begin': 31.0, 'end': 32.0},
#    {'id': 15.0, 'text': '문단에', 'type': '', 'begin': 33.0, 'end': 34.0},
#    {'id': 16.0, 'text': '데뷔했다.', 'type': '', 'begin': 35.0, 'end': 39.0}],
#   'NE': [{'id': 0.0,
#     'text': '숭실중학교',
#     'type': 'OGG_EDUCATION',
#     'begin': 0.0,
#     'end': 2.0,
#     'weight': 0.404543,
#     'common_noun': 0.0},
#    {'id': 1.0,
#     'text': '시',
#     'type': 'FD_ART',
#     'begin': 5.0,
#     'end': 5.0,
#     'weight': 0.302479,
#     'common_noun': 0.0},
#    {'id': 2.0,
#     'text': '1939년',
#     'type': 'DT_YEAR',
#     'begin': 12.0,
#     'end': 13.0,
#     'weight': 0.852788,
#     'common_noun': 0.0},
#    {'id': 3.0,
#     'text': '연희전문',
#     'type': 'OGG_EDUCATION',
#     'begin': 14.0,
#     'end': 15.0,
#     'weight': 0.37026,
#     'common_noun': 0.0},
#    {'id': 4.0,
#     'text': '2학년',
#     'type': 'QT_ORDER',
#     'begin': 16.0,
#     'end': 17.0,
#     'weight': 0.682699,
#     'common_noun': 0.0},
#    {'id': 5.0,
#     'text': '시',
#     'type': 'FD_ART',
#     'begin': 26.0,
#     'end': 26.0,
#     'weight': 0.346866,
#     'common_noun': 0.0}],
#   'NE_Link': [],
#   'dependency': [],
#   'SRL': []},
#  {'id': 3.0,
#   'reserve_str': '',
#   'text': '일본 유학 후 도시샤 대학 재학 중 , 1943년 항일운동을 했다는 혐의로 일본 경찰에 체포되어 후쿠오카 형무소(福岡刑務所)에 투옥, 100여 편의 시를 남기고 27세의 나이에 옥중에서 요절하였다.',
#   'morp': [{'id': 0.0,
#     'lemma': '일본',
#     'type': 'NNP',
#     'position': 445.0,
#     'weight': 0.0928186},
#    {'id': 1.0,
#     'lemma': '유학',
#     'type': 'NNG',
#     'position': 452.0,
#     'weight': 0.10041},
#    {'id': 2.0,
#     'lemma': '후',
#     'type': 'NNG',
#     'position': 459.0,
#     'weight': 0.102839},
#    {'id': 3.0,
#     'lemma': '도시샤',
#     'type': 'NNP',
#     'position': 463.0,
#     'weight': 0.0260959},
#    {'id': 4.0,
#     'lemma': '대학',
#     'type': 'NNG',
#     'position': 473.0,
#     'weight': 0.082479},
#    {'id': 5.0,
#     'lemma': '재학',
#     'type': 'NNG',
#     'position': 480.0,
#     'weight': 0.0877284},
#    {'id': 6.0,
#     'lemma': '중',
#     'type': 'NNB',
#     'position': 487.0,
#     'weight': 0.121254},
#    {'id': 7.0, 'lemma': ',', 'type': 'SP', 'position': 491.0, 'weight': 1.0},
#    {'id': 8.0,
#     'lemma': '1943',
#     'type': 'SN',
#     'position': 493.0,
#     'weight': 1.0},
#    {'id': 9.0,
#     'lemma': '년',
#     'type': 'NNB',
#     'position': 497.0,
#     'weight': 0.0619438},
#    {'id': 10.0,
#     'lemma': '항일',
#     'type': 'NNG',
#     'position': 501.0,
#     'weight': 0.0739251},
#    {'id': 11.0,
#     'lemma': '운동',
#     'type': 'NNG',
#     'position': 507.0,
#     'weight': 0.0686174},
#    {'id': 12.0,
#     'lemma': '을',
#     'type': 'JKO',
#     'position': 513.0,
#     'weight': 0.0975852},
#    {'id': 13.0,
#     'lemma': '하',
#     'type': 'VV',
#     'position': 517.0,
#     'weight': 0.0777991},
#    {'id': 14.0,
#     'lemma': '었',
#     'type': 'EP',
#     'position': 517.0,
#     'weight': 0.0777991},
#    {'id': 15.0,
#     'lemma': '다는',
#     'type': 'ETM',
#     'position': 520.0,
#     'weight': 0.0706352},
#    {'id': 16.0,
#     'lemma': '혐의',
#     'type': 'NNG',
#     'position': 527.0,
#     'weight': 0.116567},
#    {'id': 17.0,
#     'lemma': '로',
#     'type': 'JKB',
#     'position': 533.0,
#     'weight': 0.0725723},
#    {'id': 18.0,
#     'lemma': '일본',
#     'type': 'NNP',
#     'position': 537.0,
#     'weight': 0.156386},
#    {'id': 19.0,
#     'lemma': '경찰',
#     'type': 'NNG',
#     'position': 544.0,
#     'weight': 0.118549},
#    {'id': 20.0,
#     'lemma': '에',
#     'type': 'JKB',
#     'position': 550.0,
#     'weight': 0.0908622},
#    {'id': 21.0,
#     'lemma': '체포',
#     'type': 'NNG',
#     'position': 554.0,
#     'weight': 0.0516772},
#    {'id': 22.0,
#     'lemma': '되',
#     'type': 'XSV',
#     'position': 560.0,
#     'weight': 0.0516772},
#    {'id': 23.0,
#     'lemma': '어',
#     'type': 'EC',
#     'position': 563.0,
#     'weight': 0.149917},
#    {'id': 24.0,
#     'lemma': '후쿠오카',
#     'type': 'NNP',
#     'position': 567.0,
#     'weight': 0.047111},
#    {'id': 25.0,
#     'lemma': '형무',
#     'type': 'NNG',
#     'position': 580.0,
#     'weight': 0.0793601},
#    {'id': 26.0,
#     'lemma': '소',
#     'type': 'XSN',
#     'position': 586.0,
#     'weight': 0.0793601},
#    {'id': 27.0, 'lemma': '(', 'type': 'SS', 'position': 589.0, 'weight': 1.0},
#    {'id': 28.0,
#     'lemma': '福岡刑務所',
#     'type': 'SH',
#     'position': 590.0,
#     'weight': 1.0},
#    {'id': 29.0, 'lemma': ')', 'type': 'SS', 'position': 605.0, 'weight': 1.0},
#    {'id': 30.0,
#     'lemma': '에',
#     'type': 'JKB',
#     'position': 606.0,
#     'weight': 0.0977409},
#    {'id': 31.0,
#     'lemma': '투옥',
#     'type': 'NNG',
#     'position': 610.0,
#     'weight': 0.0371062},
#    {'id': 32.0, 'lemma': ',', 'type': 'SP', 'position': 616.0, 'weight': 1.0},
#    {'id': 33.0,
#     'lemma': '100',
#     'type': 'SN',
#     'position': 618.0,
#     'weight': 1.0},
#    {'id': 34.0,
#     'lemma': '여',
#     'type': 'XSN',
#     'position': 621.0,
#     'weight': 0.0725793},
#    {'id': 35.0,
#     'lemma': '편',
#     'type': 'NNB',
#     'position': 625.0,
#     'weight': 0.0994089},
#    {'id': 36.0,
#     'lemma': '의',
#     'type': 'JKG',
#     'position': 628.0,
#     'weight': 0.125183},
#    {'id': 37.0,
#     'lemma': '시',
#     'type': 'NNG',
#     'position': 632.0,
#     'weight': 0.0841059},
#    {'id': 38.0,
#     'lemma': '를',
#     'type': 'JKO',
#     'position': 635.0,
#     'weight': 0.118176},
#    {'id': 39.0,
#     'lemma': '남기',
#     'type': 'VV',
#     'position': 639.0,
#     'weight': 0.0717664},
#    {'id': 40.0,
#     'lemma': '고',
#     'type': 'EC',
#     'position': 645.0,
#     'weight': 0.092647},
#    {'id': 41.0, 'lemma': '27', 'type': 'SN', 'position': 649.0, 'weight': 1.0},
#    {'id': 42.0,
#     'lemma': '세',
#     'type': 'NNB',
#     'position': 651.0,
#     'weight': 0.0479291},
#    {'id': 43.0,
#     'lemma': '의',
#     'type': 'JKG',
#     'position': 654.0,
#     'weight': 0.0915571},
#    {'id': 44.0,
#     'lemma': '나이',
#     'type': 'NNG',
#     'position': 658.0,
#     'weight': 0.0907443},
#    {'id': 45.0,
#     'lemma': '에',
#     'type': 'JKB',
#     'position': 664.0,
#     'weight': 0.0871701},
#    {'id': 46.0,
#     'lemma': '옥중',
#     'type': 'NNG',
#     'position': 668.0,
#     'weight': 0.0580165},
#    {'id': 47.0,
#     'lemma': '에서',
#     'type': 'JKB',
#     'position': 674.0,
#     'weight': 0.0822538},
#    {'id': 48.0,
#     'lemma': '요절',
#     'type': 'NNG',
#     'position': 681.0,
#     'weight': 0.0391344},
#    {'id': 49.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 687.0,
#     'weight': 0.0391344},
#    {'id': 50.0,
#     'lemma': '였',
#     'type': 'EP',
#     'position': 690.0,
#     'weight': 0.051011},
#    {'id': 51.0,
#     'lemma': '다',
#     'type': 'EF',
#     'position': 693.0,
#     'weight': 0.089697},
#    {'id': 52.0, 'lemma': '.', 'type': 'SF', 'position': 696.0, 'weight': 1.0}],
#   'WSD': [{'id': 0.0,
#     'text': '일본',
#     'type': 'NNP',
#     'scode': '02',
#     'weight': 4.4,
#     'position': 445.0,
#     'begin': 0.0,
#     'end': 0.0},
#    {'id': 1.0,
#     'text': '유학',
#     'type': 'NNG',
#     'scode': '04',
#     'weight': 5.46053,
#     'position': 452.0,
#     'begin': 1.0,
#     'end': 1.0},
#    {'id': 2.0,
#     'text': '후',
#     'type': 'NNG',
#     'scode': '08',
#     'weight': 7.64737,
#     'position': 459.0,
#     'begin': 2.0,
#     'end': 2.0},
#    {'id': 3.0,
#     'text': '도시샤',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 463.0,
#     'begin': 3.0,
#     'end': 3.0},
#    {'id': 4.0,
#     'text': '대학',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 4.4,
#     'position': 473.0,
#     'begin': 4.0,
#     'end': 4.0},
#    {'id': 5.0,
#     'text': '재학',
#     'type': 'NNG',
#     'scode': '02',
#     'weight': 2.2,
#     'position': 480.0,
#     'begin': 5.0,
#     'end': 5.0},
#    {'id': 6.0,
#     'text': '중',
#     'type': 'NNB',
#     'scode': '04',
#     'weight': 4.4,
#     'position': 487.0,
#     'begin': 6.0,
#     'end': 6.0},
#    {'id': 7.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 491.0,
#     'begin': 7.0,
#     'end': 7.0},
#    {'id': 8.0,
#     'text': '1943',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 493.0,
#     'begin': 8.0,
#     'end': 8.0},
#    {'id': 9.0,
#     'text': '년',
#     'type': 'NNB',
#     'scode': '02',
#     'weight': 6.54462,
#     'position': 497.0,
#     'begin': 9.0,
#     'end': 9.0},
#    {'id': 10.0,
#     'text': '항일운동',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 501.0,
#     'begin': 10.0,
#     'end': 11.0},
#    {'id': 11.0,
#     'text': '을',
#     'type': 'JKO',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 513.0,
#     'begin': 12.0,
#     'end': 12.0},
#    {'id': 12.0,
#     'text': '하',
#     'type': 'VV',
#     'scode': '01',
#     'weight': 9.9,
#     'position': 517.0,
#     'begin': 13.0,
#     'end': 13.0},
#    {'id': 13.0,
#     'text': '었',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 517.0,
#     'begin': 14.0,
#     'end': 14.0},
#    {'id': 14.0,
#     'text': '다는',
#     'type': 'ETM',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 520.0,
#     'begin': 15.0,
#     'end': 15.0},
#    {'id': 15.0,
#     'text': '혐의',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 527.0,
#     'begin': 16.0,
#     'end': 16.0},
#    {'id': 16.0,
#     'text': '로',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 533.0,
#     'begin': 17.0,
#     'end': 17.0},
#    {'id': 17.0,
#     'text': '일본',
#     'type': 'NNP',
#     'scode': '02',
#     'weight': 8.8,
#     'position': 537.0,
#     'begin': 18.0,
#     'end': 18.0},
#    {'id': 18.0,
#     'text': '경찰',
#     'type': 'NNG',
#     'scode': '04',
#     'weight': 6.02336,
#     'position': 544.0,
#     'begin': 19.0,
#     'end': 19.0},
#    {'id': 19.0,
#     'text': '에',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 550.0,
#     'begin': 20.0,
#     'end': 20.0},
#    {'id': 20.0,
#     'text': '체포되',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 554.0,
#     'begin': 21.0,
#     'end': 22.0},
#    {'id': 21.0,
#     'text': '어',
#     'type': 'EC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 563.0,
#     'begin': 23.0,
#     'end': 23.0},
#    {'id': 22.0,
#     'text': '후쿠오카',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 567.0,
#     'begin': 24.0,
#     'end': 24.0},
#    {'id': 23.0,
#     'text': '형무소',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 580.0,
#     'begin': 25.0,
#     'end': 26.0},
#    {'id': 24.0,
#     'text': '(',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 589.0,
#     'begin': 27.0,
#     'end': 27.0},
#    {'id': 25.0,
#     'text': '福岡刑務所',
#     'type': 'SH',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 590.0,
#     'begin': 28.0,
#     'end': 28.0},
#    {'id': 26.0,
#     'text': ')',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 605.0,
#     'begin': 29.0,
#     'end': 29.0},
#    {'id': 27.0,
#     'text': '에',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 606.0,
#     'begin': 30.0,
#     'end': 30.0},
#    {'id': 28.0,
#     'text': '투옥',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 610.0,
#     'begin': 31.0,
#     'end': 31.0},
#    {'id': 29.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 616.0,
#     'begin': 32.0,
#     'end': 32.0},
#    {'id': 30.0,
#     'text': '100',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 618.0,
#     'begin': 33.0,
#     'end': 33.0},
#    {'id': 31.0,
#     'text': '여',
#     'type': 'XSN',
#     'scode': '27',
#     'weight': 1.0,
#     'position': 621.0,
#     'begin': 34.0,
#     'end': 34.0},
#    {'id': 32.0,
#     'text': '편',
#     'type': 'NNB',
#     'scode': '09',
#     'weight': 4.4,
#     'position': 625.0,
#     'begin': 35.0,
#     'end': 35.0},
#    {'id': 33.0,
#     'text': '의',
#     'type': 'JKG',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 628.0,
#     'begin': 36.0,
#     'end': 36.0},
#    {'id': 34.0,
#     'text': '시',
#     'type': 'NNG',
#     'scode': '13',
#     'weight': 2.14737,
#     'position': 632.0,
#     'begin': 37.0,
#     'end': 37.0},
#    {'id': 35.0,
#     'text': '를',
#     'type': 'JKO',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 635.0,
#     'begin': 38.0,
#     'end': 38.0},
#    {'id': 36.0,
#     'text': '남기',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 639.0,
#     'begin': 39.0,
#     'end': 39.0},
#    {'id': 37.0,
#     'text': '고',
#     'type': 'EC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 645.0,
#     'begin': 40.0,
#     'end': 40.0},
#    {'id': 38.0,
#     'text': '27',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 649.0,
#     'begin': 41.0,
#     'end': 41.0},
#    {'id': 39.0,
#     'text': '세',
#     'type': 'NNB',
#     'scode': '13',
#     'weight': 7.38947,
#     'position': 651.0,
#     'begin': 42.0,
#     'end': 42.0},
#    {'id': 40.0,
#     'text': '의',
#     'type': 'JKG',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 654.0,
#     'begin': 43.0,
#     'end': 43.0},
#    {'id': 41.0,
#     'text': '나이',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 4.2,
#     'position': 658.0,
#     'begin': 44.0,
#     'end': 44.0},
#    {'id': 42.0,
#     'text': '에',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 664.0,
#     'begin': 45.0,
#     'end': 45.0},
#    {'id': 43.0,
#     'text': '옥중',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 668.0,
#     'begin': 46.0,
#     'end': 46.0},
#    {'id': 44.0,
#     'text': '에서',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 674.0,
#     'begin': 47.0,
#     'end': 47.0},
#    {'id': 45.0,
#     'text': '요절하',
#     'type': 'VV',
#     'scode': '01',
#     'weight': 1.0,
#     'position': 681.0,
#     'begin': 48.0,
#     'end': 49.0},
#    {'id': 46.0,
#     'text': '였',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 690.0,
#     'begin': 50.0,
#     'end': 50.0},
#    {'id': 47.0,
#     'text': '다',
#     'type': 'EF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 693.0,
#     'begin': 51.0,
#     'end': 51.0},
#    {'id': 48.0,
#     'text': '.',
#     'type': 'SF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 696.0,
#     'begin': 52.0,
#     'end': 52.0}],
#   'word': [{'id': 0.0, 'text': '일본', 'type': '', 'begin': 0.0, 'end': 0.0},
#    {'id': 1.0, 'text': '유학', 'type': '', 'begin': 1.0, 'end': 1.0},
#    {'id': 2.0, 'text': '후', 'type': '', 'begin': 2.0, 'end': 2.0},
#    {'id': 3.0, 'text': '도시샤', 'type': '', 'begin': 3.0, 'end': 3.0},
#    {'id': 4.0, 'text': '대학', 'type': '', 'begin': 4.0, 'end': 4.0},
#    {'id': 5.0, 'text': '재학', 'type': '', 'begin': 5.0, 'end': 5.0},
#    {'id': 6.0, 'text': '중', 'type': '', 'begin': 6.0, 'end': 6.0},
#    {'id': 7.0, 'text': ',', 'type': '', 'begin': 7.0, 'end': 7.0},
#    {'id': 8.0, 'text': '1943년', 'type': '', 'begin': 8.0, 'end': 9.0},
#    {'id': 9.0, 'text': '항일운동을', 'type': '', 'begin': 10.0, 'end': 12.0},
#    {'id': 10.0, 'text': '했다는', 'type': '', 'begin': 13.0, 'end': 15.0},
#    {'id': 11.0, 'text': '혐의로', 'type': '', 'begin': 16.0, 'end': 17.0},
#    {'id': 12.0, 'text': '일본', 'type': '', 'begin': 18.0, 'end': 18.0},
#    {'id': 13.0, 'text': '경찰에', 'type': '', 'begin': 19.0, 'end': 20.0},
#    {'id': 14.0, 'text': '체포되어', 'type': '', 'begin': 21.0, 'end': 23.0},
#    {'id': 15.0, 'text': '후쿠오카', 'type': '', 'begin': 24.0, 'end': 24.0},
#    {'id': 16.0, 'text': '형무소(福岡刑務所)에', 'type': '', 'begin': 25.0, 'end': 30.0},
#    {'id': 17.0, 'text': '투옥,', 'type': '', 'begin': 31.0, 'end': 32.0},
#    {'id': 18.0, 'text': '100여', 'type': '', 'begin': 33.0, 'end': 34.0},
#    {'id': 19.0, 'text': '편의', 'type': '', 'begin': 35.0, 'end': 36.0},
#    {'id': 20.0, 'text': '시를', 'type': '', 'begin': 37.0, 'end': 38.0},
#    {'id': 21.0, 'text': '남기고', 'type': '', 'begin': 39.0, 'end': 40.0},
#    {'id': 22.0, 'text': '27세의', 'type': '', 'begin': 41.0, 'end': 43.0},
#    {'id': 23.0, 'text': '나이에', 'type': '', 'begin': 44.0, 'end': 45.0},
#    {'id': 24.0, 'text': '옥중에서', 'type': '', 'begin': 46.0, 'end': 47.0},
#    {'id': 25.0, 'text': '요절하였다.', 'type': '', 'begin': 48.0, 'end': 52.0}],
#   'NE': [{'id': 0.0,
#     'text': '일본',
#     'type': 'LCP_COUNTRY',
#     'begin': 0.0,
#     'end': 0.0,
#     'weight': 0.692327,
#     'common_noun': 0.0},
#    {'id': 1.0,
#     'text': '도시샤 대학',
#     'type': 'OGG_EDUCATION',
#     'begin': 3.0,
#     'end': 4.0,
#     'weight': 0.297715,
#     'common_noun': 0.0},
#    {'id': 2.0,
#     'text': '1943년',
#     'type': 'DT_YEAR',
#     'begin': 8.0,
#     'end': 9.0,
#     'weight': 0.817256,
#     'common_noun': 0.0},
#    {'id': 3.0,
#     'text': '일본',
#     'type': 'LCP_COUNTRY',
#     'begin': 18.0,
#     'end': 18.0,
#     'weight': 0.614728,
#     'common_noun': 0.0},
#    {'id': 4.0,
#     'text': '경찰',
#     'type': 'CV_OCCUPATION',
#     'begin': 19.0,
#     'end': 19.0,
#     'weight': 0.336648,
#     'common_noun': 0.0},
#    {'id': 5.0,
#     'text': '후쿠오카 형무소',
#     'type': 'LC_OTHERS',
#     'begin': 24.0,
#     'end': 26.0,
#     'weight': 0.23565,
#     'common_noun': 0.0},
#    {'id': 6.0,
#     'text': '福岡刑務所',
#     'type': 'LC_OTHERS',
#     'begin': 28.0,
#     'end': 28.0,
#     'weight': 0.0908067,
#     'common_noun': 0.0},
#    {'id': 7.0,
#     'text': '100여 편',
#     'type': 'QT_COUNT',
#     'begin': 33.0,
#     'end': 35.0,
#     'weight': 0.541078,
#     'common_noun': 0.0},
#    {'id': 8.0,
#     'text': '시',
#     'type': 'FD_ART',
#     'begin': 37.0,
#     'end': 37.0,
#     'weight': 0.462231,
#     'common_noun': 0.0},
#    {'id': 9.0,
#     'text': '27세',
#     'type': 'QT_AGE',
#     'begin': 41.0,
#     'end': 42.0,
#     'weight': 0.500877,
#     'common_noun': 0.0}],
#   'NE_Link': [],
#   'dependency': [],
#   'SRL': []},
#  {'id': 4.0,
#   'reserve_str': '',
#   'text': ' 사인이 일본의 생체실험이라는 견해가 있고 그의 사후 일본군에 의한 마루타, 생체실험설이 제기되었으나 불확실하다.',
#   'morp': [{'id': 0.0,
#     'lemma': '사인',
#     'type': 'NNG',
#     'position': 698.0,
#     'weight': 0.108559},
#    {'id': 1.0,
#     'lemma': '이',
#     'type': 'JKS',
#     'position': 704.0,
#     'weight': 0.0607505},
#    {'id': 2.0,
#     'lemma': '일본',
#     'type': 'NNP',
#     'position': 708.0,
#     'weight': 0.134047},
#    {'id': 3.0,
#     'lemma': '의',
#     'type': 'JKG',
#     'position': 714.0,
#     'weight': 0.111028},
#    {'id': 4.0,
#     'lemma': '생체',
#     'type': 'NNG',
#     'position': 718.0,
#     'weight': 0.0796089},
#    {'id': 5.0,
#     'lemma': '실험',
#     'type': 'NNG',
#     'position': 724.0,
#     'weight': 0.0754896},
#    {'id': 6.0,
#     'lemma': '이',
#     'type': 'VCP',
#     'position': 730.0,
#     'weight': 0.0863375},
#    {'id': 7.0,
#     'lemma': '라는',
#     'type': 'ETM',
#     'position': 733.0,
#     'weight': 0.0873929},
#    {'id': 8.0,
#     'lemma': '견해',
#     'type': 'NNG',
#     'position': 740.0,
#     'weight': 0.0792292},
#    {'id': 9.0,
#     'lemma': '가',
#     'type': 'JKS',
#     'position': 746.0,
# ...
#     'position': 1216.0,
#     'begin': 21.0,
#     'end': 21.0},
#    {'id': 19.0,
#     'text': '실험',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1223.0,
#     'begin': 22.0,
#     'end': 22.0},
#    {'id': 20.0,
#     'text': '으로',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1229.0,
#     'begin': 23.0,
#     'end': 23.0},
#    {'id': 21.0,
#     'text': '의문',
#     'type': 'NNG',
#     'scode': '02',
#     'weight': 1.0,
#     'position': 1236.0,
#     'begin': 24.0,
#     'end': 24.0},
#    {'id': 22.0,
#     'text': '의',
#     'type': 'JKG',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1242.0,
#     'begin': 25.0,
#     'end': 25.0},
#    {'id': 23.0,
#     'text': '죽음',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 3.2,
#     'position': 1246.0,
#     'begin': 26.0,
#     'end': 26.0},
#    {'id': 24.0,
#     'text': '을',
#     'type': 'JKO',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1252.0,
#     'begin': 27.0,
#     'end': 27.0},
#    {'id': 25.0,
#     'text': '맞',
#     'type': 'VV',
#     'scode': '02',
#     'weight': 2.2,
#     'position': 1256.0,
#     'begin': 28.0,
#     'end': 28.0},
#    {'id': 26.0,
#     'text': '는다',
#     'type': 'EF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1259.0,
#     'begin': 29.0,
#     'end': 29.0},
#    {'id': 27.0,
#     'text': '.',
#     'type': 'SF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1265.0,
#     'begin': 30.0,
#     'end': 30.0}],
#   'word': [{'id': 0.0, 'text': '그의', 'type': '', 'begin': 0.0, 'end': 1.0},
#    {'id': 1.0, 'text': '친구이자', 'type': '', 'begin': 2.0, 'end': 4.0},
#    {'id': 2.0, 'text': '사촌인', 'type': '', 'begin': 5.0, 'end': 7.0},
#    {'id': 3.0, 'text': '송몽규', 'type': '', 'begin': 8.0, 'end': 8.0},
#    {'id': 4.0, 'text': '역시', 'type': '', 'begin': 9.0, 'end': 9.0},
#    {'id': 5.0, 'text': '독립운동에', 'type': '', 'begin': 10.0, 'end': 12.0},
#    {'id': 6.0, 'text': '가담하려다가', 'type': '', 'begin': 13.0, 'end': 15.0},
#    {'id': 7.0, 'text': '체포되어', 'type': '', 'begin': 16.0, 'end': 18.0},
#    {'id': 8.0, 'text': '일제의', 'type': '', 'begin': 19.0, 'end': 20.0},
#    {'id': 9.0, 'text': '생체', 'type': '', 'begin': 21.0, 'end': 21.0},
#    {'id': 10.0, 'text': '실험으로', 'type': '', 'begin': 22.0, 'end': 23.0},
#    {'id': 11.0, 'text': '의문의', 'type': '', 'begin': 24.0, 'end': 25.0},
#    {'id': 12.0, 'text': '죽음을', 'type': '', 'begin': 26.0, 'end': 27.0},
#    {'id': 13.0, 'text': '맞는다.', 'type': '', 'begin': 28.0, 'end': 30.0}],
#   'NE': [{'id': 0.0,
#     'text': '친구',
#     'type': 'CV_RELATION',
#     'begin': 2.0,
#     'end': 2.0,
#     'weight': 0.702443,
#     'common_noun': 0.0},
#    {'id': 1.0,
#     'text': '사촌인',
#     'type': 'CV_RELATION',
#     'begin': 5.0,
#     'end': 7.0,
#     'weight': 0.237342,
#     'common_noun': 0.0},
#    {'id': 2.0,
#     'text': '송몽규',
#     'type': 'PS_NAME',
#     'begin': 8.0,
#     'end': 8.0,
#     'weight': 0.473243,
#     'common_noun': 0.0},
#    {'id': 3.0,
#     'text': '일제',
#     'type': 'LCP_COUNTRY',
#     'begin': 19.0,
#     'end': 19.0,
#     'weight': 0.413655,
#     'common_noun': 0.0}],
#   'NE_Link': [],
#   'dependency': [],
#   'SRL': []},
#  {'id': 8.0,
#   'reserve_str': '',
#   'text': " 1990년대 후반 이후 그의 창씨개명 '히라누마'가 알려져 논란이 일기도 했다.",
#   'morp': [{'id': 0.0,
#     'lemma': '1990',
#     'type': 'SN',
#     'position': 1267.0,
#     'weight': 1.0},
#    {'id': 1.0,
#     'lemma': '년대',
#     'type': 'NNB',
#     'position': 1271.0,
#     'weight': 0.0421351},
#    {'id': 2.0,
#     'lemma': '후반',
#     'type': 'NNG',
#     'position': 1278.0,
#     'weight': 0.0752402},
#    {'id': 3.0,
#     'lemma': '이후',
#     'type': 'NNG',
#     'position': 1285.0,
#     'weight': 0.0577527},
#    {'id': 4.0,
#     'lemma': '그',
#     'type': 'NP',
#     'position': 1292.0,
#     'weight': 0.096832},
#    {'id': 5.0,
#     'lemma': '의',
#     'type': 'JKG',
#     'position': 1295.0,
#     'weight': 0.118514},
#    {'id': 6.0,
#     'lemma': '창씨',
#     'type': 'NNG',
#     'position': 1299.0,
#     'weight': 0.0304945},
#    {'id': 7.0,
#     'lemma': '개명',
#     'type': 'NNG',
#     'position': 1305.0,
#     'weight': 0.019824},
#    {'id': 8.0, 'lemma': "'", 'type': 'SS', 'position': 1312.0, 'weight': 1.0},
#    {'id': 9.0,
#     'lemma': '히라누마',
#     'type': 'NNP',
#     'position': 1313.0,
#     'weight': 0.0154528},
#    {'id': 10.0, 'lemma': "'", 'type': 'SS', 'position': 1325.0, 'weight': 1.0},
#    {'id': 11.0,
#     'lemma': '가',
#     'type': 'JKS',
#     'position': 1326.0,
#     'weight': 0.0665981},
#    {'id': 12.0,
#     'lemma': '알려지',
#     'type': 'VV',
#     'position': 1330.0,
#     'weight': 0.0545119},
#    {'id': 13.0,
#     'lemma': '어',
#     'type': 'EC',
#     'position': 1336.0,
#     'weight': 0.0362818},
#    {'id': 14.0,
#     'lemma': '논란',
#     'type': 'NNG',
#     'position': 1340.0,
#     'weight': 0.0804446},
#    {'id': 15.0,
#     'lemma': '이',
#     'type': 'JKS',
#     'position': 1346.0,
#     'weight': 0.0631669},
#    {'id': 16.0,
#     'lemma': '일',
#     'type': 'VV',
#     'position': 1350.0,
#     'weight': 0.0641487},
#    {'id': 17.0,
#     'lemma': '기',
#     'type': 'ETN',
#     'position': 1353.0,
#     'weight': 0.128306},
#    {'id': 18.0,
#     'lemma': '도',
#     'type': 'JX',
#     'position': 1356.0,
#     'weight': 0.120155},
#    {'id': 19.0,
#     'lemma': '하',
#     'type': 'VX',
#     'position': 1360.0,
#     'weight': 0.0672903},
#    {'id': 20.0,
#     'lemma': '었',
#     'type': 'EP',
#     'position': 1360.0,
#     'weight': 0.0672903},
#    {'id': 21.0,
#     'lemma': '다',
#     'type': 'EF',
#     'position': 1363.0,
#     'weight': 0.104498},
#    {'id': 22.0,
#     'lemma': '.',
#     'type': 'SF',
#     'position': 1366.0,
#     'weight': 1.0}],
#   'WSD': [{'id': 0.0,
#     'text': '1990',
#     'type': 'SN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1267.0,
#     'begin': 0.0,
#     'end': 0.0},
#    {'id': 1.0,
#     'text': '년대',
#     'type': 'NNB',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1271.0,
#     'begin': 1.0,
#     'end': 1.0},
#    {'id': 2.0,
#     'text': '후반',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 2.2,
#     'position': 1278.0,
#     'begin': 2.0,
#     'end': 2.0},
#    {'id': 3.0,
#     'text': '이후',
#     'type': 'NNG',
#     'scode': '02',
#     'weight': 3.2,
#     'position': 1285.0,
#     'begin': 3.0,
#     'end': 3.0},
#    {'id': 4.0,
#     'text': '그',
#     'type': 'NP',
#     'scode': '01',
#     'weight': 3.2,
#     'position': 1292.0,
#     'begin': 4.0,
#     'end': 4.0},
#    {'id': 5.0,
#     'text': '의',
#     'type': 'JKG',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1295.0,
#     'begin': 5.0,
#     'end': 5.0},
#    {'id': 6.0,
#     'text': '창씨개명',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1299.0,
#     'begin': 6.0,
#     'end': 7.0},
#    {'id': 7.0,
#     'text': "'",
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1312.0,
#     'begin': 8.0,
#     'end': 8.0},
#    {'id': 8.0,
#     'text': '히라누마',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1313.0,
#     'begin': 9.0,
#     'end': 9.0},
#    {'id': 9.0,
#     'text': "'",
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1325.0,
#     'begin': 10.0,
#     'end': 10.0},
#    {'id': 10.0,
#     'text': '가',
#     'type': 'JKS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1326.0,
#     'begin': 11.0,
#     'end': 11.0},
#    {'id': 11.0,
#     'text': '알려지',
#     'type': 'VV',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1330.0,
#     'begin': 12.0,
#     'end': 12.0},
#    {'id': 12.0,
#     'text': '어',
#     'type': 'EC',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1336.0,
#     'begin': 13.0,
#     'end': 13.0},
#    {'id': 13.0,
#     'text': '논란',
#     'type': 'NNG',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1340.0,
#     'begin': 14.0,
#     'end': 14.0},
#    {'id': 14.0,
#     'text': '이',
#     'type': 'JKS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1346.0,
#     'begin': 15.0,
#     'end': 15.0},
#    {'id': 15.0,
#     'text': '일',
#     'type': 'VV',
#     'scode': '01',
#     'weight': 3.2,
#     'position': 1350.0,
#     'begin': 16.0,
#     'end': 16.0},
#    {'id': 16.0,
#     'text': '기',
#     'type': 'ETN',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1353.0,
#     'begin': 17.0,
#     'end': 17.0},
#    {'id': 17.0,
#     'text': '도',
#     'type': 'JX',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1356.0,
#     'begin': 18.0,
#     'end': 18.0},
#    {'id': 18.0,
#     'text': '하',
#     'type': 'VX',
#     'scode': '01',
#     'weight': 3.2,
#     'position': 1360.0,
#     'begin': 19.0,
#     'end': 19.0},
#    {'id': 19.0,
#     'text': '었',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1360.0,
#     'begin': 20.0,
#     'end': 20.0},
#    {'id': 20.0,
#     'text': '다',
#     'type': 'EF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1363.0,
#     'begin': 21.0,
#     'end': 21.0},
#    {'id': 21.0,
#     'text': '.',
#     'type': 'SF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1366.0,
#     'begin': 22.0,
#     'end': 22.0}],
#   'word': [{'id': 0.0, 'text': '1990년대', 'type': '', 'begin': 0.0, 'end': 1.0},
#    {'id': 1.0, 'text': '후반', 'type': '', 'begin': 2.0, 'end': 2.0},
#    {'id': 2.0, 'text': '이후', 'type': '', 'begin': 3.0, 'end': 3.0},
#    {'id': 3.0, 'text': '그의', 'type': '', 'begin': 4.0, 'end': 5.0},
#    {'id': 4.0, 'text': '창씨개명', 'type': '', 'begin': 6.0, 'end': 7.0},
#    {'id': 5.0, 'text': "'히라누마'가", 'type': '', 'begin': 8.0, 'end': 11.0},
#    {'id': 6.0, 'text': '알려져', 'type': '', 'begin': 12.0, 'end': 13.0},
#    {'id': 7.0, 'text': '논란이', 'type': '', 'begin': 14.0, 'end': 15.0},
#    {'id': 8.0, 'text': '일기도', 'type': '', 'begin': 16.0, 'end': 18.0},
#    {'id': 9.0, 'text': '했다.', 'type': '', 'begin': 19.0, 'end': 22.0}],
#   'NE': [{'id': 0.0,
#     'text': '1990년대 후반 이후',
#     'type': 'DT_OTHERS',
#     'begin': 0.0,
#     'end': 3.0,
#     'weight': 0.667466,
#     'common_noun': 0.0},
#    {'id': 1.0,
#     'text': '창씨개명',
#     'type': 'EV_OTHERS',
#     'begin': 6.0,
#     'end': 7.0,
#     'weight': 0.292149,
#     'common_noun': 0.0},
#    {'id': 2.0,
#     'text': '히라누마',
#     'type': 'PS_NAME',
#     'begin': 9.0,
#     'end': 9.0,
#     'weight': 0.358364,
#     'common_noun': 0.0}],
#   'NE_Link': [],
#   'dependency': [],
#   'SRL': []},
#  {'id': 9.0,
#   'reserve_str': '',
#   'text': ' 본명 외에 윤동주(尹童柱), 윤주(尹柱)라는 필명도 사용하였다.',
#   'morp': [{'id': 0.0,
#     'lemma': '본명',
#     'type': 'NNG',
#     'position': 1368.0,
#     'weight': 0.0479247},
#    {'id': 1.0,
#     'lemma': '외',
#     'type': 'NNB',
#     'position': 1375.0,
#     'weight': 0.130542},
#    {'id': 2.0,
#     'lemma': '에',
#     'type': 'JKB',
#     'position': 1378.0,
#     'weight': 0.0877618},
#    {'id': 3.0,
#     'lemma': '윤동주',
#     'type': 'NNP',
#     'position': 1382.0,
#     'weight': 0.0671216},
#    {'id': 4.0, 'lemma': '(', 'type': 'SS', 'position': 1391.0, 'weight': 1.0},
#    {'id': 5.0,
#     'lemma': '尹童柱',
#     'type': 'SH',
#     'position': 1392.0,
#     'weight': 1.0},
#    {'id': 6.0, 'lemma': ')', 'type': 'SS', 'position': 1401.0, 'weight': 1.0},
#    {'id': 7.0, 'lemma': ',', 'type': 'SP', 'position': 1402.0, 'weight': 1.0},
#    {'id': 8.0,
#     'lemma': '윤주',
#     'type': 'NNP',
#     'position': 1404.0,
#     'weight': 0.0740906},
#    {'id': 9.0, 'lemma': '(', 'type': 'SS', 'position': 1410.0, 'weight': 1.0},
#    {'id': 10.0,
#     'lemma': '尹柱',
#     'type': 'SH',
#     'position': 1411.0,
#     'weight': 1.0},
#    {'id': 11.0, 'lemma': ')', 'type': 'SS', 'position': 1417.0, 'weight': 1.0},
#    {'id': 12.0,
#     'lemma': '이',
#     'type': 'VCP',
#     'position': 1418.0,
#     'weight': 0.0651075},
#    {'id': 13.0,
#     'lemma': '라는',
#     'type': 'ETM',
#     'position': 1418.0,
#     'weight': 0.0675313},
#    {'id': 14.0,
#     'lemma': '필명',
#     'type': 'NNG',
#     'position': 1425.0,
#     'weight': 0.0521599},
#    {'id': 15.0,
#     'lemma': '도',
#     'type': 'JX',
#     'position': 1431.0,
#     'weight': 0.0986696},
#    {'id': 16.0,
#     'lemma': '사용',
#     'type': 'NNG',
#     'position': 1435.0,
#     'weight': 0.0526966},
#    {'id': 17.0,
#     'lemma': '하',
#     'type': 'XSV',
#     'position': 1441.0,
#     'weight': 0.0526966},
#    {'id': 18.0,
#     'lemma': '였',
#     'type': 'EP',
#     'position': 1444.0,
#     'weight': 0.0524451},
#    {'id': 19.0,
#     'lemma': '다',
#     'type': 'EF',
#     'position': 1447.0,
#     'weight': 0.0897342},
#    {'id': 20.0,
#     'lemma': '.',
#     'type': 'SF',
#     'position': 1450.0,
#     'weight': 1.0}],
#   'WSD': [{'id': 0.0,
#     'text': '본명',
#     'type': 'NNG',
#     'scode': '01',
#     'weight': 1.0,
#     'position': 1368.0,
#     'begin': 0.0,
#     'end': 0.0},
#    {'id': 1.0,
#     'text': '외',
#     'type': 'NNB',
#     'scode': '04',
#     'weight': 2.2,
#     'position': 1375.0,
#     'begin': 1.0,
#     'end': 1.0},
#    {'id': 2.0,
#     'text': '에',
#     'type': 'JKB',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1378.0,
#     'begin': 2.0,
#     'end': 2.0},
#    {'id': 3.0,
#     'text': '윤동주',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1382.0,
#     'begin': 3.0,
#     'end': 3.0},
#    {'id': 4.0,
#     'text': '(',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1391.0,
#     'begin': 4.0,
#     'end': 4.0},
#    {'id': 5.0,
#     'text': '尹童柱',
#     'type': 'SH',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1392.0,
#     'begin': 5.0,
#     'end': 5.0},
#    {'id': 6.0,
#     'text': ')',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1401.0,
#     'begin': 6.0,
#     'end': 6.0},
#    {'id': 7.0,
#     'text': ',',
#     'type': 'SP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1402.0,
#     'begin': 7.0,
#     'end': 7.0},
#    {'id': 8.0,
#     'text': '윤주',
#     'type': 'NNP',
#     'scode': '00',
#     'weight': 0.0,
#     'position': 1404.0,
#     'begin': 8.0,
#     'end': 8.0},
#    {'id': 9.0,
#     'text': '(',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1410.0,
#     'begin': 9.0,
#     'end': 9.0},
#    {'id': 10.0,
#     'text': '尹柱',
#     'type': 'SH',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1411.0,
#     'begin': 10.0,
#     'end': 10.0},
#    {'id': 11.0,
#     'text': ')',
#     'type': 'SS',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1417.0,
#     'begin': 11.0,
#     'end': 11.0},
#    {'id': 12.0,
#     'text': '이',
#     'type': 'VCP',
#     'scode': '01',
#     'weight': 1.0,
#     'position': 1418.0,
#     'begin': 12.0,
#     'end': 12.0},
#    {'id': 13.0,
#     'text': '라는',
#     'type': 'ETM',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1418.0,
#     'begin': 13.0,
#     'end': 13.0},
#    {'id': 14.0,
#     'text': '필명',
#     'type': 'NNG',
#     'scode': '02',
#     'weight': 3.2,
#     'position': 1425.0,
#     'begin': 14.0,
#     'end': 14.0},
#    {'id': 15.0,
#     'text': '도',
#     'type': 'JX',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1431.0,
#     'begin': 15.0,
#     'end': 15.0},
#    {'id': 16.0,
#     'text': '사용하',
#     'type': 'VV',
#     'scode': '03',
#     'weight': 2.2,
#     'position': 1435.0,
#     'begin': 16.0,
#     'end': 17.0},
#    {'id': 17.0,
#     'text': '였',
#     'type': 'EP',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1444.0,
#     'begin': 18.0,
#     'end': 18.0},
#    {'id': 18.0,
#     'text': '다',
#     'type': 'EF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1447.0,
#     'begin': 19.0,
#     'end': 19.0},
#    {'id': 19.0,
#     'text': '.',
#     'type': 'SF',
#     'scode': '00',
#     'weight': 1.0,
#     'position': 1450.0,
#     'begin': 20.0,
#     'end': 20.0}],
#   'word': [{'id': 0.0, 'text': '본명', 'type': '', 'begin': 0.0, 'end': 0.0},
#    {'id': 1.0, 'text': '외에', 'type': '', 'begin': 1.0, 'end': 2.0},
#    {'id': 2.0, 'text': '윤동주(尹童柱),', 'type': '', 'begin': 3.0, 'end': 7.0},
#    {'id': 3.0, 'text': '윤주(尹柱)라는', 'type': '', 'begin': 8.0, 'end': 13.0},
#    {'id': 4.0, 'text': '필명도', 'type': '', 'begin': 14.0, 'end': 15.0},
#    {'id': 5.0, 'text': '사용하였다.', 'type': '', 'begin': 16.0, 'end': 20.0}],
#   'NE': [{'id': 0.0,
#     'text': '윤동주',
#     'type': 'PS_NAME',
#     'begin': 3.0,
#     'end': 3.0,
#     'weight': 0.339172,
#     'common_noun': 0.0},
#    {'id': 1.0,
#     'text': '尹童柱',
#     'type': 'PS_NAME',
#     'begin': 5.0,
#     'end': 5.0,
#     'weight': 0.160315,
#     'common_noun': 0.0},
#    {'id': 2.0,
#     'text': '윤주',
#     'type': 'PS_NAME',
#     'begin': 8.0,
#     'end': 8.0,
#     'weight': 0.169571,
#     'common_noun': 0.0}],
#   'NE_Link': [],
#   'dependency': [],
#   'SRL': []}]
